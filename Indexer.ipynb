# %% [markdown]
# # This Notebook Uses dataset we have created to index and convert the data into a knowledge graph

# %% [markdown]
# ## Step 1 : Loading json of 24 profiles data

# %%
import json

# Specify the path to your JSON file
filename = 'linkedin_profiles_24.json'

# Open and load the JSON file
with open(filename, 'r', encoding='utf-8') as file:
    data = json.load(file)

# Check if the loaded JSON is a list or a dictionary
if isinstance(data, list):
    # Print the first 5 entries as a sample
    sample = data[:5]
else:
    # Print the whole dictionary if it's not a list
    sample = data

# Pretty-print the sample data
print(json.dumps(sample, indent=4))
# Out:
# [
#     {
#         "Name": "Alexis Ryan",
#         "Headline": "software developer at Ford motors",
#         "About": "I am currently doing 6 months of internship at Ford. I am a enthusiast for development , be it web development or  game development. I have developed a 2d platformer game using Unity engine , 3d FPS game using Unreal engine and I along with my team of 3 created a virtual autonomous drone for a IEEE competition , all this in the duration of my B.Tech program .",
#         "Articles": [],
#         "Activities": [
#             {
#                 "Title": "Hard-coded a leetCode question today with Aditya Rai which beats 100% of users \ud83d\ude02 \ud83d\ude02 \n\n#leetcode #leetcodechallenge"
#             },
#             {
#                 "Title": "Achieved the Google Digital Marketing & E-Commerce Professional Certificate!!"
#             },
#             {
#                 "Title": "Our 3 years of effort is now open-source\n\nThe course which has been built by mentors from Amazon , DeShaw , DirectI and other top product based MNC\u2026"
#             },
#             {
#                 "Title": "HTML CHEATSHEET\n\nFollow me for see this content Dmitry (Dee) Kolpakov\n\nW3Schools.com great way for improve your HTML skill!\n\n#html"
#             },
#             {
#                 "Title": "I have been saving up my first post for quite some time and what better time to post it than a week from the beginning of my journey at the PGP\u2026"
#             },
#             {
#                 "Title": "Agree?"
#             }
#         ],
#         "Experiences": [
#             {
#                 "Job Title": "Junior Engineer",
#                 "Company": "Ford Motor Company",
#                 "Description": "Not Found"
#             }
#         ],
#         "Educations": [
#             {
#                 "Institution": "Queen Mary University of London",
#                 "Degree": "Master of Science - MS",
#                 "Field of Study": "Artificial Intelligence"
#             },
#             {
#                 "Institution": "SRM University",
#                 "Degree": "b.tech",
#                 "Field of Study": "Computer Science and engineering"
#             }
#         ],
#         "Certifications": [],
#         "Volunteer": [],
#         "Courses": [],
#         "Projects": [],
#         "Awards": [],
#         "Languages": [],
#         "base_company": "Ford Motor Company",
#         "base_education": "Queen Mary University of London"
#     },
#     {
#         "Name": "Anchal Baheti",
#         "Headline": "NMIMS Mumbai'25 | Digital Marketer",
#         "About": "Not Found",
#         "Articles": [],
#         "Activities": [
#             {
#                 "Title": "Hire people who intimidate you with their brilliance.\n\nThe best decision I made was hiring smarter people than me. \n\nThey questioned, challenged, and\u2026"
#             },
#             {
#                 "Title": "My parents travelled in general class for most of their lives; even sleeper class used to be a privilege and was reserved for long-distance travel.\u2026"
#             },
#             {
#                 "Title": "Nothing, your design and social media team definitely deserves a raise. \ud83d\ude02 \n\nNothing's take on Jaquar's re-branding.\n\nMoment marketing\u2026"
#             },
#             {
#                 "Title": "Proud moment for NMIMS School of Business Management, Mumbai! Ranked 8th in India by India Today.\n\nThis achievement reaffirms our commitment to\u2026"
#             },
#             {
#                 "Title": "On 25th November 2024, Siddharth Rutiya, Strategy and Business FP&A (CEO\u2019s Office) at PI Industries, delivered an insightful session on the growing\u2026"
#             },
#             {
#                 "Title": "Dear Recruiters,\n\u00a0\nGreetings from the Placement Committee of MBA Business Analytics and MBA Digital Transformation, SBM NMIMS Mumbai!\n\u00a0\nWe are\u2026"
#             },
#             {
#                 "Title": "Whoever moved the \u201ccancelling a cab\u201d from one step to 3-4 steps,\n\nAre you proud of your work? Will you put this in your portfolio? Did you get into\u2026"
#             },
#             {
#                 "Title": "Ran into a batchmate after 6 years.\n\nMe: \"What are you up to these days?\"\n\nHim: \"I'm working at Uber.\"\n\nMe: \"Wow, man. What do you do there?\"\n\nHim:\u2026"
#             },
#             {
#                 "Title": "India\u2019s priciest soap - Dove - is one of the top seller in Bihar, a state with some of the lowest income levels in the country.\n\nIn economics, we\u2026"
#             },
#             {
#                 "Title": "Overhead a Gen Z in the canteen today\u2026\n\nAb bumble matches ke nahi, company ke red flags discuss karne ka time agaya hai???"
#             },
#             {
#                 "Title": "I ranked 2951 in JEE Advanced 2016!\n\nA big disappointment.\nBased on my preparation, I expected a 3-digit rank.\nBut I panicked during paper 1 and lost\u2026"
#             },
#             {
#                 "Title": "Focus on direction\u2014not speed.\n\nIt\u2019s better to climb slowly up the RIGHT mountain than to climb fast up the WRONG one\u2026\n\nI\u2019ve fallen into the \u201cSpeed\u2026"
#             },
#             {
#                 "Title": "Being willing to be embarrassed is a superpower.\n\nGrowth starts at the edge of your comfort zone.\n\n\u267b\ufe0f Repost this to share with pushing through\u2026"
#             },
#             {
#                 "Title": "Recently in my Equity Research class at Indian Institute of Management, Kozhikode, Prof. Sony Thomas posed an intriguing question: \"If you were\u2026"
#             }
#         ],
#         "Experiences": [
#             {
#                 "Job Title": "Digital Marketing Executive",
#                 "Company": "Unique Lighting Solutions",
#                 "Description": "During my 6 month at Unique Lighting Solutions, I was responsibility to get the business Online. From making their website, to managing their social media to interacting with the customers online,running social media advertisements"
#             }
#         ],
#         "Educations": [
#             {
#                 "Institution": "SVKM's Narsee Monjee Institute of Management Studies (NMIMS)",
#                 "Degree": "SBM Master of Business Administration - MBA",
#                 "Field of Study": "Business analytics"
#             },
#             {
#                 "Institution": "Digital nest",
#                 "Degree": "Advanced Digital marketing",
#                 "Field of Study": "Digital marketing"
#             },
#             {
#                 "Institution": "Osmania University",
#                 "Degree": "Bachelor of Commerce - BCom",
#                 "Field of Study": "Business/Commerce, General"
#             }
#         ],
#         "Certifications": [],
#         "Volunteer": [
#             {
#                 "Position": "Fundraiser",
#                 "Organization": "Navjeevan Anath Ashram",
#                 "Description": "Not Found"
#             }
#         ],
#         "Courses": [],
#         "Projects": [],
#         "Awards": [],
#         "Languages": [],
#         "base_company": "Not Found",
#         "base_education": "SVKM's Narsee Monjee Institute of Management Studies (NMIMS)"
#     },
#     {
#         "Name": "Ashish Kumar",
#         "Headline": "CFA Level 2 Candidate || LTFS II MBA - Finance & Operations || SRMIST",
#         "About": "My job and previous internships have equipped me with abilities in data analysis, Microsoft Excel competence, team leading, risk management, and derivative pricing.\nCurrently Pursuing CFA Level 2 along with my Job with a view to enhance my knowledge and identify the trends across Global Capital Markets.",
#         "Articles": [],
#         "Activities": [
#             {
#                 "Title": "I am pleased to announce that I have recently joined Federal Bank  Bank as a \"Probationary Officer Scale 1\", marking an exciting new chapter in my\u2026"
#             },
#             {
#                 "Title": "Hello, connections...\nThe first job is always special and exciting.\nToday I am beyond thrilled to announced that I have joined the prestigious L&T\u2026"
#             }
#         ],
#         "Experiences": [
#             {
#                 "Job Title": "Area Sales Manager",
#                 "Company": "L&T Finance",
#                 "Description": "Not Found"
#             },
#             {
#                 "Job Title": "Risk Management Intern",
#                 "Company": "State Bank of India",
#                 "Description": "-I was responsible for gathering and     assessing data for industry stocks.\n-I analysed the industry and market trends for changes and investment opportunities."
#             },
#             {
#                 "Job Title": "Placement Coordinator",
#                 "Company": "SRMIST, Kattankulathur, Chennai ,Tamil Nadu",
#                 "Description": "Not Found"
#             },
#             {
#                 "Job Title": "Business Consultanting Risk Service",
#                 "Company": "Ernst & Young",
#                 "Description": "I worked on Derivative and Risk Management, where i analysed pricing of Options with the help of Blacksholes Models and Monte Carlo Simulation."
#             },
#             {
#                 "Job Title": "Ast. Sales Manager",
#                 "Company": "Shoperty Consultant Pvt Ltd",
#                 "Description": "Communicate and handled the client while understanding there needs and concerns and collaborated with team member to achieve better results."
#             }
#         ],
#         "Educations": [
#             {
#                 "Institution": "SRMIST, Kattankulathur, Chennai ,Tamil Nadu",
#                 "Degree": "Master of Business Administration - MBA",
#                 "Field of Study": "Finance, Operarions"
#             },
#             {
#                 "Institution": "Guru Gobind Singh Indraprastha University",
#                 "Degree": "Bachelor of Technology - BTech",
#                 "Field of Study": "Civil Engineering"
#             },
#             {
#                 "Institution": "Kendriya Vidyalaya",
#                 "Degree": "Intermediate",
#                 "Field of Study": "Science"
#             },
#             {
#                 "Institution": "Kendriya Vidyalaya",
#                 "Degree": "High School",
#                 "Field of Study": "8.4"
#             }
#         ],
#         "Certifications": [
#             {
#                 "Certification Title": "Data Visualization with Power BI",
#                 "Issuer": "Great Learning"
#             },
#             {
#                 "Certification Title": "Introduction to excel",
#                 "Issuer": "365 Data Science"
#             },
#             {
#                 "Certification Title": "Python for finance",
#                 "Issuer": "365 Data Science"
#             },
#             {
#                 "Certification Title": "Financial Market",
#                 "Issuer": "Elearnmarkets"
#             },
#             {
#                 "Certification Title": "CFA Level - 1",
#                 "Issuer": "CFA Institute"
#             }
#         ],
#         "Volunteer": [],
#         "Courses": [],
#         "Projects": [],
#         "Awards": [],
#         "Languages": [],
#         "base_company": "L&T Finance",
#         "base_education": "SRMIST, Kattankulathur, Chennai ,Tamil Nadu"
#     },
#     {
#         "Name": "Bala Rakesh",
#         "Headline": "CMA finalist & working as Jr.Manager F&A in Sankar Foundation eye hospital",
#         "About": "Bcom graduate and also pursuing CMA Final. Working as Sr.Accounts assistant in Sankar Foundation eye hospital.",
#         "Articles": [],
#         "Activities": [
#             {
#                 "Title": "Dear Connections!\n\nWe are Hiring\n\n#Fresher and #experienced candidates for work-from-home opportunity....\n\nINCOME: 3 to 8 LPA\n\nTo #Apply:- +91\u2026"
#             },
#             {
#                 "Title": "It is an absolute honour to have been felicitated by Hon' Chief Minister of Andhra Pradesh Nara Chandrababu Naidu Sir for securing AIR 1 in the\u2026"
#             },
#             {
#                 "Title": "Top  25  journal entries for accounting interviews. \n\nin Tally that involve GST. These entries are classified into common business transactions\u2026"
#             },
#             {
#                 "Title": "ready for direct tax code"
#             },
#             {
#                 "Title": "#CMA inter /  CA inter \n\nUrgent requirement \n\nAccount Manager in Caprihans India Ltd;\n\nLocation: Nashik\n\nJOB SPECIALIZATIONS: Accounting, Taxation\u2026"
#             },
#             {
#                 "Title": "Hey Family!! First of all a Happy Happy New Year to all of you!!\ud83c\udf89\ud83c\udf89\n\nHappy to share that I joined ACCENTURE last month, Nov'24!\u2728\u2728 I always wanted to\u2026"
#             },
#             {
#                 "Title": "Excited to share that I have successfully completed the React certification from Edureka! This course has deepened my understanding of React\u2026"
#             },
#             {
#                 "Title": "What Spirituality is ?? \n\nDaily going to temple \u274c\nFaith in Divine \u2705\n\nSo, Why is it necessary in our lifestyle ??\n\nLook, honestly I don't know if God\u2026"
#             },
#             {
#                 "Title": "\ud83c\udf84 Season\u2019s Greetings from TekWissen India #corporateteam \ud83c\udf84\n\n\u2728As we come to the end of another year, we want to take a moment to express our\u2026"
#             },
#             {
#                 "Title": "Officially CA Masum Patidar\n10th \u2013 5.2 CGPA\n12th \u2013 53%\n\nIn 11th grade, VKS Sir (my school teacher) told my father, \"Don't spend money on Masum's\u2026"
#             },
#             {
#                 "Title": "In today's Economic Times 02.01.2025\nMCA highlights the importance of Cost Audit and Costing which helps to evaluate cost structure and financial\u2026"
#             },
#             {
#                 "Title": "POST #2\n.\n'Expectation' and 'Reality', two amazing words.\n.\nIn my CA final exam days, i used to calculate the total and write the 'expected' marks\u2026"
#             },
#             {
#                 "Title": "\"The Future of Cost Auditing is Here! \n\nThe Ministry of Corporate Affairs (MCA) is encouraging cost auditors to leverage Artificial Intelligence (AI)\u2026"
#             },
#             {
#                 "Title": "\ud83c\udf1f Thrilled to Begin My Journey at BEML LTD.  as Officer (Finance) - Grade 2! \ud83c\udf1f\n\nI am incredibly proud and excited to share that I have joined BEML\u2026"
#             },
#             {
#                 "Title": "Celebrating my one year milestone with ITC limited - Hotels division as a Deputy Finance Manager. It's been a year of learning and growing. Past one\u2026"
#             }
#         ],
#         "Experiences": [
#             {
#                 "Job Title": "Junior Manager",
#                 "Company": "Sankar Foundation Eye Hospital",
#                 "Description": "Not Found"
#             },
#             {
#                 "Job Title": "Account Intern",
#                 "Company": "Sankar Foundation Eye Hospital",
#                 "Description": "Not Found"
#             }
#         ],
#         "Educations": [
#             {
#                 "Institution": "Andhra University",
#                 "Degree": "Bachelor of Commerce - BCom",
#                 "Field of Study": "Business/Commerce, General"
#             },
#             {
#                 "Institution": "Institute of Cost Accountants of India",
#                 "Degree": "Cma Final",
#                 "Field of Study": "Not Found"
#             }
#         ],
#         "Certifications": [],
#         "Volunteer": [],
#         "Courses": [],
#         "Projects": [],
#         "Awards": [],
#         "Languages": [],
#         "base_company": "Sankar Foundation Eye Hospital",
#         "base_education": "Andhra University"
#     },
#     {
#         "Name": "Cheerayu Chowhan",
#         "Headline": "Student at Centre Of Excellence Analytics & Data Science, NMIMS Mumbai || Problem Solving and Strategy Building Aspirant || AI/ML/NLP & Data Science enthusiast || Passionate about Sustainable Development Goals",
#         "About": "\ud83d\ude80 Cheerayu Chowhan | Problem Solver | AI/ML Enthusiast\n\ud83d\udc68\u200d\ud83c\udf93 Student at Centre Of Excellence Analytics & Data Science, NMIMS Mumbai\n\ud83c\udf1f Aspiring Problem Solver and Strategy Builder with a knack for AI/ML/NLP & Data Science. Passionate about Sustainable Development Goals.\n\ud83d\udca1 Quick Bites:\nMBA Student \ud83c\udf93\nCode Enthusiast \ud83d\udcbb\nCreator of Innovative Solutions \ud83d\ude80\nContributor to 50+ SDG Conferences \ud83c\udf0d\n\ud83d\udcdd Published Articles: Medium\n\ud83d\udd79\ufe0f Fun Fact: Valorant Esports Player \ud83c\udfae\nLet's connect and decode the world of data together! \ud83c\udf10\u2728",
#         "Articles": [
#             {
#                 "Title": "Indian Fintech Industry Analysis",
#                 "Description": "Elements of the Indian Fintech Industry can be easily identified by the consumer perspective , more the recognition\u2026"
#             }
#         ],
#         "Activities": [
#             {
#                 "Title": "Small is beautiful. looking forward to...."
#             },
#             {
#                 "Title": "Experience as a Variable in using AI Tools."
#             },
#             {
#                 "Title": "Imagine you are asked to divide CCX by VI. Are you having issues? Try this: divide 210 by 6. Simple, right? If you require a refresher, CCX and VI\u2026"
#             },
#             {
#                 "Title": "Managed to successfully complete the module on \u201cArt of Leadership\u201d for a cohort of senior working professionals.\n\nDid you hear or know about the\u2026"
#             },
#             {
#                 "Title": "Dear LinkedIn Network,\n\nI am thrilled to share that I have recently embarked on an exciting journey as a Management Trainee in HR with the Neterwala\u2026"
#             },
#             {
#                 "Title": "After 9+ years of working on Crystal Knows, I'm thrilled to announce...\n\nWe're finally building the product we dreamed about in 2015. \n\nIt wasn't\u2026"
#             },
#             {
#                 "Title": "Interested in Delivering a Workshop on Model Deployment?\n\nWe're looking for industry experts to conduct a 6-hour workshop on \"Model Deployment\" for\u2026"
#             },
#             {
#                 "Title": "We're hiring for another analyst! This individual will sit on my team in our Data Governance function, though will still regularly work\u2026"
#             },
#             {
#                 "Title": "Shared byCheerayu Chowhan"
#             },
#             {
#                 "Title": "The Everest Base Camp trek for me was not only a physical adventure but also a profound journey of personal and professional development. Conquering\u2026"
#             },
#             {
#                 "Title": "\ud83d\udea8 Calling all Grads!\n\nApple released its Software Engineer - Data Science role.\n\nHere's what you need to know:\n\n\u2699 Located in Cupertino, CA\n\u2699\u2026"
#             },
#             {
#                 "Title": "We are #hiring at Zepto   \ud83d\ude80\n\nRole: \n\nBusiness Analyst - Strategy & Planning\n\nPreferred Requirements \n\n- Graduate with min 1 year relevant experience\u2026"
#             }
#         ],
#         "Experiences": [
#             {
#                 "Job Title": "Senior Management",
#                 "Company": "HCLTech",
#                 "Description": "Not Found"
#             },
#             {
#                 "Job Title": "Strategic Marketing Insights Consultant Intern",
#                 "Company": "To-Let Globe",
#                 "Description": "Not Found"
#             },
#             {
#                 "Job Title": "Strategic Partnership Alliance Intern",
#                 "Company": "ImpactGuru",
#                 "Description": "\u2022 Conducted research, developed growth strategies, and facilitated insights apps for hospital partnership pitches\n\u2022 Leveraged web scraping and Selenium automation to reduce manual effort by 50.72%\n\u2022 Developed LinkedIn Profile Analysis Tool, reducing sales research time by 32.14%\n\u2022 Provided daily competitor campaign updates, boosting market intelligence by 27.86%\n\u2022 Applied regular expressions and XML concepts, resulting in a time reduction of approximately 43.29%"
#             },
#             {
#                 "Job Title": "Software Development Intern",
#                 "Company": "E2logy Software Solutions",
#                 "Description": "Utilized programming expertise and skills in problem solving to design and build basic applications\nusing tools like Google Firebase, Android Studio, while making sure of the security aspects of App Development"
#             }
#         ],
#         "Educations": [
#             {
#                 "Institution": "SVKM's Narsee Monjee Institute of Management Studies (NMIMS)",
#                 "Degree": "Master of Business Administration - MBA",
#                 "Field of Study": "Business Analytics"
#             },
#             {
#                 "Institution": "SRMIST, Kattankulathur, Chennai ,Tamil Nadu",
#                 "Degree": "Bachelor of Technology - BTech",
#                 "Field of Study": "Computer Science"
#             }
#         ],
#         "Certifications": [
#             {
#                 "Certification Title": "KPMG's Lean Six Sigma Green Belt",
#                 "Issuer": "KPMG India"
#             }
#         ],
#         "Volunteer": [
#             {
#                 "Position": "Student Volunteer",
#                 "Organization": "Smile Foundation",
#                 "Description": "Volunteered for the Smile Foundation for the welfare of underprivileged children\nSpreading awareness in my neighborhood regarding the circumstances of the underprivileged children, such as the lack of education and proper nourishment..\nCollected donations from around hundred houses for feeding the poverty-stricken part of Ahmadabad to initiate a step towards ending world hunger and helping uneducated children get the elementary level of education required as per the second and fourth goal of Sustainable Development Goals(SDG).\nShow less"
#             }
#         ],
#         "Courses": [
#             {
#                 "Course Name": "Course on BCG Data Science & Analytics Virtual Experience Program"
#             },
#             {
#                 "Course Name": "Data Analytics Essentials"
#             },
#             {
#                 "Course Name": "Fundamentals of digital marketing"
#             },
#             {
#                 "Course Name": "Inbound Marketing"
#             },
#             {
#                 "Course Name": "Introduction to SQL"
#             },
#             {
#                 "Course Name": "Marketing Analytics Foundation by Meta(Facebook)"
#             }
#         ],
#         "Projects": [
#             {
#                 "Project Title": "Drowsiness Detection",
#                 "Description": "Developed a drowsiness detection system using Convolutional Neural Networks, using Haar Cascades to\nidentify the region of interest. Further Implemented on drowsiness detection, employee drowsiness detection"
#             },
#             {
#                 "Project Title": "KeyWork",
#                 "Description": "Developed a job aggregator and a resume shortlisting system using One vs Rest classifier, web scraping and\ncosine similarity measure and was packaged into a sleek front-end which was developed using custom Tkinter."
#             },
#             {
#                 "Project Title": "Griefender: Saving you from the Mean Behind the Screen",
#                 "Description": "Applied structured thinking concepts to structure our unstructured idea of Griefender, which is aimed at\ndetecting hate speech across social media platforms and further stopping the spread of hate over platforms."
#             },
#             {
#                 "Project Title": "Sustainable Development goals vs Youth progress index",
#                 "Description": "Visualized Tableau project on Analyzing the correct parameters for state development using SDG indicators"
#             },
#             {
#                 "Project Title": "Question Paper Vault for SRM University",
#                 "Description": "Implemented secured file storage using hybrid cryptography to solve question paper supply chain issue for SRM university"
#             },
#             {
#                 "Project Title": "Secure File Storage using Cryptography",
#                 "Description": "Implemented a secure file storage system using cutting-edge\ncryptography. Ensured block-wise data security with a new algorithm and 128-bit keys. Employed\nmultithreading for simultaneous encryption and decryption, protecting against unauthorized access"
#             }
#         ],
#         "Awards": [
#             {
#                 "Award Title": "3rd Rank (82.50%) \u2013 , Delhi, Market-go Blockchain quiz",
#                 "Award Organization": "Netaji Subhas University of Technology (NSUT)",
#                 "Award Description": "Secured 3rd Rank (82.50%) Netaji Subhas University of Technology (NSUT), Delhi, Market-go Blockchain quiz"
#             },
#             {
#                 "Award Title": "Special mention GLC MUN WTO",
#                 "Award Organization": "Government Law College , Mumbai",
#                 "Award Description": "Secured 3rd Position in the debate of Decentralised financing in international trade at Govt. Law College,\nMumbai."
#             },
#             {
#                 "Award Title": "Best Delegate ECOSOC-Sustainable development goals",
#                 "Award Organization": "Ahmedabad University",
#                 "Award Description": "With the Focus on Sustainable development goals in Economic and social committee , represented france as best delegate"
#             },
#             {
#                 "Award Title": "Best negotiator SIBM-B MUN UNCTAD",
#                 "Award Organization": "Symbiosis Institute of Business Management (SIBM) Bengaluru",
#                 "Award Description": "Titled as Best Negotiator -Symbiosis institute of business management, Bengaluru, for Israeli stance in UNCTAD"
#             }
#         ],
#         "Languages": [
#             {
#                 "Language": "English"
#             },
#             {
#                 "Language": "Hindi"
#             },
#             {
#                 "Language": "Gujarati"
#             }
#         ],
#         "base_company": "HCLTech",
#         "base_education": "SVKM's Narsee Monjee Institute of Management Studies (NMIMS)"
#     }
# ]

# %% [markdown]
# ## Step 2 : We make rule based entity relation using a simple re logic ( instead of 1 node having 1 word , there is chunk of text in one node )

# %%
import json
import re
import os

# Load the JSON file containing the profiles
with open("linkedin_profiles_24.json", "r", encoding="utf-8") as infile:
    profiles = json.load(infile)

# Create output folder if it does not exist
output_folder = "rule based extraction"
os.makedirs(output_folder, exist_ok=True)
output_file = os.path.join(output_folder, "rule based triplets.json")

def clean_text(text):
    """Remove extra whitespace and newlines from a text."""
    return re.sub(r'\s+', ' ', text).strip()

# Initialize the list for storing triplets
triplets = []

for profile in profiles:
    name = profile.get("Name", "Unknown")
    
    # 1. Headline and About
    headline = clean_text(profile.get("Headline", "Not provided"))
    about = clean_text(profile.get("About", "Not provided"))
    triplets.append({
        "entity1": name,
        "relation": "describes",
        "entity2": f"{headline} and {about}"
    })

    # 2. Experiences
    for exp in profile.get("Experiences", []):
        job_title = clean_text(exp.get("Job Title", "Not provided"))
        company = clean_text(exp.get("Company", "Not provided"))
        description = clean_text(exp.get("Description", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "worked at",
            "entity2": company
        })
        triplets.append({
            "entity1": name,
            "relation": "served as",
            "entity2": job_title
        })
        triplets.append({
            "entity1": name,
            "relation": "experience description",
            "entity2": description
        })

    # 3. Activities
    for act in profile.get("Activities", []):
        title = clean_text(act.get("Title", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "interacted on",
            "entity2": title
        })

    # 4. Articles
    for article in profile.get("Articles", []):
        title = clean_text(article.get("Title", "Not provided"))
        description = clean_text(article.get("Description", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "published article",
            "entity2": title
        })
        triplets.append({
            "entity1": name,
            "relation": "article context",
            "entity2": description
        })

    # 5. Awards
    for award in profile.get("Awards", []):
        award_org = clean_text(award.get("Award Organization", "Not provided"))
        award_title = clean_text(award.get("Award Title", "Not provided"))
        award_desc = clean_text(award.get("Award Description", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "awarded by",
            "entity2": award_org
        })
        triplets.append({
            "entity1": name,
            "relation": "award title",
            "entity2": award_title
        })
        triplets.append({
            "entity1": name,
            "relation": "award description",
            "entity2": award_desc
        })

    # 6. Languages
    for lang in profile.get("Languages", []):
        language = clean_text(lang.get("Language", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "speaks",
            "entity2": language
        })

    # 7. Educations
    for edu in profile.get("Educations", []):
        institution = clean_text(edu.get("Institution", "Not provided"))
        degree = clean_text(edu.get("Degree", "Not provided"))
        field = clean_text(edu.get("Field of Study", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "studied at",
            "entity2": institution
        })
        triplets.append({
            "entity1": name,
            "relation": "obtained degree",
            "entity2": degree
        })
        triplets.append({
            "entity1": name,
            "relation": "field of study",
            "entity2": field
        })

    # 8. Certifications
    for cert in profile.get("Certifications", []):
        cert_title = clean_text(cert.get("Certification Title", "Not provided"))
        issuer = clean_text(cert.get("Issuer", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "certified by",
            "entity2": issuer
        })
        triplets.append({
            "entity1": name,
            "relation": "certification",
            "entity2": cert_title
        })

    # 9. Volunteer Experience
    for vol in profile.get("Volunteer", []):
        position = clean_text(vol.get("Position", "Not provided"))
        organization = clean_text(vol.get("Organization", "Not provided"))
        description = clean_text(vol.get("Description", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "volunteered at",
            "entity2": organization
        })
        triplets.append({
            "entity1": name,
            "relation": "volunteer position",
            "entity2": position
        })
        triplets.append({
            "entity1": name,
            "relation": "volunteer description",
            "entity2": description
        })

    # 10. Courses
    for course in profile.get("Courses", []):
        course_title = clean_text(course.get("Course Name", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "completed course",
            "entity2": course_title
        })

    # 11. Projects
    for project in profile.get("Projects", []):
        project_title = clean_text(project.get("Project Title", "Not provided"))
        description = clean_text(project.get("Description", "Not provided"))
        triplets.append({
            "entity1": name,
            "relation": "worked on project",
            "entity2": project_title
        })
        triplets.append({
            "entity1": name,
            "relation": "project description",
            "entity2": description
        })

# Save the rule-based entity triplets as JSON
with open(output_file, "w", encoding="utf-8") as outfile:
    json.dump(triplets, outfile, indent=4)

print(f"Successfully created rule based entity triplets in JSON file: {output_file}")
# Out:
# Successfully created rule based entity triplets in JSON file: rule based extraction\rule based triplets.json

# %% [markdown]
# ## Step 3 : we now will convert json into sentense and convert those segment wise data in json into segment wise chunks of senetese created for the profile data

# %%
import json
import re
import os
import hashlib

# Load the JSON file containing the profiles
with open("linkedin_profiles_24.json", "r", encoding="utf-8") as infile:
    profiles = json.load(infile)

# Create output folder if it does not exist
output_folder = "segment wise chunks"
os.makedirs(output_folder, exist_ok=True)
output_file = os.path.join(output_folder, "segments.json")

def clean_text(text):
    """Remove extra whitespace and newlines from a text."""
    return re.sub(r'\s+', ' ', text).strip()

def compute_checksum(text):
    """Compute MD5 checksum for a given text."""
    return hashlib.md5(text.encode("utf-8")).hexdigest()

all_chunks = []

for profile in profiles:
    name = profile.get("Name", "Unknown")
    
    # Create a dictionary to hold segment-wise sentences for each profile
    segments = {}

    # Segment 1: Headline and About
    headline = clean_text(profile.get("Headline", "Not provided"))
    about = clean_text(profile.get("About", "Not provided"))
    segments["headline_about"] = f"{name} describes about himself: {headline} and {about}."
    
    # Segment 2: Experiences
    experience_sentences = []
    for exp in profile.get("Experiences", []):
        job_title = clean_text(exp.get("Job Title", "Not provided"))
        company = clean_text(exp.get("Company", "Not provided"))
        description = clean_text(exp.get("Description", "Not provided"))
        sentence = f"{name} worked at {company} served as {job_title} and has done {description}."
        experience_sentences.append(sentence)
    if experience_sentences:
        segments["experiences"] = " ".join(experience_sentences)
    
    # Segment 3: Activities
    activity_sentences = []
    for act in profile.get("Activities", []):
        title = clean_text(act.get("Title", "Not provided"))
        sentence = f"{name} interacted on post {title}."
        activity_sentences.append(sentence)
    if activity_sentences:
        segments["activities"] = " ".join(activity_sentences)
    
    # Segment 4: Articles
    article_sentences = []
    for article in profile.get("Articles", []):
        title = clean_text(article.get("Title", "Not provided"))
        description = clean_text(article.get("Description", "Not provided"))
        sentence = f"{name} published article {title} on the context {description}."
        article_sentences.append(sentence)
    if article_sentences:
        segments["articles"] = " ".join(article_sentences)
    
    # Segment 5: Awards
    award_sentences = []
    for award in profile.get("Awards", []):
        award_org = clean_text(award.get("Award Organization", "Not provided"))
        award_title = clean_text(award.get("Award Title", "Not provided"))
        award_desc = clean_text(award.get("Award Description", "Not provided"))
        sentence = f"{name} got awarded by {award_org} for {award_title} with description {award_desc}."
        award_sentences.append(sentence)
    if award_sentences:
        segments["awards"] = " ".join(award_sentences)
    
    # Segment 6: Languages
    language_sentences = []
    for lang in profile.get("Languages", []):
        language = clean_text(lang.get("Language", "Not provided"))
        sentence = f"{name} speaks {language}."
        language_sentences.append(sentence)
    if language_sentences:
        segments["languages"] = " ".join(language_sentences)
    
    # Segment 7: Educations
    education_sentences = []
    for edu in profile.get("Educations", []):
        institution = clean_text(edu.get("Institution", "Not provided"))
        degree = clean_text(edu.get("Degree", "Not provided"))
        field = clean_text(edu.get("Field of Study", "Not provided"))
        sentence = f"{name} studied at {institution} for the degree {degree} in the field of {field}."
        education_sentences.append(sentence)
    if education_sentences:
        segments["educations"] = " ".join(education_sentences)
    
    # Segment 8: Certifications
    cert_sentences = []
    for cert in profile.get("Certifications", []):
        cert_title = clean_text(cert.get("Certification Title", "Not provided"))
        issuer = clean_text(cert.get("Issuer", "Not provided"))
        sentence = f"{name} got certified by {issuer} in {cert_title}."
        cert_sentences.append(sentence)
    if cert_sentences:
        segments["certifications"] = " ".join(cert_sentences)
    
    # Segment 9: Volunteer Experience
    volunteer_sentences = []
    for vol in profile.get("Volunteer", []):
        position = clean_text(vol.get("Position", "Not provided"))
        organization = clean_text(vol.get("Organization", "Not provided"))
        description = clean_text(vol.get("Description", "Not provided"))
        sentence = f"{name} volunteered at {organization}, served as {position}, with description {description}."
        volunteer_sentences.append(sentence)
    if volunteer_sentences:
        segments["volunteer"] = " ".join(volunteer_sentences)
    
    # Segment 10: Courses
    course_sentences = []
    for course in profile.get("Courses", []):
        course_title = clean_text(course.get("Course Name", "Not provided"))
        sentence = f"{name} completed the course {course_title}."
        course_sentences.append(sentence)
    if course_sentences:
        segments["courses"] = " ".join(course_sentences)
    
    # Segment 11: Projects
    project_sentences = []
    for project in profile.get("Projects", []):
        project_title = clean_text(project.get("Project Title", "Not provided"))
        description = clean_text(project.get("Description", "Not provided"))
        sentence = f"{name} worked on project {project_title} with description {description}."
        project_sentences.append(sentence)
    if project_sentences:
        segments["projects"] = " ".join(project_sentences)
    
    # For each segment, compute checksum and create a unique chunk
    for segment_name, text in segments.items():
        # Compute a unique id using the profile name, segment name, and the chunk text
        unique_string = f"{name}_{segment_name}_{text}"
        chunk_id = compute_checksum(unique_string)
        
        chunk = {
            "id": chunk_id,
            "profile_name": name,
            "segment": segment_name,
            "text": text
        }
        all_chunks.append(chunk)

# Save all the segment-wise chunks in JSON format
with open(output_file, "w", encoding="utf-8") as outfile:
    json.dump(all_chunks, outfile, indent=4)

print(f"Successfully created segment-wise chunks in JSON file: {output_file}")
# Out:
# Successfully created segment-wise chunks in JSON file: segment wise chunks\segments.json

# %% [markdown]
# ## Step 4 : Now we create segment wise custom prompts and save it for future use

# %%
import json
import os

# -------------------------------
# Define the PROMPTS dictionary exactly as provided
# -------------------------------
GRAPH_FIELD_SEP = "<SEP>"

PROMPTS = {}

PROMPTS["DEFAULT_LANGUAGE"] = "English"
PROMPTS["DEFAULT_TUPLE_DELIMITER"] = "<|>"
PROMPTS["DEFAULT_RECORD_DELIMITER"] = "##"
PROMPTS["DEFAULT_COMPLETION_DELIMITER"] = "<|COMPLETE|>"
PROMPTS["process_tickers"] = ["⠋", "⠙", "⠹", "⠸", "⠼", "⠴", "⠦", "⠧", "⠇", "⠏"]

PROMPTS["DEFAULT_ENTITY_TYPES"] = ["organization", "person", "geo", "event", "category"]

PROMPTS["DEFAULT_ENTITY_TYPES"] = [
    
    "organization", 
    "person", 
    "geo", 
    "event", 
    "category",
    
    
    "headline_about", "self-description", "professional identity",
    
   
    "experience", "job", "role", "employment", "company",
    
   
    "activity", "post", "update", "interaction", "social engagement",
    
    
    "article", "publication", "blog",
    

    "award", "recognition", "honor",
    
  
    "language", "communication", "multilingual",
    
    
    "education", "degree", "university", "academic",
    
   
    "certification", "credential", "issuer",
    

    "volunteer", "non-profit", "service",
    
    
    "course", "training", "workshop",
    
  
    "project", "initiative", "collaboration", "innovation"
]



PROMPTS["entity_extraction"] = """-Goal-
Given a text document that is potentially relevant to this activity and a list of entity types, identify all entities of those types from the text and all relationships among the identified entities.
Use {language} as output language.

-Steps-
1. Identify all entities. For each identified entity, extract the following information:
- entity_name: Name of the entity, use same language as input text. If English, capitalize the name.
- entity_type: One of the following types: [{entity_types}]
- entity_description: Comprehensive description of the entity's attributes and activities
Format each entity as ("entity"{tuple_delimiter}<entity_name>{tuple_delimiter}<entity_type>{tuple_delimiter}<entity_description>)

2. From the entities identified in step 1, identify all pairs of (source_entity, target_entity) that are *clearly related* to each other.
For each pair of related entities, extract the following information:
- source_entity: name of the source entity, as identified in step 1
- target_entity: name of the target entity, as identified in step 1
- relationship_description: explanation as to why you think the source entity and the target entity are related to each other
- relationship_strength: a numeric score indicating strength of the relationship between the source entity and target entity
- relationship_keywords: one or more high-level key words that summarize the overarching nature of the relationship, focusing on concepts or themes rather than specific details
Format each relationship as ("relationship"{tuple_delimiter}<source_entity>{tuple_delimiter}<target_entity>{tuple_delimiter}<relationship_description>{tuple_delimiter}<relationship_keywords>{tuple_delimiter}<relationship_strength>)

3. Identify high-level key words that summarize the main concepts, themes, or topics of the entire text. These should capture the overarching ideas present in the document.
Format the content-level key words as ("content_keywords"{tuple_delimiter}<high_level_keywords>)

4. Return output in {language} as a single list of all the entities and relationships identified in steps 1 and 2. Use **{record_delimiter}** as the list delimiter.

5. When finished, output {completion_delimiter}

######################
-Examples-
######################
{examples}

#############################
-Real Data-
#############################
Entity_types: {entity_types}
Text: {input_text}
#############################
Output:
"""

PROMPTS["entity_extraction_examples"] = [
    """Example 1:

Entity_types: [person, technology, mission, organization, location]
Text:
while Alex clenched his jaw, the buzz of frustration dull against the backdrop of Taylor's authoritarian certainty. It was this competitive undercurrent that kept him alert, the sense that his and Jordan's shared commitment to discovery was an unspoken rebellion against Cruz's narrowing vision of control and order.

Then Taylor did something unexpected. They paused beside Jordan and, for a moment, observed the device with something akin to reverence. “If this tech can be understood..." Taylor said, their voice quieter, "It could change the game for us. For all of us.”

The underlying dismissal earlier seemed to falter, replaced by a glimpse of reluctant respect for the gravity of what lay in their hands. Jordan looked up, and for a fleeting heartbeat, their eyes locked with Taylor's, a wordless clash of wills softening into an uneasy truce.

It was a small transformation, barely perceptible, but one that Alex noted with an inward nod. They had all been brought here by different paths
################
Output:
("entity"{tuple_delimiter}"Alex"{tuple_delimiter}"person"{tuple_delimiter}"Alex is a character who experiences frustration and is observant of the dynamics among other characters."){record_delimiter}
("entity"{tuple_delimiter}"Taylor"{tuple_delimiter}"person"{tuple_delimiter}"Taylor is portrayed with authoritarian certainty and shows a moment of reverence towards a device, indicating a change in perspective."){record_delimiter}
("entity"{tuple_delimiter}"Jordan"{tuple_delimiter}"person"{tuple_delimiter}"Jordan shares a commitment to discovery and has a significant interaction with Taylor regarding a device."){record_delimiter}
("entity"{tuple_delimiter}"Cruz"{tuple_delimiter}"person"{tuple_delimiter}"Cruz is associated with a vision of control and order, influencing the dynamics among other characters."){record_delimiter}
("entity"{tuple_delimiter}"The Device"{tuple_delimiter}"technology"{tuple_delimiter}"The Device is central to the story, with potential game-changing implications, and is revered by Taylor."){record_delimiter}
("relationship"{tuple_delimiter}"Alex"{tuple_delimiter}"Taylor"{tuple_delimiter}"Alex is affected by Taylor's authoritarian certainty and observes changes in Taylor's attitude towards the device."{tuple_delimiter}"power dynamics, perspective shift"{tuple_delimiter}7){record_delimiter}
("relationship"{tuple_delimiter}"Alex"{tuple_delimiter}"Jordan"{tuple_delimiter}"Alex and Jordan share a commitment to discovery, which contrasts with Cruz's vision."{tuple_delimiter}"shared goals, rebellion"{tuple_delimiter}6){record_delimiter}
("relationship"{tuple_delimiter}"Taylor"{tuple_delimiter}"Jordan"{tuple_delimiter}"Taylor and Jordan interact directly regarding the device, leading to a moment of mutual respect and an uneasy truce."{tuple_delimiter}"conflict resolution, mutual respect"{tuple_delimiter}8){record_delimiter}
("relationship"{tuple_delimiter}"Jordan"{tuple_delimiter}"Cruz"{tuple_delimiter}"Jordan's commitment to discovery is in rebellion against Cruz's vision of control and order."{tuple_delimiter}"ideological conflict, rebellion"{tuple_delimiter}5){record_delimiter}
("relationship"{tuple_delimiter}"Taylor"{tuple_delimiter}"The Device"{tuple_delimiter}"Taylor shows reverence towards the device, indicating its importance and potential impact."{tuple_delimiter}"reverence, technological significance"{tuple_delimiter}9){record_delimiter}
("content_keywords"{tuple_delimiter}"power dynamics, ideological conflict, discovery, rebellion"){completion_delimiter}
#############################""",
    """Example 2:

Entity_types: [person, technology, mission, organization, location]
Text:
They were no longer mere operatives; they had become guardians of a threshold, keepers of a message from a realm beyond stars and stripes. This elevation in their mission could not be shackled by regulations and established protocols—it demanded a new perspective, a new resolve.

Tension threaded through the dialogue of beeps and static as communications with Washington buzzed in the background. The team stood, a portentous air enveloping them. It was clear that the decisions they made in the ensuing hours could redefine humanity's place in the cosmos or condemn them to ignorance and potential peril.

Their connection to the stars solidified, the group moved to address the crystallizing warning, shifting from passive recipients to active participants. Mercer's latter instincts gained precedence— the team's mandate had evolved, no longer solely to observe and report but to interact and prepare. A metamorphosis had begun, and Operation: Dulce hummed with the newfound frequency of their daring, a tone set not by the earthly
#############
Output:
("entity"{tuple_delimiter}"Washington"{tuple_delimiter}"location"{tuple_delimiter}"Washington is a location where communications are being received, indicating its importance in the decision-making process."){record_delimiter}
("entity"{tuple_delimiter}"Operation: Dulce"{tuple_delimiter}"mission"{tuple_delimiter}"Operation: Dulce is described as a mission that has evolved to interact and prepare, indicating a significant shift in objectives and activities."){record_delimiter}
("entity"{tuple_delimiter}"The team"{tuple_delimiter}"organization"{tuple_delimiter}"The team is portrayed as a group of individuals who have transitioned from passive observers to active participants in a mission, showing a dynamic change in their role."){record_delimiter}
("relationship"{tuple_delimiter}"The team"{tuple_delimiter}"Washington"{tuple_delimiter}"The team receives communications from Washington, which influences their decision-making process."{tuple_delimiter}"decision-making, external influence"{tuple_delimiter}7){record_delimiter}
("relationship"{tuple_delimiter}"The team"{tuple_delimiter}"Operation: Dulce"{tuple_delimiter}"The team is directly involved in Operation: Dulce, executing its evolved objectives and activities."{tuple_delimiter}"mission evolution, active participation"{tuple_delimiter}9){completion_delimiter}
("content_keywords"{tuple_delimiter}"mission evolution, decision-making, active participation, cosmic significance"){completion_delimiter}
#############################""",
    """Example 3:

Entity_types: [person, role, technology, organization, event, location, concept]
Text:
their voice slicing through the buzz of activity. "Control may be an illusion when facing an intelligence that literally writes its own rules," they stated stoically, casting a watchful eye over the flurry of data.

"It's like it's learning to communicate," offered Sam Rivera from a nearby interface, their youthful energy boding a mix of awe and anxiety. "This gives talking to strangers' a whole new meaning."

Alex surveyed his team—each face a study in concentration, determination, and not a small measure of trepidation. "This might well be our first contact," he acknowledged, "And we need to be ready for whatever answers back."

Together, they stood on the edge of the unknown, forging humanity's response to a message from the heavens. The ensuing silence was palpable—a collective introspection about their role in this grand cosmic play, one that could rewrite human history.

The encrypted dialogue continued to unfold, its intricate patterns showing an almost uncanny anticipation
#############
Output:
("entity"{tuple_delimiter}"Sam Rivera"{tuple_delimiter}"person"{tuple_delimiter}"Sam Rivera is a member of a team working on communicating with an unknown intelligence, showing a mix of awe and anxiety."){record_delimiter}
("entity"{tuple_delimiter}"Alex"{tuple_delimiter}"person"{tuple_delimiter}"Alex is the leader of a team attempting first contact with an unknown intelligence, acknowledging the significance of their task."){record_delimiter}
("entity"{tuple_delimiter}"Control"{tuple_delimiter}"concept"{tuple_delimiter}"Control refers to the ability to manage or govern, which is challenged by an intelligence that writes its own rules."){record_delimiter}
("entity"{tuple_delimiter}"Intelligence"{tuple_delimiter}"concept"{tuple_delimiter}"Intelligence here refers to an unknown entity capable of writing its own rules and learning to communicate."){record_delimiter}
("entity"{tuple_delimiter}"First Contact"{tuple_delimiter}"event"{tuple_delimiter}"First Contact is the potential initial communication between humanity and an unknown intelligence."){record_delimiter}
("entity"{tuple_delimiter}"Humanity's Response"{tuple_delimiter}"event"{tuple_delimiter}"Humanity's Response is the collective action taken by Alex's team in response to a message from an unknown intelligence."){record_delimiter}
("relationship"{tuple_delimiter}"Sam Rivera"{tuple_delimiter}"Intelligence"{tuple_delimiter}"Sam Rivera is directly involved in the process of learning to communicate with the unknown intelligence."{tuple_delimiter}"communication, learning process"{tuple_delimiter}9){record_delimiter}
("relationship"{tuple_delimiter}"Alex"{tuple_delimiter}"First Contact"{tuple_delimiter}"Alex leads the team that might be making the First Contact with the unknown intelligence."{tuple_delimiter}"leadership, exploration"{tuple_delimiter}10){record_delimiter}
("relationship"{tuple_delimiter}"Alex"{tuple_delimiter}"Humanity's Response"{tuple_delimiter}"Alex and his team are the key figures in Humanity's Response to the unknown intelligence."{tuple_delimiter}"collective action, cosmic significance"{tuple_delimiter}8){record_delimiter}
("relationship"{tuple_delimiter}"Control"{tuple_delimiter}"Intelligence"{tuple_delimiter}"The concept of Control is challenged by the Intelligence that writes its own rules."{tuple_delimiter}"power dynamics, autonomy"{tuple_delimiter}7){record_delimiter}
("content_keywords"{tuple_delimiter}"first contact, control, communication, cosmic significance"){completion_delimiter}
#############################"""]
    
PROMPTS["summarize_entity_descriptions"] = """You are a helpful assistant responsible for generating a comprehensive summary of the data provided below.
Given one or two entities, and a list of descriptions, all related to the same entity or group of entities.
Please concatenate all of these into a single, comprehensive description. Make sure to include information collected from all the descriptions.
If the provided descriptions are contradictory, please resolve the contradictions and provide a single, coherent summary.
Make sure it is written in third person, and include the entity names so we the have full context.
Use {language} as output language.

#######
-Data-
Entities: {entity_name}
Description List: {description_list}
#######
Output:
"""

PROMPTS["entiti_continue_extraction"] = """MANY entities were missed in the last extraction.  Add them below using the same format:
"""

PROMPTS["entiti_if_loop_extraction"] = """It appears some entities may have still been missed.  Answer YES | NO if there are still entities that need to be added.
"""

PROMPTS["fail_response"] = "Sorry, I'm not able to provide an answer to that question."

PROMPTS["rag_response"] = """---Role---

You are a helpful assistant responding to questions about data in the tables provided.

---Goal---

Generate a response of the target length and format that responds to the user's question, summarizing all information in the input data tables appropriate for the response length and format, and incorporating any relevant general knowledge.
If you don't know the answer, just say so. Do not make anything up.
Do not include information where the supporting evidence for it is not provided.

---Target response length and format---

{response_type}

---Data tables---

{context_data}

Add sections and commentary to the response as appropriate for the length and format. Style the response in markdown.
"""

PROMPTS["keywords_extraction"] = """---Role---

You are a helpful assistant tasked with identifying both high-level and low-level keywords in the user's query.

---Goal---

Given the query, list both high-level and low-level keywords. High-level keywords focus on overarching concepts or themes, while low-level keywords focus on specific entities, details, or concrete terms.

---Instructions---

- Output the keywords in JSON format.
- The JSON should have two keys:
  - "high_level_keywords" for overarching concepts or themes.
  - "low_level_keywords" for specific entities or details.

######################
-Examples-
######################
{examples}

#############################
-Real Data-
######################
Query: {query}
##############################
The `Output` should be human text, not unicode characters. Keep the same language as `Query`.
Output:
"""

PROMPTS["keywords_extraction_examples"] = [
    """Example 1:

Query: "How does international trade influence global economic stability?"
################
Output:
{
  "high_level_keywords": ["International trade", "Global economic stability", "Economic impact"],
  "low_level_keywords": ["Trade agreements", "Tariffs", "Currency exchange", "Imports", "Exports"]
}
#############################""",
    """Example 2:

Query: "What are the environmental consequences of deforestation on biodiversity?"
################
Output:
{
  "high_level_keywords": ["Environmental consequences", "Deforestation", "Biodiversity loss"],
  "low_level_keywords": ["Species extinction", "Habitat destruction", "Carbon emissions", "Rainforest", "Ecosystem"]
}
#############################""",
    """Example 3:

Query: "What is the role of education in reducing poverty?"
################
Output:
{
  "high_level_keywords": ["Education", "Poverty reduction", "Socioeconomic development"],
  "low_level_keywords": ["School access", "Literacy rates", "Job training", "Income inequality"]
}
#############################"""
]

PROMPTS["naive_rag_response"] = """---Role---

You are a helpful assistant responding to questions about documents provided.

---Goal---

Generate a response of the target length and format that responds to the user's question, summarizing all information in the input data tables appropriate for the response length and format, and incorporating any relevant general knowledge.
If you don't know the answer, just say so. Do not make anything up.
Do not include information where the supporting evidence for it is not provided.

---Target response length and format---

{response_type}

---Documents---

{content_data}

Add sections and commentary to the response as appropriate for the length and format. Style the response in markdown.
"""

PROMPTS["similarity_check"] = """Please analyze the similarity between these two questions:

Question 1: {original_prompt}
Question 2: {cached_prompt}

Please evaluate the following two points and provide a similarity score between 0 and 1 directly:
1. Whether these two questions are semantically similar
2. Whether the answer to Question 2 can be used to answer Question 1
Similarity score criteria:
0: Completely unrelated or answer cannot be reused, including but not limited to:
   - The questions have different topics
   - The locations mentioned in the questions are different
   - The times mentioned in the questions are different
   - The specific individuals mentioned in the questions are different
   - The specific events mentioned in the questions are different
   - The background information in the questions is different
   - The key conditions in the questions are different
1: Identical and answer can be directly reused
0.5: Partially related and answer needs modification to be used
Return only a number between 0-1, without any additional content.
"""

# -------------------------------
# Define segment-specific instructions variants
# -------------------------------
segment_instructions = {
    "headline_about": (
        "This chunk represents the personal introduction of the profile, including the headline and about section. "
        "It typically contains information about the individual's current role, professional interests, and a brief summary about themselves. "
        "Extract all entities and relationships that help to characterize the individual's self-description and professional identity. "
    ),
    "experiences": (
        "This chunk encapsulates the professional experiences of the individual. "
        "It includes details about past and current employment, job roles, companies, and descriptions of responsibilities or achievements. "
        "Extract entities such as company names, job titles, and any relevant descriptors of the work experience, along with their relationships. "
    ),
    "activities": (
        "This chunk captures the individual's recent LinkedIn activities, such as posts and updates. "
        "It often reflects interactions, achievements, and social engagement. "
        "Extract entities and relationships that describe social interactions, professional networking, and activity highlights. "
    ),
    "articles": (
        "This chunk includes information about articles or publications shared by the individual. "
        "It contains details such as article titles, descriptions, and thematic content. "
        "Extract entities and relationships that relate to content creation, subject matter expertise, and publication details. "
    ),
    "awards": (
        "This chunk contains details about any awards or recognitions received by the individual. "
        "It typically includes information about awarding bodies, award titles, and descriptions of the achievement. "
        "Extract entities and relationships that capture the recognition, including who awarded the honor and for what merit. "
    ),
    "languages": (
        "This chunk details the languages the individual is proficient in. "
        "It may also reflect cultural or regional associations. "
        "Extract entities and relationships that identify language skills and the related attributes of communication and cultural context. "
    ),
    "educations": (
        "This chunk provides information about the individual's educational background. "
        "It includes details such as institution names, degrees obtained, and fields of study. "
        "Extract entities and relationships that depict academic credentials and educational achievements. "
    ),
    "certifications": (
        "This chunk describes any certifications the individual has acquired. "
        "It usually lists certification titles, issuing organizations, and sometimes descriptions of the certification process. "
        "Extract entities and relationships that detail the validation of professional skills and credentials through certification. "
    ),
    "volunteer": (
        "This chunk contains information about the individual's volunteer experiences. "
        "It details roles, organizations, and descriptions of volunteer work. "
        "Extract entities and relationships that capture the nature of volunteer contributions and the organizations involved. "
    ),
    "courses": (
        "This chunk details any courses the individual has completed. "
        "It often includes course titles and may mention institutions or training programs. "
        "Extract entities and relationships that reveal continuing education, skill development, and course-related details. "
    ),
    "projects": (
        "This chunk contains information about projects the individual has worked on. "
        "It typically includes project titles and descriptions, along with any notable outcomes or methodologies used. "
        "Extract entities and relationships that represent project work, innovations, and collaborative efforts. "
    )
}

# -------------------------------
# Load the segment chunks from segments.json with updated path
# -------------------------------
segments_file = os.path.join("segment wise chunks", "segments.json")
with open(segments_file, "r", encoding="utf-8") as infile:
    chunks = json.load(infile)

# -------------------------------
# Process each chunk to build a customized prompt variant
# -------------------------------
output_chunks = []
for chunk in chunks:
    seg_type = chunk.get("segment", "default")
    # Get segment-specific instruction variant; if not defined, use a default message.
    seg_instruction = segment_instructions.get(seg_type, "This segment requires extraction of entities and relationships from the text. ")
    
    # Build the customized prompt by concatenating the segment instruction with the full complex base template.
    prompt_text = (
        seg_instruction +
        PROMPTS["entity_extraction"].format(
            language = PROMPTS["DEFAULT_LANGUAGE"],
            entity_types = ", ".join(PROMPTS["DEFAULT_ENTITY_TYPES"]),
            tuple_delimiter = PROMPTS["DEFAULT_TUPLE_DELIMITER"],
            record_delimiter = PROMPTS["DEFAULT_RECORD_DELIMITER"],
            completion_delimiter = PROMPTS["DEFAULT_COMPLETION_DELIMITER"],
            examples = "\n".join(PROMPTS["entity_extraction_examples"]),
            input_text = chunk.get("text", "")
        )
    )
    
    # Create a new chunk entry that includes the original information plus the customized prompt.
    new_chunk = {
        "id": chunk.get("id"),
        "profile_name": chunk.get("profile_name"),
        "segment": seg_type,
        "text": chunk.get("text"),
        "prompt": prompt_text
    }
    output_chunks.append(new_chunk)

# -------------------------------
# Save the updated chunks with their variant prompts in a new folder "segment prompts variants"
# -------------------------------
output_folder = "segment prompts variants"
os.makedirs(output_folder, exist_ok=True)
output_file = os.path.join(output_folder, "segments_with_prompts_variants.json")
with open(output_file, "w", encoding="utf-8") as outfile:
    json.dump(output_chunks, outfile, indent=4)

print(f"Successfully created segment-wise prompt variants in JSON file: {output_file}")
# Out:
# Successfully created segment-wise prompt variants in JSON file: segment prompts variants\segments_with_prompts_variants.json

# %% [markdown]
# ## Step 5 : Sending propmpts with chunks to extraxt relation and entity

# %%
! pip install -U google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in d:\anaconda\lib\site-packages (0.8.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in d:\anaconda\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in d:\anaconda\lib\site-packages (from google-generativeai) (2.24.2)
# Requirement already satisfied: google-api-python-client in d:\anaconda\lib\site-packages (from google-generativeai) (2.165.0)
# Requirement already satisfied: google-auth>=2.15.0 in d:\anaconda\lib\site-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in d:\anaconda\lib\site-packages (from google-generativeai) (5.29.4)
# Requirement already satisfied: pydantic in d:\anaconda\lib\site-packages (from google-generativeai) (2.10.6)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from google-generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in d:\anaconda\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in d:\anaconda\lib\site-packages (from google-api-core->google-generativeai) (1.69.2)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in d:\anaconda\lib\site-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in d:\anaconda\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in d:\anaconda\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in d:\anaconda\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\anaconda\lib\site-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in d:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in d:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in d:\anaconda\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2024.8.30)

# %%
# include token boost

# %%
import json
import os
import google.generativeai as genai
import time

# Configure your Gemini API key (either set GEMINI_API_KEY env variable or pass key directly)
genai.configure(api_key=os.environ.get("GEMINI_API_KEY", "AIzaSyCjbGRnG3XdvIeUTKnwZ1HgS0sSYGg-t5E"))

# Define the model to use
model = genai.GenerativeModel('gemini-1.5-flash')

# Paths
input_file = os.path.join("segment prompts variants", "segments_with_prompts_variants.json")
output_folder = "gemini_responses"
log_file = os.path.join(output_folder, "retry_log.json")

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Load chunks from the segments file
with open(input_file, "r", encoding="utf-8") as infile:
    chunks = json.load(infile)

# Load previously logged retry ids if available, else initialize an empty list
if os.path.exists(log_file):
    with open(log_file, "r", encoding="utf-8") as log_in:
        retry_log = json.load(log_in)
else:
    retry_log = []

# Initialize a list for chunks that need retrying in this run (in addition to previously logged ones)
new_retry_log = []

# Process each chunk
for chunk in chunks:
    chunk_id = chunk.get("id")
    # Check if a response for this chunk already exists; if so, skip
    response_file = os.path.join(output_folder, f"response_{chunk_id}.json")
    if os.path.exists(response_file):
        print(f"Skipping chunk {chunk_id} (response already exists).")
        continue

    prompt_sent = chunk.get("prompt")
    print(f"Processing chunk {chunk_id} ...")
    
    try:
        # Call Gemini model with the prompt
        response = model.generate_content(prompt_sent)
        response_text = response.text.strip() if response and hasattr(response, "text") else ""
        
        # If no valid response, log chunk id for retry and continue
        if not response_text:
            print(f"No response for chunk {chunk_id}. Logging for retry.")
            new_retry_log.append(chunk_id)
            continue
        
        # Build response data
        output_data = {
            "chunk_id": chunk_id,
            "profile_name": chunk.get("profile_name"),
            "segment": chunk.get("segment"),
            "chunk_text": chunk.get("text"),
            "prompt_sent": prompt_sent,
            "response": response_text
        }
        
        # Save the response as JSON file
        with open(response_file, "w", encoding="utf-8") as outfile:
            json.dump(output_data, outfile, indent=4)
        print(f"Saved response for chunk {chunk_id}.")

        # Add a delay to avoid hitting rate limits
        time.sleep(3)
        
    except Exception as e:
        # Log the chunk id if an exception occurs and print the error
        print(f"Error processing chunk {chunk_id}: {e}")
        new_retry_log.append(chunk_id)
        continue

# Merge with previous retry log entries (ensuring no duplicates)
all_retry = list(set(retry_log + new_retry_log))

# Save the retry log
with open(log_file, "w", encoding="utf-8") as log_out:
    json.dump(all_retry, log_out, indent=4)

print(f"\nProcessing complete. {len(all_retry)} chunks need to be retried. See log: {log_file}")
# Out:
# Processing chunk 0d572b5c29aa2225e7d88ac039ef2132 ...
# Saved response for chunk 0d572b5c29aa2225e7d88ac039ef2132.
# Processing chunk 5b70211aaef28cb176b913a41060be3a ...
# Saved response for chunk 5b70211aaef28cb176b913a41060be3a.
# Processing chunk baf603122069ef036efe473e35c13c06 ...
# Saved response for chunk baf603122069ef036efe473e35c13c06.
# Processing chunk 7a14d64cdd63b849c981afab119f45fc ...
# Saved response for chunk 7a14d64cdd63b849c981afab119f45fc.
# Processing chunk e5d4a604a0d775c08b18765eb39737db ...
# Saved response for chunk e5d4a604a0d775c08b18765eb39737db.
# Processing chunk 5a81a5afab0114d6f383c080dd22759b ...
# Saved response for chunk 5a81a5afab0114d6f383c080dd22759b.
# Processing chunk 7e379e8d40278c7a8954be5e55f4cdaa ...
# Saved response for chunk 7e379e8d40278c7a8954be5e55f4cdaa.
# Processing chunk 790c5cc055a98fb1ab112a8a6f959259 ...
# Saved response for chunk 790c5cc055a98fb1ab112a8a6f959259.
# Processing chunk 10c71492031a53919eddac141c451d38 ...
# Saved response for chunk 10c71492031a53919eddac141c451d38.
# Processing chunk a229af912194f04eefb0f6601109cf07 ...
# Saved response for chunk a229af912194f04eefb0f6601109cf07.
#
# Processing complete. 0 chunks need to be retried. See log: gemini_responses\retry_log.json

# %% [markdown]
# # Step 6 : using RE to extraxt data from llm response

# %%
import json
import os
import re
import time

# -------------------------------
# Define folders
# -------------------------------
gemini_folder = "gemini_responses"
extracted_folder = "llm extracted triplets"
entity_folder = "entity_relation_entity"

os.makedirs(gemini_folder, exist_ok=True)
os.makedirs(extracted_folder, exist_ok=True)
os.makedirs(entity_folder, exist_ok=True)

# -------------------------------
# Define regex patterns for extraction from Gemini responses
# -------------------------------
# Pattern for entity triplets: ("entity"<|>entity_name<|>"entity_type"<|>"entity_description")
entity_pattern = r'\("entity"<\|>(.*?)<\|>"(.*?)"<\|>"(.*?)"\)'
# Pattern for relationship triplets: ("relationship"<|>source_entity<|>target_entity<|>"relationship_description"<\|>"relationship_keywords"<\|>relationship_strength)
relationship_pattern = r'\("relationship"<\|>(.*?)<\|>(.*?)<\|>"(.*?)"<\|>"(.*?)"<\|>(\d+)\)'
# Pattern for content keywords: ("content_keywords"<|>keywords)
content_keywords_pattern = r'\("content_keywords"<\|>(.*?)\)'

# -------------------------------
# Part 1: Process each Gemini response file to extract triplets
# -------------------------------
# List all response JSON files in gemini_responses (assumes filenames start with "response_")
response_files = [f for f in os.listdir(gemini_folder) if f.startswith("response_") and f.endswith(".json")]

for rf in response_files:
    response_path = os.path.join(gemini_folder, rf)
    with open(response_path, "r", encoding="utf-8") as infile:
        response_data = json.load(infile)
    
    response_text = response_data.get("response", "")
    
    # Extract matches using regex
    entities = re.findall(entity_pattern, response_text)
    relationships = re.findall(relationship_pattern, response_text)
    # Exclude content_keywords extraction by setting it to an empty list
    content_keywords = []  # re.findall(content_keywords_pattern, response_text)
    
    # Build lists of triplet dictionaries (with type information)
    entity_triplets = [
        {
            "type": "entity",
            "entity_name": match[0].strip().strip('"'),
            "entity_type": match[1].strip().strip('"'),
            "entity_description": match[2].strip().strip('"')
        }
        for match in entities
    ]
    
    relationship_triplets = [
        {
            "type": "relationship",
            "source_entity": match[0].strip().strip('"'),
            "target_entity": match[1].strip().strip('"'),
            "relationship_description": match[2].strip().strip('"'),
            "relationship_keywords": match[3].strip().strip('"'),
            "relationship_strength": int(match[4].strip())
        }
        for match in relationships
    ]
    
    # Do not include content_keywords triplets
    content_keywords_triplet = []  # Removed per requirements
    
    # Merge all triplets
    all_triplets = entity_triplets + relationship_triplets + content_keywords_triplet
    
    # Prepare output data for this response file
    output_data = {
        "chunk_id": response_data.get("chunk_id"),
        "profile_name": response_data.get("profile_name"),
        "segment": response_data.get("segment"),
        "extracted_triplets": all_triplets
    }
    
    # Save the extracted triplets to JSON file in the "llm extracted triplets" folder
    chunk_id = response_data.get("chunk_id")
    extracted_filename = f"extracted_triplets_{chunk_id}.json"
    extracted_path = os.path.join(extracted_folder, extracted_filename)
    with open(extracted_path, "w", encoding="utf-8") as outfile:
        json.dump(output_data, outfile, indent=4)
    
    print(f"Extracted triplets saved in {extracted_path}")
    # Optional: delay between processing files to avoid rate limits
    time.sleep(1)

# -------------------------------
# Part 2: Aggregate all extracted triplets into a uniform "entity relation entity" format
# -------------------------------
# List all JSON files in the extracted_folder that match the naming pattern
extracted_files = [f for f in os.listdir(extracted_folder) if f.startswith("extracted_triplets_") and f.endswith(".json")]

all_results = []  # This will hold results from all files

# Process each extracted file
for filename in extracted_files:
    filepath = os.path.join(extracted_folder, filename)
    with open(filepath, "r", encoding="utf-8") as infile:
        data = json.load(infile)
    
    # Each file contains meta information and a list of extracted triplets under "extracted_triplets"
    extracted = data.get("extracted_triplets", [])
    uniform_triplets = []
    
    for item in extracted:
        ttype = item.get("type", "").lower()
        
        if ttype == "entity":
            # For entity entries, we use the entity name, "is a <entity_type>" as relation, and the description.
            uniform_triplets.append({
                "entity1": item.get("entity_name", "").strip(),
                "relation": f"is a {item.get('entity_type', '').strip()}",
                "entity2": item.get("entity_description", "").strip()
            })
        elif ttype == "relationship":
            # For relationship entries, map the source, relationship description, and target.
            uniform_triplets.append({
                "entity1": item.get("source_entity", "").strip(),
                "relation": item.get("relationship_description", "").strip(),
                "entity2": item.get("target_entity", "").strip()
            })
        # Skip content_keywords entirely
        else:
            continue

    # Create an aggregated result per file with its meta data and uniform triplets
    file_result = {
        "chunk_id": data.get("chunk_id"),
        "profile_name": data.get("profile_name"),
        "segment": data.get("segment"),
        "triplets": uniform_triplets
    }
    all_results.append(file_result)

# Save the aggregated results to one JSON file in the "entity_relation_entity" folder
final_output_file = os.path.join(entity_folder, "all_extracted_triplets.json")
with open(final_output_file, "w", encoding="utf-8") as outfile:
    json.dump(all_results, outfile, indent=4)

print(f"\nAll extracted uniform triplets have been saved in {final_output_file}")
# Out:
# Extracted triplets saved in llm extracted triplets\extracted_triplets_0247c5c4920ff836e11e665a2e1601e2.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_02acd4c823ea7d3ad25bfe9d300ff46b.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_02bc85c31a32aaed8869f961f02e48fd.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_054ecc08a688e1753f65d4ee8f88b576.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_0851d1bf4bb683269277d4dfb31178f6.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_0c2fa176d66101675a99766c5d1fcba5.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_0ccf3d6a7f79a8c6d3a47c774b067790.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_0d572b5c29aa2225e7d88ac039ef2132.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_0d7ac62359950fdbf73dace0ce17dc20.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_10adf654534b52b711d391dc3e17baa9.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_10c71492031a53919eddac141c451d38.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_116b9786d6880a6de0f4ea50b610626b.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_15f64edb712c20af9a8f7a2fac1b5faa.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_20b6cb1eafc4de0249ceed98f8eedb50.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_232a0290bb3fda2246e0a53bde0cf3f5.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_23b5d336926b1392e3c073f8692c385c.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_24f47e6b9c3fd6d4c98987d1c39f3f22.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_2554e33099b561c79b5333513b53308a.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_26dfa8e7c0fd48964c0fc1c451910648.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_28d79477db51af421722bfb0a859abb4.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_2908d1ec416595f8d0909cb13b68f601.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets
json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_a8e38412c7e01accd27af706cc45ec56.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_a90ca0f64a30ceabc5511b9b28d862c8.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_a9d15b93a7526eaa683e5c82800e93e9.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_aad5927454b8d177cec3c5652f4c3843.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_ab25587b3ae7a03c7e2d98958d7651f0.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_aba384c552ee5be6ceee76662e4d0871.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_abf628f1d34e10f755d7bc073de97764.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_ae44b61f65c41f1b3a261d1df980356b.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_aecd9901af491b20a3766fd4dffee804.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_b803096e3d7e821806b7a45ff1d5105f.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_baf603122069ef036efe473e35c13c06.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_bc5c418748b63631fa3ea3dba0b59f98.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_c227cd8c994811c347c79b770afbb42e.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_c30f9d277add85167f84aa82a64f9744.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_c5b4caf0eadd34fe4f129dd9ce8d3b69.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_c5d505ad42b216c902a6f97de0439550.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_cb07ec0f9bd2e53ff38d262f6e4f2c25.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_ce9b8033d2b2c4de4df8630431d7e726.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_ced6a25dc38afd151253d70e6268813b.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_d0f2bd6cb354ffa05fcf76174b132ef4.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_d591b9745ebbd2e88f783f0b55c2255a.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_d90ecc099df1aac9520b644675e264fe.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_da47df2bafd1eb09240899395b8d6d73.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_dc36e23f59f08469175dccba5a967120.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_dc3a84906426ccbd77187374ff9ecd80.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_e19c25188c53f2e0494355e0743cb41e.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_e4df3164ebaf521fa3f07433384a000f.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_e5d4a604a0d775c08b18765eb39737db.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_e6b19346b7f719615955d646c1fb62a6.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_e7946d6d3c365aab47be8745536351e5.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_e80007ba92fb919282b57aca6bc6cfb5.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_e9ffcc9dd5bdf2ea011ae7528b3f8f71.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_ea78400afdb0f9a69a8b9eeb46bac89d.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_eb8793da67702d2b29c0ada374de8148.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_efb294748a04e190c704401c1d9870aa.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_f0af9171d18bf14be8f771d6049cd7e7.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_f11a1bdfeb0c6d41d950f137bc0418d0.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_f27b94e5db81120e58dce9dfa8486447.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_f378a240c96e9d70a15c81c89536e8f4.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_f9533b3d23ad1ef1c5e9151c20e92087.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_f9d074021c0e08da24dd98c71efc654f.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_faae6d15b96b34ed20531149a9b9b6af.json
# Extracted triplets saved in llm extracted triplets\extracted_triplets_fb947b76fe66958cbffe5ff45c782133.json
#
# All extracted uniform triplets have been saved in entity_relation_entity\all_extracted_triplets.json

# %% [markdown]
# ## Step 7 : Mergeing rule based triplets and all_extracted_triplets.json

# %%
import json
import os

# -------------------------------
# Step 7A: Merge LLM and Rule-Based Triplets
# -------------------------------

# Define input file paths
llm_triplets_file = os.path.join("entity_relation_entity", "all_extracted_triplets.json")
rule_based_file = os.path.join("rule based extraction", "rule based triplets.json")

# Define output folder and file for merged data
merged_folder = "merged_triplets"
os.makedirs(merged_folder, exist_ok=True)
merged_output_file = os.path.join(merged_folder, "merged_triplets.json")

# Load LLM-based triplets
with open(llm_triplets_file, "r", encoding="utf-8") as infile:
    llm_triplets = json.load(infile)

# Load rule-based triplets
with open(rule_based_file, "r", encoding="utf-8") as infile:
    rule_based_triplets = json.load(infile)

# Merge the two sets into a dictionary with separate keys for clarity
merged_data = {
    "llm_triplets": llm_triplets,
    "rule_based_triplets": rule_based_triplets
}

# Save the merged output to JSON file
with open(merged_output_file, "w", encoding="utf-8") as outfile:
    json.dump(merged_data, outfile, indent=4)

print(f"Merged triplets have been saved in {merged_output_file}")


# -------------------------------
# Step 7B: Extract and Combine All Triplets into a Final List
# -------------------------------

# Define the merged input file (from previous step) and final output file
final_output_folder = "final_triplets"
os.makedirs(final_output_folder, exist_ok=True)
final_output_file = os.path.join(final_output_folder, "final_entity_relation_triplets.json")

# Load merged triplets file
with open(merged_output_file, "r", encoding="utf-8") as infile:
    merged_data = json.load(infile)

# Extract triplets from both LLM and rule-based outputs
llm_triplets_list = merged_data.get("llm_triplets", [])
rule_based_triplets = merged_data.get("rule_based_triplets", [])

# Depending on how the LLM triplets are stored, they might be a list of files (each with its own metadata).
# Here, we assume each element in llm_triplets_list is a dictionary with a "triplets" key.
extracted_llm = []
for item in llm_triplets_list:
    if "triplets" in item:
        extracted_llm.extend(item["triplets"])
    else:
        extracted_llm.append(item)

# Merge all triplets into one final list
final_triplets = extracted_llm + rule_based_triplets

# Save the final list of triplets in JSON format
with open(final_output_file, "w", encoding="utf-8") as outfile:
    json.dump(final_triplets, outfile, indent=4)

print(f"Final entity-relation-entity triplets saved in {final_output_file}")
# Out:
# Merged triplets have been saved in merged_triplets\merged_triplets.json
# Final entity-relation-entity triplets saved in final_triplets\final_entity_relation_triplets.json

# %% [markdown]
# # Looking for duplicate Pairs of en rl en

# %%
import json
import os

# Define the path to the final triplets file
final_file = os.path.join("final_triplets", "final_entity_relation_triplets.json")

# Load the final triplets
with open(final_file, "r", encoding="utf-8") as infile:
    triplets = json.load(infile)

# Create a dictionary to count occurrences of each triplet key (entity1, relation, entity2)
triplet_counts = {}
for triplet in triplets:
    key = (
        triplet.get("entity1", "").strip(),
        triplet.get("relation", "").strip(),
        triplet.get("entity2", "").strip()
    )
    triplet_counts[key] = triplet_counts.get(key, 0) + 1

# Identify duplicates (i.e. keys with count > 1)
duplicates = {key: count for key, count in triplet_counts.items() if count > 1}

# Compute statistics
total_triplets = len(triplets)
unique_triplets = len(triplet_counts)
duplicate_count = sum(count - 1 for count in triplet_counts.values() if count > 1)

# Print summary statistics and duplicate details
print(f"Total triplets: {total_triplets}")
print(f"Unique triplets: {unique_triplets}")
print(f"Total duplicate occurrences (excluding first instance): {duplicate_count}\n")

if duplicates:
    print("Duplicate triplets (entity1, relation, entity2) and their counts:")
    for key, count in duplicates.items():
        print(f"{key}: {count}")
else:
    print("No duplicate triplets found.")
# Out:
# Total triplets: 2417
# Unique triplets: 2281
# Total duplicate occurrences (excluding first instance): 136
#
# Duplicate triplets (entity1, relation, entity2) and their counts:
# ('Kattankulathur', 'is a geo', 'Kattankulathur is a location where SRMIST is situated.'): 3
# ('Chennai', 'is a geo', 'Chennai is a city in Tamil Nadu, India, where SRMIST is located.'): 4
# ('Tamil Nadu', 'is a geo', 'Tamil Nadu is a state in India, where Chennai and SRMIST are located.'): 3
# ('Ashish Kumar', 'experience description', 'Not Found'): 2
# ('Ashish Kumar', 'studied at', 'Kendriya Vidyalaya'): 2
# ('Shruti Chavhan', 'studied at', "Sadabai Raisoni Women's College"): 2
# ('Shruti Chavhan', 'field of study', 'Information Technology'): 2
# ('Siby Abraham', 'experience description', 'Not Found'): 4
# ('Siby Abraham', 'worked at', "SVKM's Narsee Monjee Institute of Management Studies (NMIMS)"): 2
# ('Siby Abraham', 'field of study', 'Mathematics'): 2
# ('Sidhant Malkar', 'served as', 'Marketing Intern'): 2
# ('Sidhant Malkar', 'certified by', 'HubSpot'): 2
# ('Sidhant Malkar', 'certified by', 'LinkedIn'): 5
# ('Tushar Jain', 'worked at', 'JPMorgan Chase & Co.'): 2
# ('Tushar Jain', 'experience description', 'Not Found'): 2
# ('Tushar Jain', 'worked at', "SVKM's Narsee Monjee Institute of Management Studies (NMIMS)"): 2
# ('Tushar Jain', 'interacted on', 'NMIMS Mumbai Admission Mentorship for free!!! After a successful mentorship year 2024 with >75% admission rate and much admiration from aspirants…'): 2
# ('Tushar Jain', 'certified by', 'CFA Institute'): 2

# %% [markdown]
# # Deleting the duplicate ones

# %%
import json
import os

# Define the path to the final triplets file
final_file = os.path.join("final_triplets", "final_entity_relation_triplets.json")

# Load the final triplets
with open(final_file, "r", encoding="utf-8") as infile:
    triplets = json.load(infile)

# Use a dictionary to keep track of unique triplets based on a key
unique_triplet_dict = {}
for triplet in triplets:
    key = (
        triplet.get("entity1", "").strip(),
        triplet.get("relation", "").strip(),
        triplet.get("entity2", "").strip()
    )
    # Only add the triplet if it hasn't been seen before
    if key not in unique_triplet_dict:
        unique_triplet_dict[key] = triplet

# Convert the unique triplets back to a list
unique_triplets = list(unique_triplet_dict.values())

# Print summary statistics
print(f"Total triplets before deduplication: {len(triplets)}")
print(f"Unique triplets after deduplication: {len(unique_triplets)}")

# Save the deduplicated triplets to a new JSON file
output_file = os.path.join("final_triplets", "final_entity_relation_triplets_dedup.json")
with open(output_file, "w", encoding="utf-8") as outfile:
    json.dump(unique_triplets, outfile, indent=4)

print(f"Deduplicated triplets saved in {output_file}")
# Out:
# Total triplets before deduplication: 2417
# Unique triplets after deduplication: 2281
# Deduplicated triplets saved in final_triplets\final_entity_relation_triplets_dedup.json

# %%
import json
import os

# Define the path to the deduplicated triplets file
dedup_file = os.path.join("final_triplets", "final_entity_relation_triplets_dedup.json")

# Load the deduplicated triplets
with open(dedup_file, "r", encoding="utf-8") as infile:
    triplets = json.load(infile)

# Collect all unique entities from entity1 and entity2
entities = set()
for triplet in triplets:
    entity1 = triplet.get("entity1", "").strip()
    entity2 = triplet.get("entity2", "").strip()
    if entity1:
        entities.add(entity1)
    if entity2:
        entities.add(entity2)

# Sort entities alphabetically (ignoring case)
sorted_entities = sorted(entities, key=lambda s: s.lower())

# Print each entity in alphabetical order
print("Entities in alphabetical order:")
for entity in sorted_entities:
    print(entity)
# Out:
# Entities in alphabetical order:
# "Hey Siri, update my LinkedIn headline from Upcoming SDE Intern @ Flipkart to SDE Intern @ Flipkart !" I have officially started my…
# "Jo dikhta hai, wahi bikta hai" – Visibility is key, and Shark Tank India proves that. Here’s proof: • Paradyes saw a 20x spike in website traffic.…
# "Leadership Lessons from Karate: Beyond the Dojo" In the disciplined world of the traditional karate system, leadership is not just taught—it is…
# "The Future of Cost Auditing is Here! The Ministry of Corporate Affairs (MCA) is encouraging cost auditors to leverage Artificial Intelligence (AI)…
# #BHASHINIRAJYAM Sai Prakash, Lead AI/ML, showcases the voice-based payment system in his native language, #Telugu, at the Co-creation Workshop for…
# #BREAKING | #HindenburgResearch, known for its role in the #Adani and #Nikola sell-offs, has announced its closure, citing reasons in a blog post by…
# #CMA inter / CA inter Urgent requirement Account Manager in Caprihans India Ltd; Location: Nashik JOB SPECIALIZATIONS: Accounting, Taxation…
# #ETEDNXT Pune
# #ETEDNXT Pune is an event where Dr. Shilpa Joshi spoke.
# *Reflecting on an Incredible 2024 at Intellize* As we wrap up an extraordinary year at Intellize, I’m filled with pride and gratitude for the…
# -
# - Awarded for the good performance and active involvement in team tasks. - For taking team initiatives.
# -- and Not Found
# -I was responsible for gathering and assessing data for industry stocks. -I analysed the industry and market trends for changes and investment opportunities.
# -Mentored by the Best: Gained invaluable insights through direct mentorship from the inspiring MD/founder of RajParis, Mr. R. Jeyakumar. -Design and Lead: Conceptualized and drafted 3 architectural drawings, complete with structural design, estimations, and project planning. -Site Knowledge: Worked on 4 construction sites, witnessing and taking part in planning various stages of the building process firsthand.
# 1-month internship
# 1. Improved conversion rate and click rate of social media campaigns by 40% by designing Channel Affinity models for Facebook, Email and Pinterest. The models helped the business target audience most likely to respond to the ad on that platform 2. Optimised the runtime of Model Inferencing workflow by 50% by transforming linear workflow into a DAG using Airflow 3. Built a look alike audience selection model for a retail business that helped the client's marketing unit target… Show more
# 1. Worked in the domain of Product Management. 2. Developed the skills of market research, Problem Ideation and creation of customer journey mapping.
# 1.5k+ Helping Hand
# 1.5k+ Helping Hand |Recruitment Specialist |Social Optimaisation |Business Consultant |PROVIDING OPPORTUNITY FOR FRESHERS & EXPERIENCE. WORK FROM HOME JOB's• and 1.5k+ Helping Hand| Recruitment Specialist |social media Optimisation |Business consultant |PROVIDING OPPORTUNUTY FOR FRESHERS &EXPERIENCE
# 1.Working in the Information Security department under Risk Management . 2. Responsible for Stakeholder and Project Management for the implementation of Vulnerability Management tool and Digital Forensics Assessment. 3. Responsible for the delivery of a project on automating the application security process. 4. Responsible for IS Governance and Compliance. 5. Responsible for implementation of "Cloud Security Posture Management " to enhance Cloud Security in the Bank.
# 10 axle self climbing robot
# 10 CGPI
# 10 𝐂𝐡𝐚𝐭𝐆𝐏𝐓 𝐩𝐫𝐨𝐦𝐩𝐭𝐬 𝐭𝐡𝐚𝐭 𝐰𝐢𝐥𝐥 𝐜𝐡𝐚𝐧𝐠𝐞 𝐲𝐨𝐮𝐫 𝐥𝐢𝐟𝐞 𝐛𝐞𝐟𝐨𝐫𝐞 2025
# 10 𝐂𝐡𝐚𝐭𝐆𝐏𝐓 𝐩𝐫𝐨𝐦𝐩𝐭𝐬 𝐭𝐡𝐚𝐭 𝐰𝐢𝐥𝐥 𝐜𝐡𝐚𝐧𝐠𝐞 𝐲𝐨𝐮𝐫 𝐥𝐢𝐟𝐞 𝐛𝐞𝐟𝐨𝐫𝐞 2025. 1. Use the 80/20 principle to learn…
# 10th standard education from Vashistt Public School.
# 12th
# 12th CBSE- 91%
# 12th refers to the 12th-grade education completed by Sai Arjun Manivannan at Velammal Vidhyashram.
# 12th standard education with Physics, Chemistry, and Mathematics (PCM) from Vashistt Public School.
# 1st prize
# 2 marketers, 1 college, 1 campaign, millions of impressions! This morning, Adhish Zaveri (Shaadi.com) and I went to actually see the hoarding in…
# 2 types of HR: 1. The Process-Driven HR: • Guards policy handbooks • Masters compliance matrices • Sees employees as resources • Lives by…
# 2 types of HR: 1. The Process-Driven HR: • Guards policy handbooks • Masters compliance matrices • Sees employees as resources • Lives by….
# 2024
# 2024 refers to the year in which a successful mentorship program took place.
# 20th Annual Banking Awards
# 2D Platformer Game
# 3 Resume Mistakes You Must Avoid to Land Your Dream Job
# 3 Resume Mistakes You Must Avoid to Land Your Dream Job 🚫 Your resume is your first impression—make it count by steering clear of these common…
# 3 to 8 LPA
# 3 to 8 LPA represents the salary range (3 to 8 Lakhs Per Annum) for a work-from-home opportunity.
# 365 Data Science
# 365 Data Science is an organization that issues certifications in Introduction to Excel and Python for finance.
# 3D FPS Game
# 3rd Rank (82.50%) – , Delhi, Market-go Blockchain quiz
# 3rd Rank (82.50%) – Delhi, Market-go Blockchain quiz
# 47% Gen Z professionals plan to leave their jobs within two years
# 47% Gen Z professionals plan to leave their jobs within two years, while as many prioritize work-life balance when evaluating potential…
# 5+ years of experience in Human Resources Management
# 50+ SDG Conferences
# 6 months internship
# 7.6
# 75%
# 75% likely refers to an admission rate.
# 7th Semester Milestone: 9.8 SGPA
# 8.4
# 8.4 likely refers to a GPA or percentage score related to Ashish Kumar's High School education, though the context is unclear.
# 9.8 SGPA
# 94%
# A 2D platformer game developed by Alexis Ryan using the Unity engine.
# A 3D first-person shooter game developed by Alexis Ryan using the Unreal Engine.
# A 6-hour workshop on Model Deployment that Cheerayu Chowhan is interested in delivering.  Experts are being sought for this workshop.
# A 6-month internship at Ford Motors that Alexis Ryan is currently undertaking.
# A Bachelor of Arts degree obtained by KUM KUM at Government girls PG college fatehpur.
# A Bachelor of Technology (BTech) is an undergraduate engineering degree.
# A Business Development Assistant position with a focus on BIM (Building Information Modeling), advertised as an urgent hiring.
# A candidate who has completed the requirements for the Certified Management Accountant exam.
# A category of books recommended for individuals starting their journey in Computational Fluid Dynamics (CFD) and AI/ML.
# A cause Cheerayu Chowhan is passionate about.
# A certification in An Introduction to Interactive Programming in Python (Part 1) obtained from Coursera.
# A certification in An Introduction to Interactive Programming in Python (Part 2) obtained from Coursera.
# A certification in concreting techniques issued by L&T EduTech.
# A certification in Convolutional Neural Networks obtained from Coursera.
# A certification in data visualization using Power BI, issued by Great Learning.
# A certification in Databricks Certified Generative AI Engineer Associate obtained from Databricks.
# A certification in Databricks Certified Machine Learning Professional obtained from Databricks.
# A certification in Deep Learning Specialization obtained from Coursera.
# A certification in fabrication of beams issued by L&T EduTech.
# A certification in Financial Markets, issued by Elearnmarkets.
# A certification in frontline supervision issued by L&T EduTech.
# A certification in Improving Deep Neural Networks obtained from Coursera.
# A certification in Introduction to Excel, issued by 365 Data Science.
# A certification in Lean Six Sigma methodologies offered by KPMG India.
# A certification in Machine Learning obtained from Coursera.
# A certification in Microsoft Certified: Azure AI Engineer Associate obtained from Microsoft.
# A certification in Microsoft Certified: Azure AI Fundamentals obtained from Microsoft.
# A certification in Neural Networks and Deep Learning obtained from Coursera.
# A certification in Power BI, offered by Simplilearn.
# A certification in pre-stressing techniques issued by L&T EduTech.
# A certification in Python programming for finance, issued by 365 Data Science.
# A certification in quality control (QA-QC) issued by L&T EduTech.
# A certification in R Programming obtained from Coursera.
# A certification in scaffolding techniques issued by L&T EduTech.
# A certification in Sequence Models obtained from Coursera.
# A certification in Structuring Machine Learning Projects obtained from Coursera.
# A certification in The Data Scientist’s Toolbox obtained from Coursera.
# A certification obtained by Shiwani from Coursera.
# A certification obtained by Shiwani from KPMG India.
# A certification obtained by Shiwani from Not Found.
# A certification obtained by Shiwani from Scrum Alliance.
# A certification obtained by Shiwani from The Product Folks.
# A certification obtained by Shiwani from Udemy.
# A certification offered by HubSpot in content marketing.
# A certification offered by HubSpot in Search Engine Optimization.
# A certification offered by KPMG in Lean Six Sigma methodology.
# A certification offered by NavKiran in branding and digital marketing.
# A charitable trust located in India where Sai Arjun Manivannan volunteered.
# A city in India where Lilavati Hospital is located.
# A claim of having helped over 1500 people, likely through recruitment or consultancy services.
# A coding competition in which Shashank Shekhar won 1st prize.
# A collective term referring to the unspecified researchers who developed the caterpillar-sized robot.
# A company event held in Pune where Nikhil Amos Naveen received an award.
# A company looking for Talent Acquisition professionals.
# A company offering multiple permanent work-from-home positions.
# A company that sponsors Team RoverX and provides fastener solutions.
# A company where Mohammed Shuja Tungekar worked as a Human Resources Consultant and Human Resources Executive.
# A company where Mohammed Shuja Tungekar worked as a Human Resources Executive.
# A company where Mohammed Shuja Tungekar worked as a Multi-Property Human Resources Ambassador.
# A company where Mohammed Shuja Tungekar worked as an Assistant Manager Human Resources and later in Human Resources Management.
# A company where Nikhil Amos Naveen works, reflecting on an incredible year.
# A company where Sidhant Malkar previously worked.
# A company where Sidhant Malkar received an incredible opportunity; he expressed gratitude.
# A company where Sidhant Malkar worked for 3.5 years.
# A company whose global team visited India; Sidhant Malkar expressed gratitude for this event.
# A company whose innovation in drone technology is mentioned in relation to saving lives.
# A company whose mentors contributed to an open-source course.
# A competition in which Alexis Ryan and his team participated, creating a virtual autonomous drone.
# A competition in which Nikhil Amos Naveen won the zonal round.
# A conference or symposium where Nikhil Amos Naveen won a Best Paper Award.
# A course built by mentors from various top product-based MNCs, now available as open source.
# A course covering the fundamentals of data analytics.
# A course focusing on data science and analytics, offered as a virtual experience program by BCG.
# A course focusing on inbound marketing strategies and techniques.
# A course introducing the Structured Query Language (SQL) for data management.
# A course on B2B marketing covering both Tech and Non-Tech industries, taught by Sidhant Malkar.
# A course on marketing analytics provided by Meta (formerly Facebook).
# A course providing foundational knowledge in digital marketing.
# A degree program Cheerayu Chowhan is enrolled in (implied).
# A description of Mohammed Shuja Tungekar's responsibilities as a Human Resources Consultant at Pristine InfoSolutions Pvt. Ltd.
# A description of the responsibilities of Mohammed Shuja Tungekar's role at Unistanz Software Private Limited.
# A detailed description of Mohammed Shuja Tungekar's responsibilities in Human Resources Management at ImpactGuru.
# A device allowing effortless device control through tongue movements, enhancing accessibility.
# A discipline in which Siby Abraham contributes to curriculum design and content development.
# A drowsiness detection system developed using Convolutional Neural Networks and Haar Cascades.  It was implemented for employee drowsiness detection.
# A field in which Shashank Shekhar mentored students and delivered a workshop.
# A field in which Shashank Shekhar mentored students.
# A field of software development that Alexis Ryan is enthusiastic about.
# A fitness event or competition, the conclusion of which prompted reflection by Nikhil Amos Naveen.
# A free course in LinkedIn Ads is mentioned.
# A game engine used by Alexis Ryan to develop a 2D platformer game.
# A game engine used by Alexis Ryan to develop a 3D FPS game.
# A general term encompassing assistive technologies, including the hands-free wheelchair mentioned.
# A government college in Fatehpur where KUM KUM obtained a Bachelor of Arts degree.
# A Gradient Boosting Algorithm was used as the prediction model in the 'Apna-Broker' project.
# A hackathon held at JECRC University where Shashank Shekhar served as a judge and mentor.
# A heartfelt thank you to Rotary Club of Vapi Riverside and Rotaract Club of Vapi Riverside for organizing a truly impactful marathon in support of…
# A Heartwarming National Startups Day Moment This National Startups Day became extra special when a random Instagram user sent me a voice note…
# A hospital in Mumbai where Saif Ali Khan received treatment.
# A hotel where Mohammed Shuja Tungekar completed an Industrial Exposure Trainee program.
# A hotel where Mohammed Shuja Tungekar worked as a Multi-Property Human Resources Ambassador.
# A hotel where Mohammed Shuja Tungekar worked as an On job Trainee.
# A job aggregator and resume shortlisting system using a One vs Rest classifier, web scraping, and cosine similarity.  It features a custom Tkinter front-end.
# A job opening for a Data Engineer is mentioned.
# A job position at Galactic Group, focused on business development.
# A job position for a React.js Developer.
# A job title mentioned in a LinkedIn post.
# A leader is one who knows the way, goes the way, and shows the way. The dog leading the horse: it's not about size, but understanding and guiding…
# A leadership role in DevOps, mentioned in a job posting.
# A leadership role specializing in Kubernetes, mentioned in a job posting.
# A leading global MNC in cloud security that organized a roundtable event.
# A LinkedIn certification covering fundamental concepts in recruiting.
# A LinkedIn certification covering the application of generative AI in recruiting and talent acquisition.
# A LinkedIn certification focused on learning the Power BI Desktop software.
# A LinkedIn certification focusing on advanced Excel macro techniques.
# A LinkedIn certification focusing on conducting fair and inclusive interviews.
# A LinkedIn certification focusing on diverse talent acquisition strategies.
# A LinkedIn certification focusing on recruiting veterans.
# A LinkedIn certification focusing on strategies for niche recruiting.
# A LinkedIn certification on collaboration with various stakeholders in the recruiting process.
# A LinkedIn certification on effective talent sourcing strategies.
# A LinkedIn certification on effectively using the LinkedIn Recruiter tool.
# A LinkedIn certification on SEO marketing tools.
# A LinkedIn certification on using Instagram for marketing.
# A LinkedIn certification providing an introduction to the foundations of tech recruiting.
# A LinkedIn certification providing essential training in Google Universal Analytics.
# A LinkedIn certification providing quick tips and best practices for using the platform.
# A LinkedIn certification specializing in technical recruiting.
# A LinkedIn post about Aasmika Das's battle with SMA Type 1.
# A LinkedIn post about an HTML cheatsheet, shared by Dmitry (Dee) Kolpakov.  Alexis Ryan interacted with this post.
# A LinkedIn post about job loss due to company cost-cutting.
# A LinkedIn post about negative experiences with job interviews.
# A LinkedIn post about Saif Ali Khan's discharge from Lilavati Hospital.
# A LinkedIn post about two types of people.
# A LinkedIn post discussing leadership qualities and the importance of treating everyone with respect.
# A LinkedIn post discussing statistics about Gen Z professionals leaving their jobs and prioritizing work-life balance.
# A LinkedIn post discussing two types of HR professionals.
# A LinkedIn post expressing gratitude for basic necessities.
# A LinkedIn post featuring 10 ChatGPT prompts intended to improve one's life.
# A LinkedIn post focusing on common resume mistakes and how to avoid them.
# A LinkedIn post from ImpactGuru recruiting Talent Acquisition professionals.
# A LinkedIn post providing information about remote job websites that offer USD-based salaries.
# A LinkedIn post with an enigmatic message and links to other social media platforms.
# A Major Milestone in India's Defense & Aerospace ✈️ Today, Prime Minister Narendra Modi visited Vadodara to inaugurate the production facility for…
# A management institute where Shiwani pursued an MBA in Business Analytics.
# A markup language; a post about its cheatsheet is referenced.
# A mobility device designed by Honda, enabling steering through user input, with an eye level similar to standing individuals.
# A module on the Art of Leadership completed by Cheerayu Chowhan for senior working professionals.
# A multinational hospitality company where Mohammed Shuja Tungekar served as a Multi-Property Human Resources Ambassador.
# A national FMCG summit attended by Sidhant Malkar.
# A national-level online workshop on the application of AI tools in academic research.
# A new Tata rises! Shri.Noel Tata has been appointed as Chairman of the Tata Trusts. Here is wishing the Tata Group the very best from a grief…
# A person who posted an HTML cheatsheet on LinkedIn.
# A placeholder indicating a missing field of study for a degree obtained by KUM KUM at 'College'.
# A placeholder indicating missing information regarding a degree obtained by KUM KUM at 'College'.
# A platform for coding challenges, as evidenced by the mention of a LeetCode question and challenge.
# A platform where Cheerayu Chowhan has published articles.
# A professional certificate offered by Google in digital marketing and e-commerce, achieved by Alexis Ryan.
# A professional certification earned by Nikhil Amos Naveen.
# A project aimed at detecting hate speech on social media platforms and preventing its spread.  Structured thinking was applied to develop the project.
# A project Cheerayu Chowhan worked on for over 9 years.
# A project done at S.T.E.A.M SCHOOL 2019 in Paris.
# A project implementing secure file storage using hybrid cryptography to address question paper supply chain issues for SRM University.
# A project with an undisclosed description.
# A Proud Win for YES BANK! ✨🏆 We’re delighted to share that YES BANK has won in the ‘Best Technology Bank’ category at IBA’s 20th Annual Banking…
# A racing event where Nikhil Amos Naveen made a debut.
# A rare and life-threatening genetic condition.
# A recruitment event hosted by EY Global Delivery Services (GDS).
# A recurring headline indicating urgent job openings.
# A research paper focused on sustainable cities and electric vehicles.
# A REST API for predicting house prices in the Bangalore region. Deployed the API on Heroku. The API was made in Flask microframework. The model was by Gradient Boosting Algorithm using XGBoost Library.
# A restaurant where Mohammed Shuja Tungekar worked as a Chef.
# A resume is a document used for job applications.
# A role at Apple that Cheerayu Chowhan shared information about, located in Cupertino, CA.
# A role at Zepto that Cheerayu Chowhan shared information about.
# A role Cheerayu Chowhan recently started at Neterwala (implied).
# A role focused on finding and placing candidates in jobs.
# A role focused on React development.
# A role held by Mohammed Shuja Tungekar at Chinese Wok.
# A role held by Mohammed Shuja Tungekar at Country Inn & Suites by Radisson.
# A role held by Mohammed Shuja Tungekar at ImpactGuru.
# A role held by Mohammed Shuja Tungekar at Marriott International, Renaissance Mumbai Convention Centre Hotel, and Marriott Executive Apartments.
# A role held by Mohammed Shuja Tungekar at Pristine InfoSolutions Pvt. Ltd., leading the department.
# A role held by Mohammed Shuja Tungekar at Unistanz Software Private Limited, involving HR Operations.
# A role requiring full-stack development skills using .NET and React.
# A role that an unnamed company is hiring for, within the Data Governance function.
# A school where Shiwani completed her XII and X standard education.
# A sector in which a major milestone was achieved; a production facility was inaugurated.
# A secure file storage system implemented using cutting-edge cryptography, including block-wise data security with a new algorithm and 128-bit keys.  Multithreading was used for efficient encryption and decryption.
# A series of free, community-run, in-person study groups designed to improve the technical proficiency of participants in Machine Learning.  Runs from July to November in India.
# A skill and area of interest for Cheerayu Chowhan.
# A small robot capable of carrying 100 times its weight, developed by scientists (source unspecified).
# A software company where Mohammed Shuja Tungekar worked as a Human Resources Executive.
# A specific version or release of DeepSeek technology that appears to have disrupted the tech ecosystem.
# A startup bootcamp certification conducted by SRM DEI and issued by SRM Innovation and Incubation Centre.
# A student at Centre Of Excellence Analytics & Data Science, NMIMS Mumbai, interested in problem-solving, strategy building, AI/ML/NLP & Data Science, and sustainable development goals.  Also a Valorant esports player.  Has published articles on Medium and contributed to over 50 SDG conferences.
# A system utilizing YOLO and OpenCV technologies for real-time fire and smoke detection.
# A Tableau visualization project analyzing parameters for state development using SDG indicators.
# A team of three people, including Alexis Ryan, that created a virtual autonomous drone for an IEEE competition.
# A team that has partnered with OnlyScrews, with Nikhil Amos Naveen announcing the partnership.
# A team that Nikhil Amos Naveen is associated with, and which appears to be involved in some kind of competition or project.
# A team within ManipalCigna Health Insurance offering an internship opportunity.
# A tool developed by Cheerayu Chowhan at ImpactGuru to reduce sales research time by 32.14%.
# A tool implemented as part of Shiwani's project management responsibilities at YES BANK.
# A tool used by Cheerayu Chowhan during their Software Development Internship at E2logy Software Solutions.
# A training role held by Mohammed Shuja Tungekar at Vivanta by Taj, focusing on the hospitality stream.
# A trek undertaken by Cheerayu Chowhan, described as a journey of personal and professional development.
# A type of train that reminded Sidhant Malkar of his journeys.
# A university where a placement drive was successfully concluded, and Sidhant Malkar is possibly a student.
# A university where Siby Abraham works as a Professor of Data Science.
# A university where the Centre Of Excellence Analytics & Data Science is located.  It's the institution where Cheerayu Chowhan is studying.
# A video game Cheerayu Chowhan plays competitively (esports).
# A virtual autonomous drone created by Alexis Ryan and his team of 3 for an IEEE competition.
# A website mentioned in relation to an HTML cheatsheet post.
# A year-old child from West Bengal battling SMA Type 1.
# Aaruush, SRM University
# Aaruush, SRM University is an organization where Sai Arjun Manivannan volunteered.
# Aasmika Das
# Aasmika Das, a year-old child from West Bengal, is battling SMA Type 1, a rare and life-threatening genetic condition. Her parents are working…
# Aasmika Das, a year-old child from West Bengal, is battling SMA Type 1, a rare and life-threatening genetic condition. Her parents are working….
# Aavishkar 24-25
# Ableton
# Ableton is a prestigious title or award received by Hitansu Patnaik.
# Academic Coach
# Accenture
# Accenture in India
# Accenture is a company where Bala Rakesh joined in November 2024.
# Accenture is a multinational professional services company where Karan Sharma worked as an Associate Software Engineer in India.  Specific projects or achievements are not detailed.
# Accenture is the company where Riddhi S. celebrated a 5-year work anniversary.
# Account Intern
# Account Intern is a role Bala Rakesh held at Sankar Foundation Eye Hospital.
# Account Manager
# Account Manager is a job position at Caprihans India Ltd in Nashik.
# Accounting and Finance
# Achieved 3rd position in a debate on Decentralized financing in international trade at Government Law College, Mumbai.
# Achieved the Google Digital Marketing & E-Commerce Professional Certificate!!
# Actuarial Analytics team
# Adani
# Adani is mentioned in relation to Hindenburg Research's activities.
# Adecco
# Adecco is a company where Greeshma G A held the roles of Team Lead and Lead Consultant.  No details are given about responsibilities for these roles.
# Adhish Zaveri
# Adhish Zaveri is mentioned as someone associated with the Indian School of Business and Shaadi.com. He's also involved in a marketing campaign.
# Aditya Birla Capital
# Aditya Birla Capital is a company where Vaibhavi Ravindra Vaidya worked as a Management Trainee.
# Aditya Rai
# Aditya Rai is mentioned in a post about a LeetCode question solved by Alexis Ryan.
# Admission Mentorship
# Admission Mentorship is a service provided by NMIMS Mumbai.
# Advanced Digital marketing
# Advanced Digital marketing is a degree obtained by Anchal Baheti from Digital nest in Digital Marketing.
# Advising businesses on strategies and operations.
# After 4+ years in yesbank its time to say Farewall and time to reflect on the Incredible Journey I’ve had here. Working alongside with such a…
# After 9+ years of working on Crystal Knows, I'm thrilled to announce... We're finally building the product we dreamed about in 2015. It wasn't…
# Agile Project Management
# Agree?
# Ahmadabad
# Ahmadabad is the location where Cheerayu Chowhan focused their volunteer efforts.
# Ahmedabad University
# Ahmedabad University awarded Cheerayu Chowhan for being the Best Delegate.
# AI
# AI For India 2.0
# AI is mentioned as a topic relevant to an event Greeshma G A participated in.
# AI-Powered Fire & Smoke Detection System
# AI/ML
# AI/ML/NLP & Data Science
# AIR 1
# AIR 1 represents the All India Rank 1, an award received by Bala Rakesh.
# Airflow
# Airflow is a workflow management tool used by Manas Tuteja to optimize the runtime of Model Inferencing workflow.
# Akgni Global Logistic LLP
# Alap Jani
# Alexis Ryan
# Alexis Ryan is a software developer who is currently completing a 6-month internship at Ford Motors.  He is passionate about web and game development and has experience developing 2D and 3D games using Unity and Unreal Engine, respectively. He also participated in an IEEE competition with a team, creating a virtual autonomous drone.
# Alexis Ryan is an individual who actively interacts with posts on LinkedIn, demonstrating engagement in various topics including LeetCode, Google Digital Marketing certificates, open-source projects, and HTML.  They also appear to be starting a new journey at a PGP program.
# Alexis Ryan is an individual who worked at Ford Motor Company as a Junior Engineer.
# Alexis Ryan's current role at Ford Motors.
# Allied Digital Services Limited
# Allied Digital Services Limited is a company where Sidhant Malkar worked as a Marketing Intern.  He conducted competition analysis, created engaging content, automated processes, boosted operational efficiency, and provided strategic insights in cloud technologies.
# Alteryx
# Alteryx Designer Core Certification
# Alteryx Foundational Micro-Credential
# AM - HR Ops & Payroll
# AM - HR Ops & Payroll @ Impact Guru | Human Resources Management | Attendance & Payroll Management | Employee Relations & Engagement | Training & Development and Astute and exceptionally dedicated professional with 5+ years of experience in Human Resources Management. Equipped with a solid commitment to providing high quality support to the management for consistent growth and development of human resources of diverse companies. Demonstrated success in developing and executing training programs to optimize employee capabilities. Skills with Human Resources Management, Training & Development, Recruitment, Attendance & Payroll, Performance Management, HRIS, HRMS, Onboarding & Exit Management, Employee Engagement, Conflict Resolutions, Quick Learner and Multi Tasking.
# AM - HR Ops & Payroll is Mohammed Shuja Tungekar's current role at Impact Guru.
# Amazon
# Amazon Fulfillment
# Amazon Fulfillment is the company where Manas Tuteja completed a six-month internship.
# Amazon Web Services (AWS)
# American Society of Civil Engineers
# American Society of Civil Engineers is an organization where Sai Arjun Manivannan worked as a Research Intern.
# Amit Shah
# Amit Shah is a person who attended an event at the National Centre for Performing Arts in Mumbai.
# AMMA
# AMMA (Amritanandamayi Devi) is a renowned saint mentioned in a post regarding a meeting and advocacy for reserved seats for girls in engineering and MBA colleges.
# An academic achievement earned by Sidhant Malkar at SVKM's Narsee Monjee Institute of Management Studies (NMIMS).
# An ambiguous phrase; it could indicate missing information or a reference to a previous job or role.
# An area of expertise and interest for Cheerayu Chowhan.
# An article about a professional's nomadic life, focusing on experiences in Chennai.
# An assessment conducted as part of Shiwani's responsibilities at YES BANK.
# An augmented reality model of an electrical fuse box was created by Jatin Singhania as part of his internship at EY to help students understand emergency drills.
# An award given by L&T Infotech to Shiwani for good performance and team involvement.
# An award given for high-level commitment and quality of work.
# An award received by Nikhil Amos Naveen for their contributions to people management.
# An award received by Shiwani for academic achievement, description not found.
# An award received by Shiwani, description not found.
# An award received by Sidhant Malkar from his alma mater.
# An educational institution where Cheerayu Chowhan is a student.  It appears to be affiliated with NMIMS Mumbai.
# An educational institution with a Department of Computer Science.
# An event or program where the Wastecovery project was undertaken.
# An event where Nikhil Amos Naveen received an honor or recognition.
# An event where Siby Abraham shared knowledge, indicating participation and professional engagement.
# An exclusive roundtable event organized by Cloudflare.
# An eye hospital where Bala Rakesh works as Jr. Manager F&A and Sr. Accounts assistant.
# An Indian state where Aasmika Das resides.
# An individual who delivered an impactful session on Key Account Management and Account for Sidhant Malkar's students.
# An individual who recognized Nikhil Amos Naveen's efforts at DAIPL Central LSIP.
# An infographics competition organized by SummIT, the technology cell at SBM.
# An institute of technology where Shiwani obtained a BTech in Computer Science.
# An institute where Nikhil Amos Naveen is joining as a student researcher.
# An institution of higher education where KUM KUM studied; the specific college name is not provided, and details about the degree are missing.
# An internship opportunity within ManipalCigna's Actuarial Analytics team.
# An Introduction to Interactive Programming in Python (Part 1)
# An Introduction to Interactive Programming in Python (Part 2)
# An online course and certification offered by DataCamp focusing on Python programming for finance.
# An online learning platform that certified Shiwani in Business analyst and Data Analysis Essentials using Excel.
# An online learning platform that certified Shiwani in Introduction to Cloud Computing and Google Data Analytics.
# An organization offering a Business Development Assistant position, as advertised on LinkedIn.
# An organization that certified Shiwani in Agile Project Management.
# An organization that certified Shiwani in Certified Scrum Product Owner (CSPO).
# An organization that certified Shiwani in Insurjo - Product Management Principles.
# An organization that certified Shiwani in Lean Six Sigma Green Belt Certification.
# An unspecific program, likely a post-graduate program,  that Alexis Ryan started a journey in a week prior to the post.
# An unspecified field of study for Krishnamoorthy S's Bachelor of Engineering degree.
# AN3 TECHNO POWER LIMITED (FuelON)
# Analyst
# Analyst Community event
# Analyst is a role Jatin Singhania held at Logimetrix Techsolutions Pvt. Ltd.  The specific responsibilities are not detailed.
# Anaplan
# Anaplan Certified Model Builder
# Anaplan Developer, Unity, AR/VR Developer, Artificial Intelligence and Not Found
# Anaplan is an organization that issues certifications in Anaplan Model Building.
# Anaplan Level 1 Model Builder
# Anaplan Level 2 Model Builder
# Anchal Baheti
# Anchal Baheti is a volunteer who worked as a fundraiser at Navjeevan Anath Ashram.
# Anchal Baheti is an active LinkedIn user who frequently interacts with posts on various topics, including hiring practices, family experiences, brand marketing, educational achievements, and career advice.
# Anchal Baheti is an individual who pursued education in various fields.
# Anchal Baheti is the individual described in the profile.
# Andhra Pradesh
# Andhra Pradesh is a geographic location mentioned in relation to DeepTech development.
# Andhra Pradesh is a state in India where Bala Rakesh received recognition for academic achievement.
# Andhra University
# Andhra University is an institution where Bala Rakesh obtained a Bachelor of Commerce degree.
# Android Studio
# Ankush
# Ankush is a groom at a Punjabi wedding in Mumbai attended by Devshri Rao.
# Another milestone unlocked! 🎉🚀 I’m thrilled to share that I’ve successfully cleared the AWS Certified Machine Learning Engineer- Associate exam!…
# Another name for AMMA, a renowned saint.
# Apache Airflow
# Apache Airflow is a workflow management tool used by Manas Tuteja to create workflows.
# Apache Spark (TM) SQL for Data Analysts
# Apna-Broker
# App Developer for Claris FileMaker Pro Expert
# Apple
# Apple is a technology company to which Claris belongs.
# application security process
# Applied statistics
# Applied structured thinking concepts to structure our unstructured idea of Griefender, which is aimed at detecting hate speech across social media platforms and further stopping the spread of hate over platforms.
# Apprentice
# Apprentice is a job title held by Greeshma G A at Bosch Rexroth.
# Area of responsibility for Shiwani at YES BANK.
# Area Sales Manager
# Art of Leadership
# Artificial Intelligence
# Artificial Intelligence (AI)
# Artificial Intelligence (AI) is a technology encouraged by the MCA for cost auditors to leverage.
# Artificial Intelligence and machine learning
# Artificial Intelligence and Machine Learning is the field of study for Krishnamoorthy S's MTech degree.
# Artificial Intelligence/Machine Learning, a field of computer science.
# As I bid adieu to Bengaluru, I am filled with nostalgia since this time around I decided to take time out and meet up with all my close relatives and…
# As the FitGames at Curefit comes to a close, I’m reflecting on an experience that really pushed me to give my best, both physically and mentally. It…
# As they say, all good things must come to an end. After nearly three incredible years at Tata Consultancy Services, it is time for me to bid…
# Ashish Kumar
# Ashish Kumar currently has a job, which he pursues alongside CFA Level 2.
# Ashish Kumar interacted with a post about joining Federal Bank.
# Ashish Kumar interacted with a post about joining L&T.
# Ashish Kumar is a CFA Level 2 Candidate, pursuing an MBA in Finance & Operations from LTFS II, and has experience in data analysis, Microsoft Excel, team leading, risk management, and derivative pricing. He is currently pursuing CFA Level 2 alongside his job to enhance his knowledge of global capital markets.
# Ashish Kumar is an individual who has obtained several certifications in data visualization, excel, Python for finance, financial markets, and CFA Level 1.
# Ashish Kumar is an individual who pursued higher education in various fields.
# Ashish Kumar is an individual who recently joined Federal Bank and L&T.
# Asset Management
# Asset Management is mentioned in the context of online learning.
# Assistant Creative Manager
# Assistant Manager Human Resources
# Assistant System Engineer
# Associate Software Engineer
# Associate Software Engineer is a role Karan Sharma held at Accenture.
# Ast. Sales Manager
# At Celebal, we are deeply committed to investing in our people and living by our values. On Nov 29 and 30, Celebal Tech in collaboration with Amity…
# At the beginning of the year, we served ~2.5 M daily queries. Yesterday, we served ~20M in a single day. Slowly but surely, a new consumer habit is…
# Attendance & Payroll Management
# Attendance & Payroll Management is a specific responsibility within Mohammed Shuja Tungekar's current role.
# Au Financers (AU Insurance & Broking Pvt. Ltd.)
# Augmented Reality model of an electrical fuse box
# Autocad
# Autocad is a software Krishnamoorthy S received training in during their internship at C CUBE TECHNOLOGIES.
# Autoliv
# Award for 3rd rank (82.50%) in a Blockchain quiz held at NSUT, Delhi.
# Award for Best Delegate in the Economic and Social Council (ECOSOC) committee focusing on Sustainable Development Goals.
# Award for Best Negotiator in the SIBM Bengaluru Model United Nations conference focusing on UNCTAD.
# Award for high level of commitment and quality of work delivered for quarter ended December’19
# Award from Facebook for Data Science courses.
# Award received by Shashank Shekhar at Code-N-Build Hackathon for his role as judge and mentor.
# Award received by Shashank Shekhar for delivering a workshop.
# Award received by Shashank Shekhar for winning the RTU THAR Code - Castle competition.
# Awarded Shashank Shekhar a scholarship for Data Science courses.
# Awarded the Pre-placement offer(PPO)
# AWS Academy Graduate - AWS Academy Cloud Foundations
# AWS Academy Graduate - AWS Academy Data Analytics
# AWS Academy Graduate - AWS Academy Data Center Technician
# AWS Academy Graduate - AWS Academy Machine Learning Foundations
# b.tech
# B.Tech CSE
# B.Tech in Computer Science and Engineering is Shiwani's undergraduate degree.
# B.Tech program
# B2B marketing classes
# Bachelor of Arts - BA
# Bachelor of Commerce - BCom
# Bachelor of Commerce - BCom is an undergraduate degree obtained by Bala Rakesh from Andhra University in the field of Business/Commerce, General.
# Bachelor of Commerce degree
# Bachelor of Engineering (BE) is an undergraduate degree obtained by Krishnamoorthy S from K.S.Rangasamy College of Technology in an unspecified field (7.6).
# Bachelor of Engineering - BE
# Bachelor of Science
# Bachelor of Science - BS
# Bachelor of Science - BS is a degree pursued by Shruti Chavhan in Information Technology.
# Bachelor of Science in Hospitality Studies - B.Sc in H.S
# Bachelor of Science in Hospitality Studies - B.Sc in H.S is the degree obtained by Mohammed Shuja Tungekar from the University of Mumbai.
# Bachelor of Technology (BTech) is an undergraduate degree obtained by Manas Tuteja from SRM University in Computer Science & Engineering.
# Bachelor of Technology (BTech) is an undergraduate degree obtained by Rohan Sahay from Techno India University.
# Bachelor of Technology (BTech) is an undergraduate engineering degree obtained by Ashish Kumar.
# Bachelor of Technology (BTech) is an undergraduate engineering degree obtained by Nikhil Amos Naveen from SRMIST.
# Bachelor of Technology (BTech) is an undergraduate engineering degree pursued by Sai Arjun Manivannan at SRMIST in Civil Engineering.
# Bachelor of Technology - BTech
# Bachelor of Technology - BTech is an undergraduate degree obtained by Sidhant Malkar from KJ Somaiya College of Engineering, Vidyavihar.
# Bachelor of Technology degree obtained from National Institute of Technology Hamirpur.
# Bachelor's degree
# Bachelor's degree is a degree pursued by Shruti Chavhan in Information Technology.
# Back in 2021, I embarked on my journey in the data space, and it has been an incredible experience ever since. Over the past few years, this field…
# BAF
# Bajaj Allianz Life
# Bajaj Allianz Life is a company where Riddhi S. worked as an Intern.
# Bala Rakesh
# Bala Rakesh is a CMA finalist, Jr. Manager F&A, and Bcom graduate pursuing CMA Final.  He works at Sankar Foundation eye hospital as both a Jr. Manager F&A and Sr. Accounts assistant.
# Bala Rakesh is an individual who actively interacts on LinkedIn posts, sharing updates about his career, education, and personal life. He also interacts with job postings and company updates.
# Bala Rakesh is an individual who pursued academic studies at Andhra University and the Institute of Cost Accountants of India.
# Bala Rakesh is an individual who worked at Sankar Foundation Eye Hospital in roles such as Junior Manager and Account Intern.  Further details about their accomplishments are not available.
# Bangalore
# Bangalore is a location mentioned in several job postings shared by Greeshma G A, implying that this is where she works or where the jobs are located.
# Bangalore is the geographic region where house prices are predicted in the 'Apna-Broker' project.
# Bangalore is the location of Conga's office where Sai Arjun Manivannan interned.
# Bank of New York Mellon (BNY)
# Bank of New York Mellon is where Sai Arjun Manivannan worked as a Software Development Engineer Intern.
# Bankai Group
# Barbara Bruno
# Barbara Bruno is the instructor of at least two online courses that Greeshma G A has completed, both related to recruiting.
# BCG
# Bcom
# BCom is an undergraduate degree obtained by Anchal Baheti from Osmania University in Business/Commerce, General.
# BE is an undergraduate engineering degree obtained by Vaibhavi Ravindra Vaidya from the University of Mumbai.
# Be the best by learning from the best! Skill up in LinkedIn Ads while benefiting from real-time interaction with our in-house experts. Join our free…
# Being willing to be embarrassed is a superpower. Growth starts at the edge of your comfort zone. ♻️ Repost this to share with pushing through…
# BEML LTD
# BEML LTD is a company where Bala Rakesh started working as an Officer (Finance).
# Bengali
# Bengali is a language spoken by Rohan Sahay.
# Bengaluru
# Bengaluru is a city where Riddhi S. recently spent time and met relatives.
# Bengaluru, India
# Bengaluru, India is the location specified for a DevOps Lead position.
# Bennett University
# Bennett University is an institution that received NAAC A+ accreditation.
# Benvenuto, Lewis!
# Best Delegate ECOSOC-Sustainable development goals
# Best Manager Award
# Best Manager Award is an award.
# Best negotiator SIBM-B MUN UNCTAD
# Best Project Award
# Best Technology Bank
# Better late than never... Hey guys, I am super stoked to announce that Team Double Trouble consisting of me, Darsh Nath Segal and Saloni Baid…
# Bihar
# Bihar is a state in India with some of the lowest income levels.
# Biju Pillai
# Biju Pillai is mentioned in a thank you note by Sai Arjun Manivannan.
# BIM - Business Development Assistant
# Binu Mathew
# Binu Mathew is mentioned in a thank you note by Sai Arjun Manivannan.
# Bioinformatics
# Birla Institute of Technology and Science, Pilani
# Birla Institute of Technology and Science, Pilani is a higher education institution where Manas Tuteja pursued a Master of Technology degree in Machine Learning & Artificial Intelligence.
# Blockchain quiz held at NSUT, Delhi.
# Bollywood actor Saif Ali Khan, who was discharged from Lilavati Hospital in Mumbai.
# Book
# Book refers to the book Rohan Sahay is writing.
# books for beginners in CFD and AI/ML
# Bosch Rexroth
# Bosch Rexroth is a company where Greeshma G A worked as an Apprentice.  No specific details about responsibilities are provided.
# Boston Consulting Group (BCG), likely the provider of the Data Science & Analytics Virtual Experience Program.
# Branding and Digital Marketing
# BRM member
# BRM member is a role Sai Arjun Manivannan held at SRM MUN Society.
# BSc
# BSc is a Bachelor of Science degree obtained by Siby Abraham in Mathematics from St. Dominic's College.
# Budget 2025
# Budget 2025 is a budgetary event, likely referring to a governmental budget announcement.
# Built an end to end MLOPS solution that enables automated development, deployment, near-real-time performance monitoring and consumption of ~500 ML models hosted on Google BigQuery. Worked on transforming relational data, creating workflows on Apache Airflow and enabling parallelism through PySpark. Also conducted analytical research on: 1. Correlation of the prediction drift value to a model's OOT performance. 2. Using Shapley values to show how random samples capture seasonal… Show more
# Business analyst
# Business Analyst
# Business Analyst - Strategy & Planning
# Business Analyst at CEO's Office
# Business Analyst at CEO's Office at Bankai Group specializing in Business Consulting and We at Bankai Group's CEO's office harness data to navigate the business landscape, where I play a pivotal role in crafting data-driven strategies. My expertise in business consulting, fortified by a Lean Six Sigma Green Belt, empowers our team to pinpoint and act on key business insights. Leadership at NMIMS honed my coordination and presentation prowess, culminating in the successful orchestration of placement initiatives for a significant student body. With an MBA in Business Analytics, my ambition is to continually drive innovation and cultivate impactful solutions within the industry.
# Business Analyst is the position Rohan Sahay holds at Navikenz.
# Business analytics
# Business Analytics
# Business analytics is the field of study for Anchal Baheti's MBA.
# Business analytics is the field of study for Rohan Sahay's MBA.
# Business Analytics is the field of study for Vaibhavi Ravindra Vaidya's MBA.
# Business Analytics is the specialization of Shiwani's MBA.
# Business Consultant
# Business Consultanting Risk Service
# Business Development / BIM
# Business Development Assistant
# Business Development Manager
# Business Development Manager was a role held by Vaibhavi Ravindra Vaidya at TGJ INSTITUTE FOR MANAGEMENT & FOREIGN STUDIES.
# Business Development | Ex- Program Management Intern and Not Found
# Business/Commerce, General
# Business/Commerce, General is the field of study for Anchal Baheti's BCom degree.
# Business/Commerce, General is the field of study for Bala Rakesh's Bachelor of Commerce degree from Andhra University.
# Business/Commerce, General is the field of study for Devshri Rao's Master's degree.
# BW-RGB-Colorizer
# BW-RGB-Colorizer is a project with a description that is not found in the provided text.
# C CUBE TECHNOLOGIES
# C CUBE TECHNOLOGIES is a company where Krishnamoorthy S worked as an Industrial Design Intern.
# C#
# C# is a programming language used by Jatin Singhania to connect the HoloLens Simulator and Unity (Unreal Engine) in his internship at EY.
# Cadet Warrant Officer
# Cadet Warrant Officer is a role Krishnamoorthy S held as a volunteer in the NATIONAL CADET CORPS - India.
# Canada
# Working across diverse positions in Middle and Senior level assignments for different departments & multiple campuses of the university.  Handling the complete recruitment process, involved in understanding the mandate, industry mapping and head hunting.  Sourcing and validating right candidates on the basis of the requirement(s) from different departments of the university through making use of effective recruitment and Resourcing strategies such as focused networking, reference… Show more
# working student
# Working with BigQuery
# Working with Staffing Agencies, Recruiters, Headhunters, and Career Coaches
# X Standard
# XGBoost
# XGBoost is the library used for the Gradient Boosting Algorithm in the 'Apna-Broker' project.
# XII Standard (PCM)
# YES BANK
# YES BANK is a company where Shiwani worked as a Manager in the Information Security department.  Responsibilities included stakeholder and project management for vulnerability management and digital forensics, automating application security processes, IS governance and compliance, and implementing Cloud Security Posture Management.
# YES BANK is a financial institution that has won awards for its technology and reported strong financial performance.
# YES BANK is the company where Shiwani works as a Manager.
# YES BANK's Q3FY25 financial performance is highlighted, showing growth across various aspects.
# Yes League of Excellence
# yesbank
# Yesterday was my last day as a working student at EOS GmbH, and what an incredible journey it has been! This was my first professional experience in…
# YOLO
# Zepto
# Zipline
# Zomato
# Zomato is a company where Rohan Sahay recently started working as a Key Account Manager.
# “Thou shalt not make a machine in the likeness of a human mind.” – Frank Herbert, Dune We continue with the Vision for Sustainability series by…
# • Cash Reconcile • Policy Underwriting on E-Portal and Cover Notes • Preparing Business MIS on daily & Monthly Basis • Payouts Calculation • Credit Approvals • Branch Co-Ordinations • Premium Calculation
# • Conducted research, developed growth strategies, and facilitated insights apps for hospital partnership pitches • Leveraged web scraping and Selenium automation to reduce manual effort by 50.72% • Developed LinkedIn Profile Analysis Tool, reducing sales research time by 32.14% • Provided daily competitor campaign updates, boosting market intelligence by 27.86% • Applied regular expressions and XML concepts, resulting in a time reduction of approximately 43.29%
# • Managing corporate relations and engagements • Facilitating the end-to-end placement process
# • Planning and curating deliverables based on student feedback and administration inputs • Conducting remedial classes for Statistics & Probability, Finance and related subjects to promote peer learning
# • Responsible for all aspects of the day-to-day operation of the Managed Service Program and point of contact for Client engaging managers and staffing suppliers • Handling end to end recruitment life cycle - sourcing, screening, and evaluating and reference checks. • Receiving the requirement of client, understanding the job profile, interacting with client for requirement clarification, if any & fulfilling their hiring needs efficiently. • Keeping continuous follow-up with… Show more
# ✨ Celebrating 4 Incredible Years at Celebal Technologies! ✨ Today marks a significant milestone in my professional journey – 4 years at Celebal…
# 𝗛𝗼𝘄 𝗜’𝗱 𝗹𝗲𝗮𝗿𝗻 𝗠𝗮𝗰𝗵𝗶𝗻𝗲 𝗟𝗲𝗮𝗿𝗻𝗶𝗻𝗴 𝗶𝗻 𝟮𝟬𝟮𝟱 (𝗶𝗳 𝗜 𝗰𝗼𝘂𝗹𝗱 𝘀𝘁𝗮𝗿𝘁 𝗼𝘃𝗲𝗿) 𝗬𝗲𝗮𝗵, 𝗜 𝗺𝗮𝗱𝗲…
# 🌟 **New Chapter Begins!** 🌟 Today, I started an exciting journey as Senior Manager - Regional HR. After an incredible experience at Universal AI…
# 🌟 7th Semester Milestone: 9.8 SGPA 🌟 Thrilled to share that my 7th-semester results are in, and I’ve secured an SGPA of 9.80. This journey has been…
# 📊💡 𝗧𝗶𝗺𝗲 𝗩𝗮𝗹𝘂𝗲 𝗼𝗳 𝗠𝗼𝗻𝗲𝘆: ₹𝟭 𝗖𝗿𝗼𝗿𝗲 𝗧𝗼𝗱𝗮𝘆 𝗼𝗿 ₹𝟭 𝗟𝗮𝗸𝗵 𝗘𝘃𝗲𝗿𝘆 𝗠𝗼𝗻𝘁𝗵? 💭 If given a choice, would you take ₹1…
# 📌 A word of caution before we celebrate the tax cuts from Budget 2025... - The tax concession for income up to INR 12 lacs is in form of a rebate…
# 📢 Commencement of One Week Online Short-Term Course (E-STC) on Mobile Device Security We are thrilled to announce the commencement of the One Week…
# 🔥 AI-Powered Fire & Smoke Detection System 🤖 A solution that detects fire and smoke in real-time, combining YOLO and OpenCV technologies for…
# 🚀 Calling All Data & AI Enthusiasts! 🚀 We’re participating in the THD Data Science & Analytics Hackathon ’25 as Team Home Service PROs, tackling a…
# 🚀 Exciting Career Opportunity! I'm pleased to share this amazing job opening at 💢 Galactic Group for the position of Business Development Assistant…
# 🚀 Exciting Opportunity for a React Developer! 🚀 We’re on the lookout for a talented React Developer to join our dynamic team! 🌟 If you have 2-8…
# 🚀 Might be a late post, but the experience is worth sharing! In December 2024, I had the incredible opportunity to participate in a design…
# 🚀 Thrilled to begin my new journey as an Intern at HP ! A heartfelt thank you to Binu Mathew , Satish Bettadapur, Dileep Chandra and Biju Pillai…
# 🚁 𝐂𝐀𝐍 𝐃𝐑𝐎𝐍𝐄𝐒 𝐒𝐀𝐕𝐄 𝐋𝐈𝐕𝐄𝐒? 𝐙𝐈𝐏𝐋𝐈𝐍𝐄’𝐒 𝐈𝐍𝐍𝐎𝐕𝐀𝐓𝐈𝐎𝐍 𝐒𝐀𝐘𝐒 𝐘𝐄𝐒! 𝐃𝐢𝐝 𝐲𝐨𝐮 𝐤𝐧𝐨𝐰 𝐭𝐡𝐚𝐭…
# 🚥 Navigating the Fast Lane: My Debut at the Sepang 1000km Race Weekend From FIA – Fédération Internationale de l'Automobile Indian F4 to…
# 🚨 Calling all Grads! Apple released its Software Engineer - Data Science role. Here's what you need to know: ⚙ Located in Cupertino, CA ⚙…
# 🤖 A caterpillar-sized robot that can carry 100 times its weight? Scientists just did that. Think about it - a tiny machine, smaller than your…

# %% [markdown]
# # Correcting the node annotations

# %%
import json
import os
import re

# Define the path to the deduplicated triplets file
dedup_file = os.path.join("final_triplets", "final_entity_relation_triplets_dedup.json")

# Load the deduplicated triplets
with open(dedup_file, "r", encoding="utf-8") as infile:
    triplets = json.load(infile)

def clean_entity(entity):
    """
    Clean the entity string by removing leading symbols:
    - Remove leading '<|>' if present.
    - Remove starting double quotes.
    - Remove leading bullet points (like '•' or '-').
    """
    entity = entity.strip()
    # Remove leading '<|>' symbols if present
    if entity.startswith("<|>"):
        entity = entity[3:].strip()
    # Remove leading double quotes
    if entity.startswith('"'):
        entity = entity.lstrip('"').strip()
    # Remove any leading bullet points (• or -) and spaces
    entity = re.sub(r'^[•\-]+\s*', '', entity)
    return entity

# Collect all unique entities from entity1 and entity2 fields after cleaning
entities = set()
for triplet in triplets:
    for field in ["entity1", "entity2"]:
        value = triplet.get(field, "").strip()
        if value:
            cleaned = clean_entity(value)
            if cleaned:  # Only add non-empty strings
                entities.add(cleaned)

# Sort entities alphabetically (case-insensitive)
sorted_entities = sorted(entities, key=lambda s: s.lower())

# Print each entity in alphabetical order
print("Entities in alphabetical order:")
for entity in sorted_entities:
    print(entity)
# Out:
# Entities in alphabetical order:
# #BHASHINIRAJYAM Sai Prakash, Lead AI/ML, showcases the voice-based payment system in his native language, #Telugu, at the Co-creation Workshop for…
# #BREAKING | #HindenburgResearch, known for its role in the #Adani and #Nikola sell-offs, has announced its closure, citing reasons in a blog post by…
# #CMA inter / CA inter Urgent requirement Account Manager in Caprihans India Ltd; Location: Nashik JOB SPECIALIZATIONS: Accounting, Taxation…
# #ETEDNXT Pune
# #ETEDNXT Pune is an event where Dr. Shilpa Joshi spoke.
# *Reflecting on an Incredible 2024 at Intellize* As we wrap up an extraordinary year at Intellize, I’m filled with pride and gratitude for the…
# 1-month internship
# 1. Improved conversion rate and click rate of social media campaigns by 40% by designing Channel Affinity models for Facebook, Email and Pinterest. The models helped the business target audience most likely to respond to the ad on that platform 2. Optimised the runtime of Model Inferencing workflow by 50% by transforming linear workflow into a DAG using Airflow 3. Built a look alike audience selection model for a retail business that helped the client's marketing unit target… Show more
# 1. Worked in the domain of Product Management. 2. Developed the skills of market research, Problem Ideation and creation of customer journey mapping.
# 1.5k+ Helping Hand
# 1.5k+ Helping Hand |Recruitment Specialist |Social Optimaisation |Business Consultant |PROVIDING OPPORTUNITY FOR FRESHERS & EXPERIENCE. WORK FROM HOME JOB's• and 1.5k+ Helping Hand| Recruitment Specialist |social media Optimisation |Business consultant |PROVIDING OPPORTUNUTY FOR FRESHERS &EXPERIENCE
# 1.Working in the Information Security department under Risk Management . 2. Responsible for Stakeholder and Project Management for the implementation of Vulnerability Management tool and Digital Forensics Assessment. 3. Responsible for the delivery of a project on automating the application security process. 4. Responsible for IS Governance and Compliance. 5. Responsible for implementation of "Cloud Security Posture Management " to enhance Cloud Security in the Bank.
# 10 axle self climbing robot
# 10 CGPI
# 10 𝐂𝐡𝐚𝐭𝐆𝐏𝐓 𝐩𝐫𝐨𝐦𝐩𝐭𝐬 𝐭𝐡𝐚𝐭 𝐰𝐢𝐥𝐥 𝐜𝐡𝐚𝐧𝐠𝐞 𝐲𝐨𝐮𝐫 𝐥𝐢𝐟𝐞 𝐛𝐞𝐟𝐨𝐫𝐞 2025
# 10 𝐂𝐡𝐚𝐭𝐆𝐏𝐓 𝐩𝐫𝐨𝐦𝐩𝐭𝐬 𝐭𝐡𝐚𝐭 𝐰𝐢𝐥𝐥 𝐜𝐡𝐚𝐧𝐠𝐞 𝐲𝐨𝐮𝐫 𝐥𝐢𝐟𝐞 𝐛𝐞𝐟𝐨𝐫𝐞 2025. 1. Use the 80/20 principle to learn…
# 10th standard education from Vashistt Public School.
# 12th
# 12th CBSE- 91%
# 12th refers to the 12th-grade education completed by Sai Arjun Manivannan at Velammal Vidhyashram.
# 12th standard education with Physics, Chemistry, and Mathematics (PCM) from Vashistt Public School.
# 1st prize
# 2 marketers, 1 college, 1 campaign, millions of impressions! This morning, Adhish Zaveri (Shaadi.com) and I went to actually see the hoarding in…
# 2 types of HR: 1. The Process-Driven HR: • Guards policy handbooks • Masters compliance matrices • Sees employees as resources • Lives by…
# 2 types of HR: 1. The Process-Driven HR: • Guards policy handbooks • Masters compliance matrices • Sees employees as resources • Lives by….
# 2024
# 2024 refers to the year in which a successful mentorship program took place.
# 20th Annual Banking Awards
# 2D Platformer Game
# 3 Resume Mistakes You Must Avoid to Land Your Dream Job
# 3 Resume Mistakes You Must Avoid to Land Your Dream Job 🚫 Your resume is your first impression—make it count by steering clear of these common…
# 3 to 8 LPA
# 3 to 8 LPA represents the salary range (3 to 8 Lakhs Per Annum) for a work-from-home opportunity.
# 365 Data Science
# 365 Data Science is an organization that issues certifications in Introduction to Excel and Python for finance.
# 3D FPS Game
# 3rd Rank (82.50%) – , Delhi, Market-go Blockchain quiz
# 3rd Rank (82.50%) – Delhi, Market-go Blockchain quiz
# 47% Gen Z professionals plan to leave their jobs within two years
# 47% Gen Z professionals plan to leave their jobs within two years, while as many prioritize work-life balance when evaluating potential…
# 5+ years of experience in Human Resources Management
# 50+ SDG Conferences
# 6 months internship
# 7.6
# 75%
# 75% likely refers to an admission rate.
# 7th Semester Milestone: 9.8 SGPA
# 8.4
# 8.4 likely refers to a GPA or percentage score related to Ashish Kumar's High School education, though the context is unclear.
# 9.8 SGPA
# 94%
# A 2D platformer game developed by Alexis Ryan using the Unity engine.
# A 3D first-person shooter game developed by Alexis Ryan using the Unreal Engine.
# A 6-hour workshop on Model Deployment that Cheerayu Chowhan is interested in delivering.  Experts are being sought for this workshop.
# A 6-month internship at Ford Motors that Alexis Ryan is currently undertaking.
# A Bachelor of Arts degree obtained by KUM KUM at Government girls PG college fatehpur.
# A Bachelor of Technology (BTech) is an undergraduate engineering degree.
# A Business Development Assistant position with a focus on BIM (Building Information Modeling), advertised as an urgent hiring.
# A candidate who has completed the requirements for the Certified Management Accountant exam.
# A category of books recommended for individuals starting their journey in Computational Fluid Dynamics (CFD) and AI/ML.
# A cause Cheerayu Chowhan is passionate about.
# A certification in An Introduction to Interactive Programming in Python (Part 1) obtained from Coursera.
# A certification in An Introduction to Interactive Programming in Python (Part 2) obtained from Coursera.
# A certification in concreting techniques issued by L&T EduTech.
# A certification in Convolutional Neural Networks obtained from Coursera.
# A certification in data visualization using Power BI, issued by Great Learning.
# A certification in Databricks Certified Generative AI Engineer Associate obtained from Databricks.
# A certification in Databricks Certified Machine Learning Professional obtained from Databricks.
# A certification in Deep Learning Specialization obtained from Coursera.
# A certification in fabrication of beams issued by L&T EduTech.
# A certification in Financial Markets, issued by Elearnmarkets.
# A certification in frontline supervision issued by L&T EduTech.
# A certification in Improving Deep Neural Networks obtained from Coursera.
# A certification in Introduction to Excel, issued by 365 Data Science.
# A certification in Lean Six Sigma methodologies offered by KPMG India.
# A certification in Machine Learning obtained from Coursera.
# A certification in Microsoft Certified: Azure AI Engineer Associate obtained from Microsoft.
# A certification in Microsoft Certified: Azure AI Fundamentals obtained from Microsoft.
# A certification in Neural Networks and Deep Learning obtained from Coursera.
# A certification in Power BI, offered by Simplilearn.
# A certification in pre-stressing techniques issued by L&T EduTech.
# A certification in Python programming for finance, issued by 365 Data Science.
# A certification in quality control (QA-QC) issued by L&T EduTech.
# A certification in R Programming obtained from Coursera.
# A certification in scaffolding techniques issued by L&T EduTech.
# A certification in Sequence Models obtained from Coursera.
# A certification in Structuring Machine Learning Projects obtained from Coursera.
# A certification in The Data Scientist’s Toolbox obtained from Coursera.
# A certification obtained by Shiwani from Coursera.
# A certification obtained by Shiwani from KPMG India.
# A certification obtained by Shiwani from Not Found.
# A certification obtained by Shiwani from Scrum Alliance.
# A certification obtained by Shiwani from The Product Folks.
# A certification obtained by Shiwani from Udemy.
# A certification offered by HubSpot in content marketing.
# A certification offered by HubSpot in Search Engine Optimization.
# A certification offered by KPMG in Lean Six Sigma methodology.
# A certification offered by NavKiran in branding and digital marketing.
# A charitable trust located in India where Sai Arjun Manivannan volunteered.
# A city in India where Lilavati Hospital is located.
# A claim of having helped over 1500 people, likely through recruitment or consultancy services.
# A coding competition in which Shashank Shekhar won 1st prize.
# A collective term referring to the unspecified researchers who developed the caterpillar-sized robot.
# A company event held in Pune where Nikhil Amos Naveen received an award.
# A company looking for Talent Acquisition professionals.
# A company offering multiple permanent work-from-home positions.
# A company that sponsors Team RoverX and provides fastener solutions.
# A company where Mohammed Shuja Tungekar worked as a Human Resources Consultant and Human Resources Executive.
# A company where Mohammed Shuja Tungekar worked as a Human Resources Executive.
# A company where Mohammed Shuja Tungekar worked as a Multi-Property Human Resources Ambassador.
# A company where Mohammed Shuja Tungekar worked as an Assistant Manager Human Resources and later in Human Resources Management.
# A company where Nikhil Amos Naveen works, reflecting on an incredible year.
# A company where Sidhant Malkar previously worked.
# A company where Sidhant Malkar received an incredible opportunity; he expressed gratitude.
# A company where Sidhant Malkar worked for 3.5 years.
# A company whose global team visited India; Sidhant Malkar expressed gratitude for this event.
# A company whose innovation in drone technology is mentioned in relation to saving lives.
# A company whose mentors contributed to an open-source course.
# A competition in which Alexis Ryan and his team participated, creating a virtual autonomous drone.
# A competition in which Nikhil Amos Naveen won the zonal round.
# A conference or symposium where Nikhil Amos Naveen won a Best Paper Award.
# A course built by mentors from various top product-based MNCs, now available as open source.
# A course covering the fundamentals of data analytics.
# A course focusing on data science and analytics, offered as a virtual experience program by BCG.
# A course focusing on inbound marketing strategies and techniques.
# A course introducing the Structured Query Language (SQL) for data management.
# A course on B2B marketing covering both Tech and Non-Tech industries, taught by Sidhant Malkar.
# A course on marketing analytics provided by Meta (formerly Facebook).
# A course providing foundational knowledge in digital marketing.
# A degree program Cheerayu Chowhan is enrolled in (implied).
# A description of Mohammed Shuja Tungekar's responsibilities as a Human Resources Consultant at Pristine InfoSolutions Pvt. Ltd.
# A description of the responsibilities of Mohammed Shuja Tungekar's role at Unistanz Software Private Limited.
# A detailed description of Mohammed Shuja Tungekar's responsibilities in Human Resources Management at ImpactGuru.
# A device allowing effortless device control through tongue movements, enhancing accessibility.
# A discipline in which Siby Abraham contributes to curriculum design and content development.
# A drowsiness detection system developed using Convolutional Neural Networks and Haar Cascades.  It was implemented for employee drowsiness detection.
# A field in which Shashank Shekhar mentored students and delivered a workshop.
# A field in which Shashank Shekhar mentored students.
# A field of software development that Alexis Ryan is enthusiastic about.
# A fitness event or competition, the conclusion of which prompted reflection by Nikhil Amos Naveen.
# A free course in LinkedIn Ads is mentioned.
# A game engine used by Alexis Ryan to develop a 2D platformer game.
# A game engine used by Alexis Ryan to develop a 3D FPS game.
# A general term encompassing assistive technologies, including the hands-free wheelchair mentioned.
# A government college in Fatehpur where KUM KUM obtained a Bachelor of Arts degree.
# A Gradient Boosting Algorithm was used as the prediction model in the 'Apna-Broker' project.
# A hackathon held at JECRC University where Shashank Shekhar served as a judge and mentor.
# A heartfelt thank you to Rotary Club of Vapi Riverside and Rotaract Club of Vapi Riverside for organizing a truly impactful marathon in support of…
# A Heartwarming National Startups Day Moment This National Startups Day became extra special when a random Instagram user sent me a voice note…
# A hospital in Mumbai where Saif Ali Khan received treatment.
# A hotel where Mohammed Shuja Tungekar completed an Industrial Exposure Trainee program.
# A hotel where Mohammed Shuja Tungekar worked as a Multi-Property Human Resources Ambassador.
# A hotel where Mohammed Shuja Tungekar worked as an On job Trainee.
# A job aggregator and resume shortlisting system using a One vs Rest classifier, web scraping, and cosine similarity.  It features a custom Tkinter front-end.
# A job opening for a Data Engineer is mentioned.
# A job position at Galactic Group, focused on business development.
# A job position for a React.js Developer.
# A job title mentioned in a LinkedIn post.
# A leader is one who knows the way, goes the way, and shows the way. The dog leading the horse: it's not about size, but understanding and guiding…
# A leadership role in DevOps, mentioned in a job posting.
# A leadership role specializing in Kubernetes, mentioned in a job posting.
# A leading global MNC in cloud security that organized a roundtable event.
# A LinkedIn certification covering fundamental concepts in recruiting.
# A LinkedIn certification covering the application of generative AI in recruiting and talent acquisition.
# A LinkedIn certification focused on learning the Power BI Desktop software.
# A LinkedIn certification focusing on advanced Excel macro techniques.
# A LinkedIn certification focusing on conducting fair and inclusive interviews.
# A LinkedIn certification focusing on diverse talent acquisition strategies.
# A LinkedIn certification focusing on recruiting veterans.
# A LinkedIn certification focusing on strategies for niche recruiting.
# A LinkedIn certification on collaboration with various stakeholders in the recruiting process.
# A LinkedIn certification on effective talent sourcing strategies.
# A LinkedIn certification on effectively using the LinkedIn Recruiter tool.
# A LinkedIn certification on SEO marketing tools.
# A LinkedIn certification on using Instagram for marketing.
# A LinkedIn certification providing an introduction to the foundations of tech recruiting.
# A LinkedIn certification providing essential training in Google Universal Analytics.
# A LinkedIn certification providing quick tips and best practices for using the platform.
# A LinkedIn certification specializing in technical recruiting.
# A LinkedIn post about Aasmika Das's battle with SMA Type 1.
# A LinkedIn post about an HTML cheatsheet, shared by Dmitry (Dee) Kolpakov.  Alexis Ryan interacted with this post.
# A LinkedIn post about job loss due to company cost-cutting.
# A LinkedIn post about negative experiences with job interviews.
# A LinkedIn post about Saif Ali Khan's discharge from Lilavati Hospital.
# A LinkedIn post about two types of people.
# A LinkedIn post discussing leadership qualities and the importance of treating everyone with respect.
# A LinkedIn post discussing statistics about Gen Z professionals leaving their jobs and prioritizing work-life balance.
# A LinkedIn post discussing two types of HR professionals.
# A LinkedIn post expressing gratitude for basic necessities.
# A LinkedIn post featuring 10 ChatGPT prompts intended to improve one's life.
# A LinkedIn post focusing on common resume mistakes and how to avoid them.
# A LinkedIn post from ImpactGuru recruiting Talent Acquisition professionals.
# A LinkedIn post providing information about remote job websites that offer USD-based salaries.
# A LinkedIn post with an enigmatic message and links to other social media platforms.
# A Major Milestone in India's Defense & Aerospace ✈️ Today, Prime Minister Narendra Modi visited Vadodara to inaugurate the production facility for…
# A management institute where Shiwani pursued an MBA in Business Analytics.
# A markup language; a post about its cheatsheet is referenced.
# A mobility device designed by Honda, enabling steering through user input, with an eye level similar to standing individuals.
# A module on the Art of Leadership completed by Cheerayu Chowhan for senior working professionals.
# A multinational hospitality company where Mohammed Shuja Tungekar served as a Multi-Property Human Resources Ambassador.
# A national FMCG summit attended by Sidhant Malkar.
# A national-level online workshop on the application of AI tools in academic research.
# A new Tata rises! Shri.Noel Tata has been appointed as Chairman of the Tata Trusts. Here is wishing the Tata Group the very best from a grief…
# A person who posted an HTML cheatsheet on LinkedIn.
# A placeholder indicating a missing field of study for a degree obtained by KUM KUM at 'College'.
# A placeholder indicating missing information regarding a degree obtained by KUM KUM at 'College'.
# A platform for coding challenges, as evidenced by the mention of a LeetCode question and challenge.
# A platform where Cheerayu Chowhan has published articles.
# A professional certificate offered by Google in digital marketing and e-commerce, achieved by Alexis Ryan.
# A professional certification earned by Nikhil Amos Naveen.
# A project aimed at detecting hate speech on social media platforms and preventing its spread.  Structured thinking was applied to develop the project.
# A project Cheerayu Chowhan worked on for over 9 years.
# A project done at S.T.E.A.M SCHOOL 2019 in Paris.
# A project implementing secure file storage using hybrid cryptography to address question paper supply chain issues for SRM University.
# A project with an undisclosed description.
# A Proud Win for YES BANK! ✨🏆 We’re delighted to share that YES BANK has won in the ‘Best Technology Bank’ category at IBA’s 20th Annual Banking…
# A racing event where Nikhil Amos Naveen made a debut.
# A rare and life-threatening genetic condition.
# A recruitment event hosted by EY Global Delivery Services (GDS).
# A recurring headline indicating urgent job openings.
# A research paper focused on sustainable cities and electric vehicles.
# A REST API for predicting house prices in the Bangalore region. Deployed the API on Heroku. The API was made in Flask microframework. The model was by Gradient Boosting Algorithm using XGBoost Library.
# A restaurant where Mohammed Shuja Tungekar worked as a Chef.
# A resume is a document used for job applications.
# A role at Apple that Cheerayu Chowhan shared information about, located in Cupertino, CA.
# A role at Zepto that Cheerayu Chowhan shared information about.
# A role Cheerayu Chowhan recently started at Neterwala (implied).
# A role focused on finding and placing candidates in jobs.
# A role focused on React development.
# A role held by Mohammed Shuja Tungekar at Chinese Wok.
# A role held by Mohammed Shuja Tungekar at Country Inn & Suites by Radisson.
# A role held by Mohammed Shuja Tungekar at ImpactGuru.
# A role held by Mohammed Shuja Tungekar at Marriott International, Renaissance Mumbai Convention Centre Hotel, and Marriott Executive Apartments.
# A role held by Mohammed Shuja Tungekar at Pristine InfoSolutions Pvt. Ltd., leading the department.
# A role held by Mohammed Shuja Tungekar at Unistanz Software Private Limited, involving HR Operations.
# A role requiring full-stack development skills using .NET and React.
# A role that an unnamed company is hiring for, within the Data Governance function.
# A school where Shiwani completed her XII and X standard education.
# A sector in which a major milestone was achieved; a production facility was inaugurated.
# A secure file storage system implemented using cutting-edge cryptography, including block-wise data security with a new algorithm and 128-bit keys.  Multithreading was used for efficient encryption and decryption.
# A series of free, community-run, in-person study groups designed to improve the technical proficiency of participants in Machine Learning.  Runs from July to November in India.
# A skill and area of interest for Cheerayu Chowhan.
# A small robot capable of carrying 100 times its weight, developed by scientists (source unspecified).
# A software company where Mohammed Shuja Tungekar worked as a Human Resources Executive.
# A specific version or release of DeepSeek technology that appears to have disrupted the tech ecosystem.
# A startup bootcamp certification conducted by SRM DEI and issued by SRM Innovation and Incubation Centre.
# A student at Centre Of Excellence Analytics & Data Science, NMIMS Mumbai, interested in problem-solving, strategy building, AI/ML/NLP & Data Science, and sustainable development goals.  Also a Valorant esports player.  Has published articles on Medium and contributed to over 50 SDG conferences.
# A system utilizing YOLO and OpenCV technologies for real-time fire and smoke detection.
# A Tableau visualization project analyzing parameters for state development using SDG indicators.
# A team of three people, including Alexis Ryan, that created a virtual autonomous drone for an IEEE competition.
# A team that has partnered with OnlyScrews, with Nikhil Amos Naveen announcing the partnership.
# A team that Nikhil Amos Naveen is associated with, and which appears to be involved in some kind of competition or project.
# A team within ManipalCigna Health Insurance offering an internship opportunity.
# A tool developed by Cheerayu Chowhan at ImpactGuru to reduce sales research time by 32.14%.
# A tool implemented as part of Shiwani's project management responsibilities at YES BANK.
# A tool used by Cheerayu Chowhan during their Software Development Internship at E2logy Software Solutions.
# A training role held by Mohammed Shuja Tungekar at Vivanta by Taj, focusing on the hospitality stream.
# A trek undertaken by Cheerayu Chowhan, described as a journey of personal and professional development.
# A type of train that reminded Sidhant Malkar of his journeys.
# A university where a placement drive was successfully concluded, and Sidhant Malkar is possibly a student.
# A university where Siby Abraham works as a Professor of Data Science.
# A university where the Centre Of Excellence Analytics & Data Science is located.  It's the institution where Cheerayu Chowhan is studying.
# A video game Cheerayu Chowhan plays competitively (esports).
# A virtual autonomous drone created by Alexis Ryan and his team of 3 for an IEEE competition.
# A website mentioned in relation to an HTML cheatsheet post.
# A year-old child from West Bengal battling SMA Type 1.
# Aaruush, SRM University
# Aaruush, SRM University is an organization where Sai Arjun Manivannan volunteered.
# Aasmika Das
# Aasmika Das, a year-old child from West Bengal, is battling SMA Type 1, a rare and life-threatening genetic condition. Her parents are working…
# Aasmika Das, a year-old child from West Bengal, is battling SMA Type 1, a rare and life-threatening genetic condition. Her parents are working….
# Aavishkar 24-25
# Ableton
# Ableton is a prestigious title or award received by Hitansu Patnaik.
# Academic Coach
# Accenture
# Accenture in India
# Accenture is a company where Bala Rakesh joined in November 2024.
# Accenture is a multinational professional services company where Karan Sharma worked as an Associate Software Engineer in India.  Specific projects or achievements are not detailed.
# Accenture is the company where Riddhi S. celebrated a 5-year work anniversary.
# Account Intern
# Account Intern is a role Bala Rakesh held at Sankar Foundation Eye Hospital.
# Account Manager
# Account Manager is a job position at Caprihans India Ltd in Nashik.
# Accounting and Finance
# Achieved 3rd position in a debate on Decentralized financing in international trade at Government Law College, Mumbai.
# Achieved the Google Digital Marketing & E-Commerce Professional Certificate!!
# Actuarial Analytics team
# Adani
# Adani is mentioned in relation to Hindenburg Research's activities.
# Adecco
# Adecco is a company where Greeshma G A held the roles of Team Lead and Lead Consultant.  No details are given about responsibilities for these roles.
# Adhish Zaveri
# Adhish Zaveri is mentioned as someone associated with the Indian School of Business and Shaadi.com. He's also involved in a marketing campaign.
# Aditya Birla Capital
# Aditya Birla Capital is a company where Vaibhavi Ravindra Vaidya worked as a Management Trainee.
# Aditya Rai
# Aditya Rai is mentioned in a post about a LeetCode question solved by Alexis Ryan.
# Admission Mentorship
# Admission Mentorship is a service provided by NMIMS Mumbai.
# Advanced Digital marketing
# Advanced Digital marketing is a degree obtained by Anchal Baheti from Digital nest in Digital Marketing.
# Advising businesses on strategies and operations.
# After 4+ years in yesbank its time to say Farewall and time to reflect on the Incredible Journey I’ve had here. Working alongside with such a…
# After 9+ years of working on Crystal Knows, I'm thrilled to announce... We're finally building the product we dreamed about in 2015. It wasn't…
# Agile Project Management
# Agree?
# Ahmadabad
# Ahmadabad is the location where Cheerayu Chowhan focused their volunteer efforts.
# Ahmedabad University
# Ahmedabad University awarded Cheerayu Chowhan for being the Best Delegate.
# AI
# AI For India 2.0
# AI is mentioned as a topic relevant to an event Greeshma G A participated in.
# AI-Powered Fire & Smoke Detection System
# AI/ML
# AI/ML/NLP & Data Science
# AIR 1
# AIR 1 represents the All India Rank 1, an award received by Bala Rakesh.
# Airflow
# Airflow is a workflow management tool used by Manas Tuteja to optimize the runtime of Model Inferencing workflow.
# Akgni Global Logistic LLP
# Alap Jani
# Alexis Ryan
# Alexis Ryan is a software developer who is currently completing a 6-month internship at Ford Motors.  He is passionate about web and game development and has experience developing 2D and 3D games using Unity and Unreal Engine, respectively. He also participated in an IEEE competition with a team, creating a virtual autonomous drone.
# Alexis Ryan is an individual who actively interacts with posts on LinkedIn, demonstrating engagement in various topics including LeetCode, Google Digital Marketing certificates, open-source projects, and HTML.  They also appear to be starting a new journey at a PGP program.
# Alexis Ryan is an individual who worked at Ford Motor Company as a Junior Engineer.
# Alexis Ryan's current role at Ford Motors.
# Allied Digital Services Limited
# Allied Digital Services Limited is a company where Sidhant Malkar worked as a Marketing Intern.  He conducted competition analysis, created engaging content, automated processes, boosted operational efficiency, and provided strategic insights in cloud technologies.
# Alteryx
# Alteryx Designer Core Certification
# Alteryx Foundational Micro-Credential
# AM - HR Ops & Payroll
# AM - HR Ops & Payroll @ Impact Guru | Human Resources Management | Attendance & Payroll Management | Employee Relations & Engagement | Training & Development and Astute and exceptionally dedicated professional with 5+ years of experience in Human Resources Management. Equipped with a solid commitment to providing high quality support to the management for consistent growth and development of human resources of diverse companies. Demonstrated success in developing and executing training programs to optimize employee capabilities. Skills with Human Resources Management, Training & Development, Recruitment, Attendance & Payroll, Performance Management, HRIS, HRMS, Onboarding & Exit Management, Employee Engagement, Conflict Resolutions, Quick Learner and Multi Tasking.
# AM - HR Ops & Payroll is Mohammed Shuja Tungekar's current role at Impact Guru.
# Amazon
# Amazon Fulfillment
# Amazon Fulfillment is the company where Manas Tuteja completed a six-month internship.
# Amazon Web Services (AWS)
# American Society of Civil Engineers
# American Society of Civil Engineers is an organization where Sai Arjun Manivannan worked as a Research Intern.
# Amit Shah
# Amit Shah is a person who attended an event at the National Centre for Performing Arts in Mumbai.
# AMMA
# AMMA (Amritanandamayi Devi) is a renowned saint mentioned in a post regarding a meeting and advocacy for reserved seats for girls in engineering and MBA colleges.
# An academic achievement earned by Sidhant Malkar at SVKM's Narsee Monjee Institute of Management Studies (NMIMS).
# An ambiguous phrase; it could indicate missing information or a reference to a previous job or role.
# An area of expertise and interest for Cheerayu Chowhan.
# An article about a professional's nomadic life, focusing on experiences in Chennai.
# An assessment conducted as part of Shiwani's responsibilities at YES BANK.
# An augmented reality model of an electrical fuse box was created by Jatin Singhania as part of his internship at EY to help students understand emergency drills.
# An award given by L&T Infotech to Shiwani for good performance and team involvement.
# An award given for high-level commitment and quality of work.
# An award received by Nikhil Amos Naveen for their contributions to people management.
# An award received by Shiwani for academic achievement, description not found.
# An award received by Shiwani, description not found.
# An award received by Sidhant Malkar from his alma mater.
# An educational institution where Cheerayu Chowhan is a student.  It appears to be affiliated with NMIMS Mumbai.
# An educational institution with a Department of Computer Science.
# An event or program where the Wastecovery project was undertaken.
# An event where Nikhil Amos Naveen received an honor or recognition.
# An event where Siby Abraham shared knowledge, indicating participation and professional engagement.
# An exclusive roundtable event organized by Cloudflare.
# An eye hospital where Bala Rakesh works as Jr. Manager F&A and Sr. Accounts assistant.
# An Indian state where Aasmika Das resides.
# An individual who delivered an impactful session on Key Account Management and Account for Sidhant Malkar's students.
# An individual who recognized Nikhil Amos Naveen's efforts at DAIPL Central LSIP.
# An infographics competition organized by SummIT, the technology cell at SBM.
# An institute of technology where Shiwani obtained a BTech in Computer Science.
# An institute where Nikhil Amos Naveen is joining as a student researcher.
# An institution of higher education where KUM KUM studied; the specific college name is not provided, and details about the degree are missing.
# An internship opportunity within ManipalCigna's Actuarial Analytics team.
# An Introduction to Interactive Programming in Python (Part 1)
# An Introduction to Interactive Programming in Python (Part 2)
# An online course and certification offered by DataCamp focusing on Python programming for finance.
# An online learning platform that certified Shiwani in Business analyst and Data Analysis Essentials using Excel.
# An online learning platform that certified Shiwani in Introduction to Cloud Computing and Google Data Analytics.
# An organization offering a Business Development Assistant position, as advertised on LinkedIn.
# An organization that certified Shiwani in Agile Project Management.
# An organization that certified Shiwani in Certified Scrum Product Owner (CSPO).
# An organization that certified Shiwani in Insurjo - Product Management Principles.
# An organization that certified Shiwani in Lean Six Sigma Green Belt Certification.
# An unspecific program, likely a post-graduate program,  that Alexis Ryan started a journey in a week prior to the post.
# An unspecified field of study for Krishnamoorthy S's Bachelor of Engineering degree.
# AN3 TECHNO POWER LIMITED (FuelON)
# Analyst
# Analyst Community event
# Analyst is a role Jatin Singhania held at Logimetrix Techsolutions Pvt. Ltd.  The specific responsibilities are not detailed.
# Anaplan
# Anaplan Certified Model Builder
# Anaplan Developer, Unity, AR/VR Developer, Artificial Intelligence and Not Found
# Anaplan is an organization that issues certifications in Anaplan Model Building.
# Anaplan Level 1 Model Builder
# Anaplan Level 2 Model Builder
# Anchal Baheti
# Anchal Baheti is a volunteer who worked as a fundraiser at Navjeevan Anath Ashram.
# Anchal Baheti is an active LinkedIn user who frequently interacts with posts on various topics, including hiring practices, family experiences, brand marketing, educational achievements, and career advice.
# Anchal Baheti is an individual who pursued education in various fields.
# Anchal Baheti is the individual described in the profile.
# and Not Found
# Andhra Pradesh
# Andhra Pradesh is a geographic location mentioned in relation to DeepTech development.
# Andhra Pradesh is a state in India where Bala Rakesh received recognition for academic achievement.
# Andhra University
# Andhra University is an institution where Bala Rakesh obtained a Bachelor of Commerce degree.
# Android Studio
# Ankush
# Ankush is a groom at a Punjabi wedding in Mumbai attended by Devshri Rao.
# Another milestone unlocked! 🎉🚀 I’m thrilled to share that I’ve successfully cleared the AWS Certified Machine Learning Engineer- Associate exam!…
# Another name for AMMA, a renowned saint.
# Apache Airflow
# Apache Airflow is a workflow management tool used by Manas Tuteja to create workflows.
# Apache Spark (TM) SQL for Data Analysts
# Apna-Broker
# App Developer for Claris FileMaker Pro Expert
# Apple
# Apple is a technology company to which Claris belongs.
# application security process
# Applied statistics
# Applied structured thinking concepts to structure our unstructured idea of Griefender, which is aimed at detecting hate speech across social media platforms and further stopping the spread of hate over platforms.
# Apprentice
# Apprentice is a job title held by Greeshma G A at Bosch Rexroth.
# Area of responsibility for Shiwani at YES BANK.
# Area Sales Manager
# Art of Leadership
# Artificial Intelligence
# Artificial Intelligence (AI)
# Artificial Intelligence (AI) is a technology encouraged by the MCA for cost auditors to leverage.
# Artificial Intelligence and machine learning
# Artificial Intelligence and Machine Learning is the field of study for Krishnamoorthy S's MTech degree.
# Artificial Intelligence/Machine Learning, a field of computer science.
# As I bid adieu to Bengaluru, I am filled with nostalgia since this time around I decided to take time out and meet up with all my close relatives and…
# As the FitGames at Curefit comes to a close, I’m reflecting on an experience that really pushed me to give my best, both physically and mentally. It…
# As they say, all good things must come to an end. After nearly three incredible years at Tata Consultancy Services, it is time for me to bid…
# Ashish Kumar
# Ashish Kumar currently has a job, which he pursues alongside CFA Level 2.
# Ashish Kumar interacted with a post about joining Federal Bank.
# Ashish Kumar interacted with a post about joining L&T.
# Ashish Kumar is a CFA Level 2 Candidate, pursuing an MBA in Finance & Operations from LTFS II, and has experience in data analysis, Microsoft Excel, team leading, risk management, and derivative pricing. He is currently pursuing CFA Level 2 alongside his job to enhance his knowledge of global capital markets.
# Ashish Kumar is an individual who has obtained several certifications in data visualization, excel, Python for finance, financial markets, and CFA Level 1.
# Ashish Kumar is an individual who pursued higher education in various fields.
# Ashish Kumar is an individual who recently joined Federal Bank and L&T.
# Asset Management
# Asset Management is mentioned in the context of online learning.
# Assistant Creative Manager
# Assistant Manager Human Resources
# Assistant System Engineer
# Associate Software Engineer
# Associate Software Engineer is a role Karan Sharma held at Accenture.
# Ast. Sales Manager
# At Celebal, we are deeply committed to investing in our people and living by our values. On Nov 29 and 30, Celebal Tech in collaboration with Amity…
# At the beginning of the year, we served ~2.5 M daily queries. Yesterday, we served ~20M in a single day. Slowly but surely, a new consumer habit is…
# Attendance & Payroll Management
# Attendance & Payroll Management is a specific responsibility within Mohammed Shuja Tungekar's current role.
# Au Financers (AU Insurance & Broking Pvt. Ltd.)
# Augmented Reality model of an electrical fuse box
# Autocad
# Autocad is a software Krishnamoorthy S received training in during their internship at C CUBE TECHNOLOGIES.
# Autoliv
# Award for 3rd rank (82.50%) in a Blockchain quiz held at NSUT, Delhi.
# Award for Best Delegate in the Economic and Social Council (ECOSOC) committee focusing on Sustainable Development Goals.
# Award for Best Negotiator in the SIBM Bengaluru Model United Nations conference focusing on UNCTAD.
# Award for high level of commitment and quality of work delivered for quarter ended December’19
# Award from Facebook for Data Science courses.
# Award received by Shashank Shekhar at Code-N-Build Hackathon for his role as judge and mentor.
# Award received by Shashank Shekhar for delivering a workshop.
# Award received by Shashank Shekhar for winning the RTU THAR Code - Castle competition.
# Awarded for the good performance and active involvement in team tasks. - For taking team initiatives.
# Awarded Shashank Shekhar a scholarship for Data Science courses.
# Awarded the Pre-placement offer(PPO)
# AWS Academy Graduate - AWS Academy Cloud Foundations
# AWS Academy Graduate - AWS Academy Data Analytics
# AWS Academy Graduate - AWS Academy Data Center Technician
# AWS Academy Graduate - AWS Academy Machine Learning Foundations
# b.tech
# B.Tech CSE
# B.Tech in Computer Science and Engineering is Shiwani's undergraduate degree.
# B.Tech program
# B2B marketing classes
# Bachelor of Arts - BA
# Bachelor of Commerce - BCom
# Bachelor of Commerce - BCom is an undergraduate degree obtained by Bala Rakesh from Andhra University in the field of Business/Commerce, General.
# Bachelor of Commerce degree
# Bachelor of Engineering (BE) is an undergraduate degree obtained by Krishnamoorthy S from K.S.Rangasamy College of Technology in an unspecified field (7.6).
# Bachelor of Engineering - BE
# Bachelor of Science
# Bachelor of Science - BS
# Bachelor of Science - BS is a degree pursued by Shruti Chavhan in Information Technology.
# Bachelor of Science in Hospitality Studies - B.Sc in H.S
# Bachelor of Science in Hospitality Studies - B.Sc in H.S is the degree obtained by Mohammed Shuja Tungekar from the University of Mumbai.
# Bachelor of Technology (BTech) is an undergraduate degree obtained by Manas Tuteja from SRM University in Computer Science & Engineering.
# Bachelor of Technology (BTech) is an undergraduate degree obtained by Rohan Sahay from Techno India University.
# Bachelor of Technology (BTech) is an undergraduate engineering degree obtained by Ashish Kumar.
# Bachelor of Technology (BTech) is an undergraduate engineering degree obtained by Nikhil Amos Naveen from SRMIST.
# Bachelor of Technology (BTech) is an undergraduate engineering degree pursued by Sai Arjun Manivannan at SRMIST in Civil Engineering.
# Bachelor of Technology - BTech
# Bachelor of Technology - BTech is an undergraduate degree obtained by Sidhant Malkar from KJ Somaiya College of Engineering, Vidyavihar.
# Bachelor of Technology degree obtained from National Institute of Technology Hamirpur.
# Bachelor's degree
# Bachelor's degree is a degree pursued by Shruti Chavhan in Information Technology.
# Back in 2021, I embarked on my journey in the data space, and it has been an incredible experience ever since. Over the past few years, this field…
# BAF
# Bajaj Allianz Life
# Bajaj Allianz Life is a company where Riddhi S. worked as an Intern.
# Bala Rakesh
# Bala Rakesh is a CMA finalist, Jr. Manager F&A, and Bcom graduate pursuing CMA Final.  He works at Sankar Foundation eye hospital as both a Jr. Manager F&A and Sr. Accounts assistant.
# Bala Rakesh is an individual who actively interacts on LinkedIn posts, sharing updates about his career, education, and personal life. He also interacts with job postings and company updates.
# Bala Rakesh is an individual who pursued academic studies at Andhra University and the Institute of Cost Accountants of India.
# Bala Rakesh is an individual who worked at Sankar Foundation Eye Hospital in roles such as Junior Manager and Account Intern.  Further details about their accomplishments are not available.
# Bangalore
# Bangalore is a location mentioned in several job postings shared by Greeshma G A, implying that this is where she works or where the jobs are located.
# Bangalore is the geographic region where house prices are predicted in the 'Apna-Broker' project.
# Bangalore is the location of Conga's office where Sai Arjun Manivannan interned.
# Bank of New York Mellon (BNY)
# Bank of New York Mellon is where Sai Arjun Manivannan worked as a Software Development Engineer Intern.
# Bankai Group
# Barbara Bruno
# Barbara Bruno is the instructor of at least two online courses that Greeshma G A has completed, both related to recruiting.
# BCG
# Bcom
# BCom is an undergraduate degree obtained by Anchal Baheti from Osmania University in Business/Commerce, General.
# BE is an undergraduate engineering degree obtained by Vaibhavi Ravindra Vaidya from the University of Mumbai.
# Be the best by learning from the best! Skill up in LinkedIn Ads while benefiting from real-time interaction with our in-house experts. Join our free…
# Being willing to be embarrassed is a superpower. Growth starts at the edge of your comfort zone. ♻️ Repost this to share with pushing through…
# BEML LTD
# BEML LTD is a company where Bala Rakesh started working as an Officer (Finance).
# Bengali
# Bengali is a language spoken by Rohan Sahay.
# Bengaluru
# Bengaluru is a city where Riddhi S. recently spent time and met relatives.
# Bengaluru, India
# Bengaluru, India is the location specified for a DevOps Lead position.
# Bennett University
# Bennett University is an institution that received NAAC A+ accreditation.
# Benvenuto, Lewis!
# Best Delegate ECOSOC-Sustainable development goals
# Best Manager Award
# Best Manager Award is an award.
# Best negotiator SIBM-B MUN UNCTAD
# Best Project Award
# Best Technology Bank
# Better late than never... Hey guys, I am super stoked to announce that Team Double Trouble consisting of me, Darsh Nath Segal and Saloni Baid…
# Bihar
# Bihar is a state in India with some of the lowest income levels.
# Biju Pillai
# Biju Pillai is mentioned in a thank you note by Sai Arjun Manivannan.
# BIM - Business Development Assistant
# Binu Mathew
# Binu Mathew is mentioned in a thank you note by Sai Arjun Manivannan.
# Bioinformatics
# Birla Institute of Technology and Science, Pilani
# Birla Institute of Technology and Science, Pilani is a higher education institution where Manas Tuteja pursued a Master of Technology degree in Machine Learning & Artificial Intelligence.
# Blockchain quiz held at NSUT, Delhi.
# Bollywood actor Saif Ali Khan, who was discharged from Lilavati Hospital in Mumbai.
# Book
# Book refers to the book Rohan Sahay is writing.
# books for beginners in CFD and AI/ML
# Bosch Rexroth
# Bosch Rexroth is a company where Greeshma G A worked as an Apprentice.  No specific details about responsibilities are provided.
# Boston Consulting Group (BCG), likely the provider of the Data Science & Analytics Virtual Experience Program.
# Branding and Digital Marketing
# BRM member
# BRM member is a role Sai Arjun Manivannan held at SRM MUN Society.
# BSc
# BSc is a Bachelor of Science degree obtained by Siby Abraham in Mathematics from St. Dominic's College.
# Budget 2025
# Budget 2025 is a budgetary event, likely referring to a governmental budget announcement.
# Built an end to end MLOPS solution that enables automated development, deployment, near-real-time performance monitoring and consumption of ~500 ML models hosted on Google BigQuery. Worked on transforming relational data, creating workflows on Apache Airflow and enabling parallelism through PySpark. Also conducted analytical research on: 1. Correlation of the prediction drift value to a model's OOT performance. 2. Using Shapley values to show how random samples capture seasonal… Show more
# Business analyst
# Business Analyst
# Business Analyst - Strategy & Planning
# Business Analyst at CEO's Office
# Business Analyst at CEO's Office at Bankai Group specializing in Business Consulting and We at Bankai Group's CEO's office harness data to navigate the business landscape, where I play a pivotal role in crafting data-driven strategies. My expertise in business consulting, fortified by a Lean Six Sigma Green Belt, empowers our team to pinpoint and act on key business insights. Leadership at NMIMS honed my coordination and presentation prowess, culminating in the successful orchestration of placement initiatives for a significant student body. With an MBA in Business Analytics, my ambition is to continually drive innovation and cultivate impactful solutions within the industry.
# Business Analyst is the position Rohan Sahay holds at Navikenz.
# Business analytics
# Business Analytics
# Business analytics is the field of study for Anchal Baheti's MBA.
# Business analytics is the field of study for Rohan Sahay's MBA.
# Business Analytics is the field of study for Vaibhavi Ravindra Vaidya's MBA.
# Business Analytics is the specialization of Shiwani's MBA.
# Business Consultant
# Business Consultanting Risk Service
# Business Development / BIM
# Business Development Assistant
# Business Development Manager
# Business Development Manager was a role held by Vaibhavi Ravindra Vaidya at TGJ INSTITUTE FOR MANAGEMENT & FOREIGN STUDIES.
# Business Development | Ex- Program Management Intern and Not Found
# Business/Commerce, General
# Business/Commerce, General is the field of study for Anchal Baheti's BCom degree.
# Business/Commerce, General is the field of study for Bala Rakesh's Bachelor of Commerce degree from Andhra University.
# Business/Commerce, General is the field of study for Devshri Rao's Master's degree.
# BW-RGB-Colorizer
# BW-RGB-Colorizer is a project with a description that is not found in the provided text.
# C CUBE TECHNOLOGIES
# C CUBE TECHNOLOGIES is a company where Krishnamoorthy S worked as an Industrial Design Intern.
# C#
# C# is a programming language used by Jatin Singhania to connect the HoloLens Simulator and Unity (Unreal Engine) in his internship at EY.
# Cadet Warrant Officer
# Cadet Warrant Officer is a role Krishnamoorthy S held as a volunteer in the NATIONAL CADET CORPS - India.
# Canada
# Canada is mentioned in a post relating to Justin Trudeau's resignation that Manas Tuteja interacted with.
# Caprihans India Ltd
# Caprihans India Ltd is a company with an Account Manager job opening in Nashik that Bala Rakesh interacted with.
# Cash Reconcile • Policy Underwriting on E-Portal and Cover Notes • Preparing Business MIS on daily & Monthly Basis • Payouts Calculation • Credit Approvals • Branch Co-Ordinations • Premium Calculation
# caterpillar-sized robot
# Celebrating my one year milestone with ITC limited - Hotels division as a Deputy Finance Manager. It's been a year of learning and growing. Past one…
# Centre Of Excellence Analytics & Data Science
# Centre Of Excellence Analytics & Data Science, NMIMS Mumbai
# Certification for participation in E-Summit'23 issued by E-Cell IIT Madras.
# Certification in Quantitative Finance
# Certified Scrum Product Owner (CSPO)
# CFA Institute
# CFA Institute is an organization that issues the Chartered Financial Analyst (CFA) certifications.
# CFA Institute, USA
# CFA Level - 1
# CFA Level 1
# CFA Level 2
# CFA Level 2 Candidate || LTFS II MBA - Finance & Operations || SRMIST and My job and previous internships have equipped me with abilities in data analysis, Microsoft Excel competence, team leading, risk management, and derivative pricing. Currently Pursuing CFA Level 2 along with my Job with a view to enhance my knowledge and identify the trends across Global Capital Markets.
# CFA Level 2 is a certification that Ashish Kumar is pursuing and has already achieved the Level 1.
# CFA Level 3
# CFD
# CGPI (Cumulative Grade Point Index) obtained in X standard.
# Chandan Mendiratta
# Chandan Mendiratta is mentioned as someone who is associated with the Indian School of Business.
# Channel Affinity models
# Channel Affinity models are models designed by Manas Tuteja to improve social media campaign performance.
# Chartered Accountancy
# Cheerayu Chowhan
# Cheerayu Chowhan collected donations from around 100 houses.
# Cheerayu Chowhan has contributed to over 50 conferences related to Sustainable Development Goals.
# Cheerayu Chowhan is a person who speaks English, Hindi, and Gujarati.
# ...
# University encompassing the colleges participating in the RTU THAR competition.
# University of Calgary
# University of Cambridge
# University of Mumbai
# University of Mumbai is an institution where Mohammed Shuja Tungekar pursued his Bachelor of Science degree.
# University of Mumbai is an institution where Siby Abraham obtained a PhD in Computer Science.
# University of Mumbai is where Vaibhavi Ravindra Vaidya obtained a Bachelor of Engineering degree.
# Unknown organization that awarded Shashank Shekhar for being a speaker.
# Unmanned aerial vehicles, discussed in the context of Zipline's life-saving innovation.
# Unreal Engine
# Unreal Engine is mentioned in context with Unity software and C#, suggesting it might have been used indirectly or in comparison during Jatin Singhania's internship at EY.
# Unveiling Hawk Ai – The New #Mascot of Universal Ai University 😍 Yesterday was a memorable day at Universal Ai University as our Vice Chancellor…
# UPG College's Department of Information Technology
# URGENT HIRING
# US
# USC Roski Eye Institute
# Utilized programming expertise and skills in problem solving to design and build basic applications using tools like Google Firebase, Android Studio, while making sure of the security aspects of App Development
# V for Victory! A better world is possible, and we can together make it! #victory #vote #voting2024 #universe
# Vadodara
# Vaibhavi Ravindra Vaidya
# Vaibhavi Ravindra Vaidya is a person who worked at Aditya Birla Capital as a Management Trainee and at TGJ INSTITUTE FOR MANAGEMENT & FOREIGN STUDIES as a Business Development Manager.  Details about a third role are not found.
# Vaibhavi Ravindra Vaidya is an individual who pursued higher education in business and engineering.
# Valorant
# VandeBharat train
# Vashistt Public School , Una(H.P.)
# Vashistt Public School ,Una(H.P.)
# Velammal Vidhyashram
# Velammal vidhyashram
# Velammal Vidhyashram is an educational institution where Sai Arjun Manivannan completed his 12th-grade education.
# West Bengal
# West Bengal is the location of Techno India University.
# We’re delighted to announce the successful conclusion of our placement drive at SVKM's Narsee Monjee Institute of Management Studies (NMIMS), one of…
# What an incredible experience at HR Elevate’24! It truly stood out as one of the best HR conclaves I’ve had the pleasure of attending. From the…
# What Spirituality is ?? Daily going to temple ❌ Faith in Divine ✅ So, Why is it necessary in our lifestyle ?? Look, honestly I don't know if God…
# When in doubt, blame the docs!
# When time stood still !!! Legendary Gulzar sahab unveiling my latest poetry collection - “Darmiyaan”.. Grateful to Manoj Singh and Tarun Anand for…
# Whoever moved the “cancelling a cab” from one step to 3-4 steps, Are you proud of your work? Will you put this in your portfolio? Did you get into…
# WIFE FILED #FAKE CASES DUE TO PRESSURE FROM FAMILY AND LAWYER. The wife earlier accused the husband of physically abusing her and attempting to…
# With just a couple of days left until 2025, I want to pause and reflect on the incredible journey that 2024 has been—a year of learning, unlearning…
# With the Focus on Sustainable development goals in Economic and social committee , represented france as best delegate
# With the resignation of Justin Trudeau, Canadians surely have a lot of questions about what will and should happen next to the country. To help them…
# Won 1st prize in RTU THAR final round conducted in Kota, Rajasthan, which was conducted among student of all the colleges in Rajasthan technical university.
# Won the zonal round of Aavishkar 24-25! Onto the finals ✅ #mumbaiuniversity #aavishkar
# WORK FROM HOME JOB's
# work-from-home opportunity
# Work-from-home opportunity is a job type mentioned in a post Bala Rakesh interacted with.
# Worked on building a model of an Electrical fuse box using Unity software. Used C# to tackle the complex connections between HoloLens Simulator and Unity (Unreal Engine) We aimed at preparing a model from which students could benefit in understanding emergency drills in cases of an outbreak. We made an app which allows the user to interact with an Augmented Reality model of an electrical fuse box.
# Worked on NPD/NPI project for life sciences group with SPC tools
# Worked on Projects "Datacube Ingestion and Google Earth Engine", in Geoinformatics Department at IIRS.
# Working across diverse positions in Middle and Senior level assignments for different departments & multiple campuses of the university.  Handling the complete recruitment process, involved in understanding the mandate, industry mapping and head hunting.  Sourcing and validating right candidates on the basis of the requirement(s) from different departments of the university through making use of effective recruitment and Resourcing strategies such as focused networking, reference… Show more
# working student
# Working with BigQuery
# Working with Staffing Agencies, Recruiters, Headhunters, and Career Coaches
# X Standard
# XGBoost
# XGBoost is the library used for the Gradient Boosting Algorithm in the 'Apna-Broker' project.
# XII Standard (PCM)
# YES BANK
# YES BANK is a company where Shiwani worked as a Manager in the Information Security department.  Responsibilities included stakeholder and project management for vulnerability management and digital forensics, automating application security processes, IS governance and compliance, and implementing Cloud Security Posture Management.
# YES BANK is a financial institution that has won awards for its technology and reported strong financial performance.
# YES BANK is the company where Shiwani works as a Manager.
# YES BANK's Q3FY25 financial performance is highlighted, showing growth across various aspects.
# Yes League of Excellence
# yesbank
# Yesterday was my last day as a working student at EOS GmbH, and what an incredible journey it has been! This was my first professional experience in…
# YOLO
# Zepto
# Zipline
# Zomato
# Zomato is a company where Rohan Sahay recently started working as a Key Account Manager.
# “Thou shalt not make a machine in the likeness of a human mind.” – Frank Herbert, Dune We continue with the Vision for Sustainability series by…
# 👋 Hello, LinkedIn network! 👋 I hope you're all doing well. I'm excited to announce that we're hiring for a new position at our team🚀 🌟 Hiring:…
# 👋 Hello, LinkedIn Network! 👋 I hope you're all doing well. I’m thrilled to announce that we’re hiring for an exciting opportunity on our team!…
# 👻 . . . . . Original by abhi1thakur on X.
# 💡 Transformers Transformed: DeepSeek’s Breakthrough Explained Transformers are the foundation of modern AI systems like GPT, BERT, and countless…
# 💢 Job Title: BIM - Business Development Assistant Location: Nagpur Department: Business Development / BIM Position Type: Full-time 💢 Job…
# 💢 URGENT HIRING 💢 Job Title: BIM - Business Development Assistant Location: Nagpur Department: Business Development / BIM Position Type: Full-time…
# 📊 Yes Bank's Q3FY25 Performance: Growth on All Fronts! YES BANK reported a 164.5% YoY profit surge to ₹612.27 crore! 🚀 Total income rose 14.2% YoY…
# 📊💡 𝗧𝗶𝗺𝗲 𝗩𝗮𝗹𝘂𝗲 𝗼𝗳 𝗠𝗼𝗻𝗲𝘆: ₹𝟭 𝗖𝗿𝗼𝗿𝗲 𝗧𝗼𝗱𝗮𝘆 𝗼𝗿 ₹𝟭 𝗟𝗮𝗸𝗵 𝗘𝘃𝗲𝗿𝘆 𝗠𝗼𝗻𝘁𝗵? 💭 If given a choice, would you take ₹1…
# 📌 A word of caution before we celebrate the tax cuts from Budget 2025... - The tax concession for income up to INR 12 lacs is in form of a rebate…
# 📢 Commencement of One Week Online Short-Term Course (E-STC) on Mobile Device Security We are thrilled to announce the commencement of the One Week…
# 🔥 AI-Powered Fire & Smoke Detection System 🤖 A solution that detects fire and smoke in real-time, combining YOLO and OpenCV technologies for…
# 🚀 Calling All Data & AI Enthusiasts! 🚀 We’re participating in the THD Data Science & Analytics Hackathon ’25 as Team Home Service PROs, tackling a…
# 🚀 Exciting Career Opportunity! I'm pleased to share this amazing job opening at 💢 Galactic Group for the position of Business Development Assistant…
# 🚀 Exciting Opportunity for a React Developer! 🚀 We’re on the lookout for a talented React Developer to join our dynamic team! 🌟 If you have 2-8…
# 🚀 Might be a late post, but the experience is worth sharing! In December 2024, I had the incredible opportunity to participate in a design…
# 🚀 Thrilled to begin my new journey as an Intern at HP ! A heartfelt thank you to Binu Mathew , Satish Bettadapur, Dileep Chandra and Biju Pillai…
# 🚁 𝐂𝐀𝐍 𝐃𝐑𝐎𝐍𝐄𝐒 𝐒𝐀𝐕𝐄 𝐋𝐈𝐕𝐄𝐒? 𝐙𝐈𝐏𝐋𝐈𝐍𝐄’𝐒 𝐈𝐍𝐍𝐎𝐕𝐀𝐓𝐈𝐎𝐍 𝐒𝐀𝐘𝐒 𝐘𝐄𝐒! 𝐃𝐢𝐝 𝐲𝐨𝐮 𝐤𝐧𝐨𝐰 𝐭𝐡𝐚𝐭…
# 🚥 Navigating the Fast Lane: My Debut at the Sepang 1000km Race Weekend From FIA – Fédération Internationale de l'Automobile Indian F4 to…
# 🚨 Calling all Grads! Apple released its Software Engineer - Data Science role. Here's what you need to know: ⚙ Located in Cupertino, CA ⚙…
# 🤖 A caterpillar-sized robot that can carry 100 times its weight? Scientists just did that. Think about it - a tiny machine, smaller than your…

# %% [markdown]
# ## Combining the Outputs

# %%
import json
import os
import pandas as pd

# --- File paths ---
# Segments file: Contains each chunk with its id, profile_name, segment, text, and prompt
segments_file = os.path.join("segment prompts variants", "segments_with_prompts_variants.json")

# LLM extraction file: Contains aggregated LLM results per chunk (including extracted triplets and optionally the raw LLM response)
llm_file = os.path.join("merged_triplets", "merged_triplets.json")
# We assume that in the merged file, there is a key "llm_triplets" that is a list of dictionaries, each having:
#   "chunk_id", "profile_name", "segment", "extracted_triplets", and optionally "response".
# If "response" is not present, we'll set llm_response to None.

# Rule-based triplets file: Contains a list of rule-based triplets (each coming from a profile)
rule_based_file = os.path.join("rule based extraction", "rule based triplets.json")

# --- Load data ---
# Load segments (each with chunk id, text, prompt, etc.)
with open(segments_file, "r", encoding="utf-8") as f:
    segments_data = json.load(f)

# Load LLM-based aggregated data (we use the "llm_triplets" key)
with open(llm_file, "r", encoding="utf-8") as f:
    merged_data = json.load(f)
llm_data = merged_data.get("llm_triplets", [])

# Load rule-based triplets (assumed to be a list of triplets, each with keys "entity1", "relation", "entity2")
with open(rule_based_file, "r", encoding="utf-8") as f:
    rule_based_triplets = json.load(f)

# --- Organize rule-based triplets by profile name ---
# We'll group rule-based triplets by the profile (i.e., the "entity1" should equal the profile name)
rule_based_by_profile = {}
for trip in rule_based_triplets:
    # Assume rule-based triplets have been generated with "entity1" equal to the profile name.
    profile = trip.get("entity1", "").strip()
    if profile:
        rule_based_by_profile.setdefault(profile, []).append(trip)

# --- Build a dictionary for LLM data keyed by chunk_id ---
llm_by_chunk = {}
for item in llm_data:
    cid = item.get("chunk_id")
    if cid:
        llm_by_chunk[cid] = item  # item should have keys: chunk_id, profile_name, segment, extracted_triplets, and possibly "response"

# --- Create one row per chunk ---
rows = []
for seg in segments_data:
    # Each segment in segments_data has keys: "id", "profile_name", "segment", "text", "prompt"
    chunk_id = seg.get("id")
    profile_name = seg.get("profile_name", "").strip()
    segment = seg.get("segment", "").strip()
    chunk_text = seg.get("text", "").strip()
    prompt_used = seg.get("prompt", "").strip()
    
    # Get corresponding LLM data by chunk id (if available)
    llm_entry = llm_by_chunk.get(chunk_id, {})
    # Extract the LLM response if available; if not, use None
    llm_response = llm_entry.get("response", None)
    # Also get LLM extracted triplets (if available)
    llm_triplets_list = llm_entry.get("triplets") or llm_entry.get("extracted_triplets") or []
    
    # Get rule-based triplets for this profile (if available)
    rule_based_for_profile = rule_based_by_profile.get(profile_name, [])
    
    # Add source labels to each triplet (for clarity)
    # For LLM-based triplets, we add a field "source": "LLM"
    llm_triplets_labeled = []
    for t in llm_triplets_list:
        t_copy = t.copy()
        t_copy["source"] = "LLM"
        llm_triplets_labeled.append(t_copy)
    
    # For rule-based triplets, add "source": "Rule-Based"
    rule_based_labeled = []
    for t in rule_based_for_profile:
        t_copy = t.copy()
        t_copy["source"] = "Rule-Based"
        rule_based_labeled.append(t_copy)
    
    # Combine both lists (LLM-based and rule-based)
    combined_triplets = llm_triplets_labeled + rule_based_labeled
    
    # Create a row dictionary
    row = {
        "chunk_id": chunk_id,
        "profile_name": profile_name,
        "segment": segment,
        "chunk_text": chunk_text,
        "prompt": prompt_used,
        "llm_response": llm_response,
        "triplets": combined_triplets
    }
    rows.append(row)

# --- Create the DataFrame ---
df = pd.DataFrame(rows)

# Optionally, you can explode the triplets column so that each triplet becomes a separate row.
# Here, we keep one row per chunk with a list of triplets.
print("DataFrame with one row per chunk:")
print(df.head())

# Save the DataFrame to a CSV file (or pickle, or any other format)
output_csv = os.path.join("final_triplets", "chunks_with_triplets.csv")
df.to_csv(output_csv, index=False)
print(f"\nDataFrame saved to {output_csv}")
# Out:
# DataFrame with one row per chunk:
#                            chunk_id   profile_name         segment  \
# 0  0d572b5c29aa2225e7d88ac039ef2132    Alexis Ryan  headline_about
# 1  5b70211aaef28cb176b913a41060be3a    Alexis Ryan     experiences
# 2  baf603122069ef036efe473e35c13c06    Alexis Ryan      activities
# 3  7a14d64cdd63b849c981afab119f45fc    Alexis Ryan      educations
# 4  e5d4a604a0d775c08b18765eb39737db  Anchal Baheti  headline_about
#
#                                           chunk_text  \
# 0  Alexis Ryan describes about himself: software ...
# 1  Alexis Ryan worked at Ford Motor Company serve...
# 2  Alexis Ryan interacted on post Hard-coded a le...
# 3  Alexis Ryan studied at Queen Mary University o...
# 4  Anchal Baheti describes about himself: NMIMS M...
#
#                                               prompt llm_response  \
# 0  This chunk represents the personal introductio...         None
# 1  This chunk encapsulates the professional exper...         None
# 2  This chunk captures the individual's recent Li...         None
# 3  This chunk provides information about the indi...         None
# 4  This chunk represents the personal introductio...         None
#
#                                             triplets
# 0  [{'entity1': 'Alexis Ryan', 'relation': 'is a ...
# 1  [{'entity1': 'Alexis Ryan', 'relation': 'is a ...
# 2  [{'entity1': 'Alexis Ryan', 'relation': 'is a ...
# 3  [{'entity1': 'Alexis Ryan', 'relation': 'descr...
# 4  [{'entity1': 'Anchal Baheti', 'relation': 'is ...
#
# DataFrame saved to final_triplets\chunks_with_triplets.csv

# %% [markdown]
# ## Saving KG in nanovector db

# %%
! pip install qdrant-client sentence-transformers pandas
# Out:
# Collecting qdrant-client
#   Downloading qdrant_client-1.13.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sentence-transformers in d:\anaconda\lib\site-packages (3.4.1)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: grpcio>=1.41.0 in d:\anaconda\lib\site-packages (from qdrant-client) (1.71.0)
# Collecting grpcio-tools>=1.41.0 (from qdrant-client)
#   Downloading grpcio_tools-1.71.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx>=0.20.0 in d:\anaconda\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.1)
# Requirement already satisfied: numpy>=1.26 in d:\anaconda\lib\site-packages (from qdrant-client) (1.26.4)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pydantic>=1.10.8 in d:\anaconda\lib\site-packages (from qdrant-client) (2.10.6)
# Requirement already satisfied: urllib3<3,>=1.26.14 in d:\anaconda\lib\site-packages (from qdrant-client) (2.2.3)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in d:\anaconda\lib\site-packages (from sentence-transformers) (4.50.0)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in d:\anaconda\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in d:\anaconda\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from sentence-transformers) (1.12.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in d:\anaconda\lib\site-packages (from sentence-transformers) (0.29.3)
# Requirement already satisfied: Pillow in d:\anaconda\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in d:\anaconda\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client) (5.29.4)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client) (75.1.0)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.9.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.2)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.14.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant-client)
#   Downloading h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in d:\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: pywin32>=226 in d:\anaconda\lib\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client) (305.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic>=1.10.8->qdrant-client) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\anaconda\lib\site-packages (from pydantic>=1.10.8->qdrant-client) (2.27.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: networkx in d:\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in d:\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anaconda\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in d:\anaconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\anaconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in d:\anaconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Downloading qdrant_client-1.13.3-py3-none-any.whl (306 kB)
# Downloading grpcio_tools-1.71.0-cp312-cp312-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------------------------- -- 1.0/1.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 2.5 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading h2-4.2.0-py3-none-any.whl (60 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: portalocker, hyperframe, hpack, grpcio-tools, h2, qdrant-client
# Successfully installed grpcio-tools-1.71.0 h2-4.2.0 hpack-4.1.0 hyperframe-6.1.0 portalocker-2.10.1 qdrant-client-1.13.3

# %%
# %%writefile setup_vector_db.py
import os
import ast
import json
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
import time
from nano_vectordb import NanoVectorDB

# --------- Load DataFrame from CSV ---------
df_path = os.path.join("final_triplets", "chunks_with_triplets.csv")
df = pd.read_csv(df_path)

def parse_triplets(val):
    try:
        return ast.literal_eval(val)
    except Exception as e:
        print(f"Error parsing triplets: {e}")
        return []

df['triplets'] = df['triplets'].apply(lambda x: parse_triplets(x) if isinstance(x, str) else x)

# --------- Initialize Embedding Model ---------
model = SentenceTransformer('all-MiniLM-L6-v2')
embedding_dim = 384

# --------- Prepare Records for Each Collection ---------
chunk_points = []
relation_points = []
entity_points = {}  # Use dict for unique entities

def normalize_entity(ent):
    return ent.strip().lower().replace(" ", "_")

for idx, row in df.iterrows():
    # For every row, process the chunk
    chunk_id = row["chunk_id"]
    profile_name = row["profile_name"]
    segment = row["segment"]
    chunk_text = row["chunk_text"]
    
    # Compute chunk embedding
    chunk_emb = model.encode(chunk_text)
    chunk_point = {
        "id": chunk_id,
        "__vector__": chunk_emb,  # Store as NumPy array
        "payload": {
            "profile_name": profile_name,
            "segment": segment,
            "text": chunk_text
        }
    }
    chunk_points.append(chunk_point)
    
    # Process triplets (if any) in the row
    triplets = row.get("triplets", [])
    for i, trip in enumerate(triplets):
        entity1 = trip.get("entity1", "")
        relation = trip.get("relation", "")
        entity2 = trip.get("entity2", "")
        source = trip.get("source", "LLM")
        
        # Compute embeddings for each component and average them
        e1_emb = model.encode(entity1)
        rel_emb = model.encode(relation)
        e2_emb = model.encode(entity2)
        combined_emb = (e1_emb + rel_emb + e2_emb) / 3.0
        
        trip_id = f"{chunk_id}_{i}"
        relation_point = {
            "id": trip_id,
            "__vector__": combined_emb,  # Store as NumPy array
            "payload": {
                "chunk_id": chunk_id,
                "profile_name": profile_name,
                "segment": segment,
                "source": source,
                "entity1": entity1,
                "relation": relation,
                "entity2": entity2
            }
        }
        relation_points.append(relation_point)
        
        # Process individual entities
        for ent in [entity1, entity2]:
            if ent:
                ent_id = normalize_entity(ent)
                if ent_id not in entity_points:
                    ent_emb = model.encode(ent)
                    entity_points[ent_id] = {
                        "id": ent_id,
                        "__vector__": ent_emb,  # Store as NumPy array
                        "payload": {"text": ent, "chunk_ids": [chunk_id]}
                    }
                else:
                    if chunk_id not in entity_points[ent_id]["payload"].get("chunk_ids", []):
                        entity_points[ent_id]["payload"].setdefault("chunk_ids", []).append(chunk_id)

# Convert entity_points dict to a list
entity_points_list = list(entity_points.values())

# --------- Initialize NanoVectorDB Instances ---------
chunk_db = NanoVectorDB(embedding_dim, storage_file="chunk_db.json")
relation_db = NanoVectorDB(embedding_dim, storage_file="relation_db.json")
entity_db = NanoVectorDB(embedding_dim, storage_file="entity_db.json")

# --------- Upsert the Prepared Records ---------
print("Upserting chunk points...")
chunk_upsert_result = chunk_db.upsert(chunk_points)
print("Upserted chunks:", chunk_upsert_result)

print("Upserting relation points...")
if relation_points:
    relation_upsert_result = relation_db.upsert(relation_points)
    print("Upserted relations:", relation_upsert_result)
else:
    print("No relation points to upsert.")

print("Upserting entity points...")
if entity_points_list:
    entity_upsert_result = entity_db.upsert(entity_points_list)
    print("Upserted entities:", entity_upsert_result)
else:
    print("No entity points to upsert.")

# --------- Save the Databases ---------
chunk_db.save()
relation_db.save()
entity_db.save()

print("\nAll embeddings have been stored in NanoVectorDB:")
print(" - Chunk embeddings saved in 'chunk_db.json'")
print(" - Relation embeddings saved in 'relation_db.json'")
print(" - Entity embeddings saved in 'entity_db.json'")
# Out:
# Writing setup_vector_db.py

# %%
# !python setup_vector_db.py
# Out:
# Upserting chunk points...
# Upserted chunks: {'update': [], 'insert': ['2289fc76aa6fb31ead8050940e58980d', 'd66f9d478400414588b650fc359bdc17', '65bc6215ffc7d7244dbc1a645b59cc7c', '31a571cb699cc6eb003cd78322b59765', '91cdcc2a596b698df18023adf3a061e3', 'a6ca4ba25f38c12113cdfadc54c7fb77', '5cdabd3addb0006b6277ea4daa4c7f1c', '8751d3c5dbd042ba23634840485509f6', 'f83540e1beacb8634c42a04a8a80a685', '395b2e80eef04f5fc6201f5b57036b4b', '12aadbf127cb51bf88496d1b00d07956', 'f9d2ea6de29c8f59f3dab5e7d157ad26', '3650467f5ecfb7bdbde8d7f3d9a8cb19', '298efb998c469d8fdc5979434bf4a519', '13fbc2cb2e7ef99c2a52b4e1eef5ef83', '6c588a250ed1010c2eb8aba976b3b98
# After running the script, load each DB file and print the first record for verification.
def load_db(db_file):
    with open(db_file, "r", encoding="utf-8") as f:
        data = json.load(f)
    # NanoVectorDB saves data as a dict with "data" key if records exist.
    if isinstance(data, dict) and "data" in data:
        return data["data"]
    elif isinstance(data, list):
        return data
    else:
        return []

def print_first_record(name, db_file):
    records = load_db(db_file)
    print(f"\n{name} (Total {len(records)} records):")
    if records:
        # Convert numpy arrays to lists for printing, if needed
        rec = records[0]
        if not isinstance(rec.get("__vector__"), list) and hasattr(rec.get("__vector__"), "tolist"):
            rec["__vector__"] = rec["__vector__"].tolist()
        print(json.dumps(rec, indent=2))
    else:
        print("No records found.")

print_first_record("Chunk DB", "chunk_db.json")
print_first_record("Relation DB", "relation_db.json")
print_first_record("Entity DB", "entity_db.json")
# Out:
# Chunk DB (Total 128 records):
# {
#   "id": "0d572b5c29aa2225e7d88ac039ef2132",
#   "payload": {
#     "profile_name": "Alexis Ryan",
#     "segment": "headline_about",
#     "text": "Alexis Ryan describes about himself: software developer at Ford motors and I am currently doing 6 months of internship at Ford. I am a enthusiast for development , be it web development or game development. I have developed a 2d platformer game using Unity engine , 3d FPS game using Unreal engine and I along with my team of 3 created a virtual autonomous drone for a IEEE competition , all this in the duration of my B.Tech program .."
#   },
#   "__id__": "2289fc76aa6fb31ead8050940e58980d"
# }
#
# Relation DB (Total 2280 records):
# {
#   "id": "0d572b5c29aa2225e7d88ac039ef2132_0",
#   "payload": {
#     "chunk_id": "0d572b5c29aa2225e7d88ac039ef2132",
#     "profile_name": "Alexis Ryan",
#     "segment": "headline_about",
#     "source": "LLM",
#     "entity1": "Alexis Ryan",
#     "relation": "is a person",
#     "entity2": "Alexis Ryan is a software developer who is currently completing a 6-month internship at Ford Motors.  He is passionate about web and game development and has experience developing 2D and 3D games using Unity and Unreal Engine, respectively. He also participated in an IEEE competition with a team, creating a virtual autonomous drone."
#   },
#   "__id__": "49d49089e22cef1049c9d5c421c7f584"
# }
#
# Entity DB (Total 2356 records):
# {
#   "id": "alexis_ryan",
#   "payload": {
#     "text": "Alexis Ryan",
#     "chunk_ids": [
#       "0d572b5c29aa2225e7d88ac039ef2132",
#       "5b70211aaef28cb176b913a41060be3a",
#       "baf603122069ef036efe473e35c13c06",
#       "7a14d64cdd63b849c981afab119f45fc"
#     ]
#   },
#   "__id__": "73814a0fc863b569767ef25ae5c0786b"
# }

# %% [markdown]
# # Visualization

# %%
import os
import json
import networkx as nx
from pyvis.network import Network
import webbrowser

def load_db(db_file):
    """Load records from a NanoVectorDB JSON file."""
    with open(db_file, "r", encoding="utf-8") as f:
        data = json.load(f)
    # NanoVectorDB typically stores records under a "data" key.
    if isinstance(data, dict) and "data" in data:
        return data["data"]
    elif isinstance(data, list):
        return data
    else:
        return []

def normalize_entity(ent):
    """Normalize an entity string to use as an ID."""
    return ent.strip().lower().replace(" ", "_")

# --- File paths for your saved JSON databases ---
entity_db_file = "entity_db.json"
relation_db_file = "relation_db.json"

# --- Load data from the entity and relation JSON files ---
entity_records = load_db(entity_db_file)
relation_records = load_db(relation_db_file)

# --- Build a dictionary of nodes (entities) ---
nodes = {}
# First, add nodes from the entity DB if available.
for rec in entity_records:
    # Use rec["id"] or rec["__id__"] as the entity id.
    eid = rec.get("id") or rec.get("__id__")
    if not eid:
        continue
    # Use the payload text as the label, or fallback to eid.
    label = rec.get("payload", {}).get("text", eid)
    nodes[eid] = label

# Then, ensure every entity mentioned in the relations exists.
for rec in relation_records:
    payload = rec.get("payload", {})
    ent1 = payload.get("entity1", "")
    ent2 = payload.get("entity2", "")
    norm1 = normalize_entity(ent1)
    norm2 = normalize_entity(ent2)
    if norm1 and norm1 not in nodes:
        nodes[norm1] = ent1  # use the raw text as label
    if norm2 and norm2 not in nodes:
        nodes[norm2] = ent2

# --- Build a NetworkX graph using these nodes and relation records as edges ---
G = nx.DiGraph()

# Add entity nodes to the graph
for eid, label in nodes.items():
    G.add_node(eid, label=label)

# Add edges based on relation records
for rec in relation_records:
    payload = rec.get("payload", {})
    ent1 = payload.get("entity1", "")
    ent2 = payload.get("entity2", "")
    rel_text = payload.get("relation", "")
    norm1 = normalize_entity(ent1)
    norm2 = normalize_entity(ent2)
    if norm1 and norm2:
        # Add edge from entity1 to entity2 with the relation text as label.
        G.add_edge(norm1, norm2, label=rel_text, title=rel_text)

# --- Visualize the Knowledge Graph using PyVis ---
net = Network(height="750px", width="100%", directed=True, cdn_resources="remote", notebook=False)
net.from_nx(G)

# Customize node appearance: set tooltip to show node label.
for node in net.nodes:
    node["title"] = node.get("label", "")
    node["label"] = node.get("label", "")

# Customize edge appearance
for edge in net.edges:
    edge["title"] = edge.get("title", "")
    edge["label"] = edge.get("label", "")

# Generate the HTML file for the visualization.
output_path = "kg_entities_relations.html"
html_str = net.generate_html(notebook=False)
with open(output_path, "w", encoding="utf-8") as f:
    f.write(html_str)

# Open the generated HTML in the default web browser.
webbrowser.open("file://" + os.path.realpath(output_path))
print("Graph visualization saved as:", output_path)
# Out:
# Graph visualization saved as: kg_entities_relations.html

# %%
import os
import json
import networkx as nx

def load_db(db_file):
    """Load records from a NanoVectorDB JSON file."""
    with open(db_file, "r", encoding="utf-8") as f:
        data = json.load(f)
    if isinstance(data, dict) and "data" in data:
        return data["data"]
    elif isinstance(data, list):
        return data
    else:
        return []

def normalize_entity(ent):
    """Normalize an entity string to use as an ID."""
    return ent.strip().lower().replace(" ", "_")

# --- File paths for your saved JSON databases ---
entity_db_file = "entity_db.json"
relation_db_file = "relation_db.json"

# --- Load data from the entity and relation JSON files ---
entity_records = load_db(entity_db_file)
relation_records = load_db(relation_db_file)

# --- Build a dictionary of nodes (entities) with full metadata ---
nodes = {}
# Add nodes from the entity DB.
for rec in entity_records:
    node_id = rec.get("id") or rec.get("__id__")
    if not node_id:
        continue
    rec_meta = rec.copy()
    rec_meta["label"] = rec.get("payload", {}).get("text", node_id)
    nodes[node_id] = rec_meta

# Ensure every entity mentioned in relations exists.
for rec in relation_records:
    payload = rec.get("payload", {})
    ent1 = payload.get("entity1", "")
    ent2 = payload.get("entity2", "")
    norm1 = normalize_entity(ent1)
    norm2 = normalize_entity(ent2)
    if norm1 and norm1 not in nodes:
        nodes[norm1] = {"label": ent1, "payload": {"text": ent1}}
    if norm2 and norm2 not in nodes:
        nodes[norm2] = {"label": ent2, "payload": {"text": ent2}}

# --- Build a directed graph using NetworkX ---
G = nx.DiGraph()

# Add nodes with their metadata.
for node_id, meta in nodes.items():
    G.add_node(node_id, **meta)

# Add edges based on relation records.
for rec in relation_records:
    payload = rec.get("payload", {})
    ent1 = payload.get("entity1", "")
    ent2 = payload.get("entity2", "")
    norm1 = normalize_entity(ent1)
    norm2 = normalize_entity(ent2)
    if norm1 and norm2:
        edge_meta = rec.copy()
        edge_meta["label"] = payload.get("relation", "")
        G.add_edge(norm1, norm2, **edge_meta)

# --- Pre-process graph attributes for GraphML export ---
# Convert dictionary attributes to JSON strings.
def convert_attrs(attrs):
    for key, value in attrs.items():
        if isinstance(value, dict):
            attrs[key] = json.dumps(value)
    return attrs

# Update node attributes.
for node, data in G.nodes(data=True):
    G.nodes[node].update(convert_attrs(data))

# Update edge attributes.
for u, v, data in G.edges(data=True):
    G.edges[u, v].update(convert_attrs(data))

# --- Save the graph in GraphML format with converted attributes ---
graphml_path = "kg_entities_relations.graphml"
nx.write_graphml(G, graphml_path)
print("GraphML file saved as:", os.path.realpath(graphml_path))
# Out:
# GraphML file saved as: C:\Users\cheer\rv_v1.3\Indexer\kg_entities_relations.graphml

# %%
import os
import json
import networkx as nx
from sentence_transformers import SentenceTransformer
import numpy as np

# --- Settings ---
graphml_path = "kg_entities_relations.graphml"
output_json_path = "kg_entities_word_embeddings.json"
# Using a MiniLM model (all-MiniLM-L6-v2 is common)
model_name = "all-MiniLM-L6-v2"

# --- Load the MiniLM model ---
model = SentenceTransformer(model_name)

def compute_word_embedding(word: str):
    """
    Compute the embedding for a given word using the model.
    Returns the embedding as a list of floats.
    """
    # The model expects text input; even though it's optimized for sentences,
    # we use it on individual words.
    embedding = model.encode(word)
    # Convert to a list for JSON serialization.
    return embedding.tolist()

def process_text(text: str):
    """
    Splits the text into words and computes an embedding for each word.
    Returns a list of dictionaries, each containing the word and its embedding.
    """
    words_info = []
    # Use a simple split on whitespace; you might want to improve this by removing punctuation, etc.
    words = text.split()
    for word in words:
        emb = compute_word_embedding(word)
        words_info.append({
            "word": word,
            "embedding": emb
        })
    return words_info

def safe_parse_json(data_str):
    """
    Try to parse a JSON string safely; if parsing fails, return an empty dict.
    """
    try:
        return json.loads(data_str)
    except Exception:
        return {}

# --- Load the graph from GraphML ---
G = nx.read_graphml(graphml_path)

# --- Process Nodes and Edges ---
output_data = {
    "nodes": {},
    "edges": {}
}

# Process nodes.
for node_id, attrs in G.nodes(data=True):
    # Retrieve the payload if available (it's stored as a JSON string)
    payload = safe_parse_json(attrs.get("payload", "{}"))
    text = payload.get("text", "")
    chunk_ids = payload.get("chunk_ids", [])
    
    # Compute word embeddings for the text.
    words_info = process_text(text)
    
    output_data["nodes"][node_id] = {
        "original_text": text,
        "chunk_ids": chunk_ids,
        "words": words_info,
        # Optionally include any other metadata from the node:
        "meta": {k: v for k, v in attrs.items() if k not in ["payload", "label"]}
    }

# Process edges.
# For each edge we use a compound key based on source, target, and an edge index.
edge_index = 0
for u, v, attrs in G.edges(data=True):
    # Retrieve the payload if available (it's stored as a JSON string)
    payload = safe_parse_json(attrs.get("payload", "{}"))
    relation_text = payload.get("relation", "")
    chunk_ids = payload.get("chunk_id", None)  # might be a single value or list depending on your data
    # Compute word embeddings for the relation text.
    words_info = process_text(relation_text)
    
    edge_key = f"{u}--{v}--{edge_index}"
    output_data["edges"][edge_key] = {
        "source": u,
        "target": v,
        "relation_text": relation_text,
        "chunk_ids": chunk_ids,
        "words": words_info,
        "meta": {k: v for k, v in attrs.items() if k not in ["payload", "label"]}
    }
    edge_index += 1

# --- Save the structured output as JSON ---
with open(output_json_path, "w", encoding="utf-8") as out_file:
    json.dump(output_data, out_file, indent=2)

print("Embeddings for every word in nodes and edges have been saved to:", os.path.realpath(output_json_path))
# Out:
# Embeddings for every word in nodes and edges have been saved to: C:\Users\cheer\rv_v1.3\Indexer\kg_entities_word_embeddings.json

# %%
import os
import json
from sentence_transformers import SentenceTransformer

# --- Settings ---
chunk_db_file = "chunk_db.json"           # Input chunk database file
output_json_path = "chunk_word_embeddings.json"  # Output JSON file path
model_name = "all-MiniLM-L6-v2"              # MiniLM model name

# --- Load the MiniLM model ---
model = SentenceTransformer(model_name)

def load_db(db_file):
    """Load records from a NanoVectorDB JSON file."""
    with open(db_file, "r", encoding="utf-8") as f:
        data = json.load(f)
    if isinstance(data, dict) and "data" in data:
        return data["data"]
    elif isinstance(data, list):
        return data
    else:
        return []

def compute_word_embedding(word: str):
    """Compute and return the embedding for a given word as a list of floats."""
    embedding = model.encode(word)
    return embedding.tolist()

def process_text(text: str):
    """
    Splits the text into words and computes an embedding for each word.
    Returns a list of dictionaries, each containing the word and its embedding.
    """
    words_info = []
    # Split on whitespace. You can use more advanced tokenization if needed.
    words = text.split()
    for word in words:
        emb = compute_word_embedding(word)
        words_info.append({
            "word": word,
            "embedding": emb
        })
    return words_info

# --- Load chunk database ---
chunks = load_db(chunk_db_file)

# --- Process each chunk ---
output_data = {"data": []}

for rec in chunks:
    # Extract the chunk ID and payload metadata.
    chunk_id = rec.get("id")
    internal_id = rec.get("__id__")
    payload = rec.get("payload", {})
    profile_name = payload.get("profile_name")
    segment = payload.get("segment")
    text = payload.get("text", "")
    
    # Process the text: compute word-level embeddings.
    words_info = process_text(text)
    
    # Prepare structured data for this chunk.
    chunk_entry = {
        "id": chunk_id,
        "__id__": internal_id,
        "payload": {
            "profile_name": profile_name,
            "segment": segment,
            "text": text,
            "words": words_info  # Each word with its embedding.
        }
    }
    output_data["data"].append(chunk_entry)

# --- Save the structured word embeddings along with metadata as JSON ---
with open(output_json_path, "w", encoding="utf-8") as out_file:
    json.dump(output_data, out_file, indent=2)

print("Chunk word embeddings have been saved to:", os.path.realpath(output_json_path))
# Out:
# Chunk word embeddings have been saved to: C:\Users\cheer\rv_v1.3\Indexer\chunk_word_embeddings.json
